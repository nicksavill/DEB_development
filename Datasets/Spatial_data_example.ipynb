# %%
Geopandas needs its own environemnt on my machine - hopefully not hte case onthe Univerisity servers?

# %%
conda create --name Spatial
conda activate spatial 
conda install geopandas
conda install -c anaconda seaborn 
conda remove gdal
conda remove fiona
conda install -c conda-forge fiona=1.8.4
conda install -c conda-forge gdal=2.3.3
python -m ipykernel install --user --name=Spatial
conda deactivate

# %% [markdown]
# Within Conda Forge, I force uninstalled both GDAL and Fiona, then installed Fiona 1.8.19 as suggested by Abhiram. Conda Forge installed GDAL 3.2.2 as part of this process, and the two seem to work together well
#
#
#
# Eventually I ended up with the following versions:
#
# python 3.7.11
#
# geopandas 0.6.1
#
# gdal 2.3.3
#
# fiona 1.8.4
#
# Share

# %%
# Analysis modules
import numpy as np
import pandas as pd
import matplotlib as mpl
import seaborn as sns
import geopandas as gpd
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~/opt/anaconda3/envs/spatial/lib/python3.6/site-packages/numpy/core/__init__.py in <module>
#      16 try:
# ---> 17     from . import multiarray
#      18 except ImportError as exc:
#
# ~/opt/anaconda3/envs/spatial/lib/python3.6/site-packages/numpy/core/multiarray.py in <module>
#      13
# ---> 14 from . import overrides
#      15 from . import _multiarray_umath
#
# ~/opt/anaconda3/envs/spatial/lib/python3.6/site-packages/numpy/core/overrides.py in <module>
#       6
# ----> 7 from numpy.core._multiarray_umath import (
#       8     add_docstring, implement_array_function, _get_implementing_args)
#
# ImportError: dlopen(/Users/ckidner/opt/anaconda3/envs/spatial/lib/python3.6/site-packages/numpy/core/_multiarray_umath.cpython-36m-darwin.so, 2): Library not loaded: @rpath/libopenblas.dylib
# ...

# %%
PATH = '/home/thibauld/Documents/Bioinformatics/Bioinformatics_lab_book/2022_06_23_ROH_PNG_Begonia'

dfgeo = pd.read_csv('dffinal.csv', sep=',')
#.astype('category')
dfgeo
# Out:
#      Unnamed: 0 #ID_Hannah_thesis  NROH     SROH          Species Coll_number  \
# 0             0                 1   123  172.422  B.bipinnatifida       90414
# 1             1               102   265  510.787    B.Petermannia      41875B
# 2             2               110   110  300.562    B.Petermannia     B15JD87
# 3             3               113    31   41.544       B.strigosa        5167
# 4             4               117   119  170.453     B.Symbegonia         594
# ..          ...               ...   ...      ...              ...         ...
# 124         124                84     4    4.814    B.Petermannia    NGF17871
# 125         125                87     4    4.398      B.tafaensis       22330
# 126         126                89    59   92.645    B.Petermannia       23593
# 127         127                93     3    4.457    B.Petermannia        2644
# 128         128                97    18   22.126    B.Petermannia    LAE50435
#
# ...

# %%
# Add FROH
dfgeo['FROH'] = dfgeo['SROH'] / 310462
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-291bf394c14c> in <module>
#       1 # Add FROH
# ----> 2 dfgeo['FROH'] = dfgeo['SROH'] / 310462
#
# NameError: name 'dfgeo' is not defined

# %%
gpd.datasets.get_path("naturalearth_lowres")
# Out:
# '/Users/ckidner/opt/anaconda3/envs/spatial/lib/python3.6/site-packages/geopandas/datasets/naturalearth_lowres/naturalearth_lowres.shp'

# %%
countries = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-e83b6b35728d> in <module>
# ----> 1 countries = gpd.read_file(gpd.datasets.get_path("naturalearth_lowres"))
#
# ~/opt/anaconda3/envs/spatial/lib/python3.6/site-packages/geopandas/io/file.py in _read_file(filename, bbox, mask, rows, **kwargs)
#     125     by using the encoding keyword parameter, e.g. ``encoding='utf-8'``.
#     126     """
# --> 127     _check_fiona("'read_file' function")
#     128     if _is_url(filename):
#     129         req = _urlopen(filename)
#
# ~/opt/anaconda3/envs/spatial/lib/python3.6/site-packages/geopandas/io/file.py in _check_fiona(func)
#      41     if fiona is None:
#      42         raise ImportError(
# ---> 43             f"the {func} requires the 'fiona' package, but it is not installed or does "
# ...

# %%
countries.head()
