# %% [markdown]
# ### If you're feeling more ambitious....

# %% [markdown]
# I want to look at the evolution of Begonia in Papua New Guinea.  How many already have sequence in NCBI and how many will I need to sequence?

# %% [markdown]
# List of Begonia sequences in Genbank can be got here:
#     https://www.ncbi.nlm.nih.gov/genbank/
# Search txid3681[Organism:exp]
# Download the complete record in format summary (button at bottom right of page)

# %% [markdown]
# List of Begonia in Papua New Guinea can be got here:
#     https://padme.rbge.org.uk/Begonia/data/checklist
# Make a checklist for Papua New Guinea.  You have the option to download as a word document, but this will not read directly into pandas, to access this we need to install a new module - python-docx

# %%
pip install python-docx
# Out:
# Requirement already satisfied: python-docx in /Users/ckidner/opt/anaconda3/lib/python3.8/site-packages (0.8.11)
# Requirement already satisfied: lxml>=2.3.2 in /Users/ckidner/opt/anaconda3/lib/python3.8/site-packages (from python-docx) (4.9.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import docx
PNG_doc = docx.Document('../datasets/Checklist of Papua New Guinea.docx')

# %% [markdown]
# We can then extract the text

# %%
text = [p.text for p in PNG_doc.paragraphs if p.text]  
text
# Out:
# ['Begonia L.',
#  'Acetosa Mill.',
#  'Riessia Klotzsch',
#  'Trilomisa Raf.',
#  'Sect. Baryandra',
#  'Begonia sharpeana F.Muell.',
#  'Sect. Diploclinium',
#  'Begonia Sect. Trilobaria A.DC.',
#  'Diploclinium Lindl.',
#  'Begonia acaulis Merr. & L.M.Perry',
#  'Begonia bartlettiana Merr. & L.M.Perry',
#  'Begonia kaniensis Irmsch.',
#  'Begonia minjemensis Irmsch.',
#  'Begonia subcyclophylla Irmsch.',
#  'Sect. Donaldia',
#  'Donaldia Klotzsch',
#  'Begonia ulmifolia Willd.',
#  'Begonia dasycarpa A.DC.',
#  'Begonia gesnerioides L.B.Sm. & B.G.Schub.',
#  'Begonia jairii Brade',
#  'Donaldia ulmifolia (Willd.) Klotzsch',
#  'Sect. Ignota',
#  'Begonia archboldiana Merr. & L.M.Perry',
#  'Begonia physandra Merr. & L.M.Perry',
#  'Sect. Oligandrae',
#  'Begonia chambersiae W.N.Takeuchi',
#  'Begonia maguniana H.P.Wilson',
#  'Begonia oligandra Merr. & L.M.Perry',
#  'Begonia pentandra W.N.Takeuchi',
#  'Begonia sandsiana W.N.Takeuchi',
#  'Sect. Petermannia',
#  'Petermannia Klotzsch',
#  'Begonia aikrono H.P.Wilson & Jimbo',
#  'Begonia augustae Irmsch.',
#  'Begonia bipinnatifida J.J.Sm.',
#  'Begonia brevirimosa Irmsch.',
#  'Begonia brevirimosa subsp. exotica Tebbitt',
#  'Begonia exotica A.B. Graf ex Golding nom. nud.',
#  'Begonia calliantha Merr. & L.M.Perry',
#  'Begonia clemensiae Merr. & L.M.Perry',
#  'Begonia diffusiflora Merr. & L.M.Perry',
#  'Begonia djamuensis Irmsch.',
#  'Begonia dosedlae Gilli',
#  'Begonia eliasii Warb.',
#  'Begonia elianii Warb. orth. var.',
#  'Begonia filibracteosa Irmsch.',
#  'Begonia fractalifolia H.P.Wilson & Jimbo',
#  'Begonia gilgiana Irmsch.',
#  'Begonia glabricaulis Irmsch.',
#  'Begonia glabricaulis var. brachyphylla Irmsch.',
#  'Begonia glabricaulis var. glabricaulis',
#  'Begonia hirsuticaulis Irmsch.',
#  'Begonia kelliana Irmsch.',
#  'Begonia kerstingii Irmsch.',
#  'Begonia lauterbachii Warb.',
#  'Begonia lauterbachii forma monopoda Irmsch. nom. inval.',
#  'Begonia ledermannii Irmsch.',
#  'Begonia malmquistiana Irmsch.',
#  'Begonia media Merr. & L.M.Perry',
#  'Begonia monantha Warb.',
#  'Begonia montis-bismarckii Warb.',
#  'Begonia multidentata Warb.',
#  'Begonia naumoniensis Irmsch.',
#  'Begonia novoguineensis Merr. & L.M.Perry',
#  'Begonia papuana Warb.',
#  'Begonia pediophylla Merr. & L.M.Perry',
#  'Begonia pinnatifida Merr. & L.M.Perry',
#  'Begonia randiana Merr. & L.M.Perry',
#  'Begonia rieckei Warb.',
#  'Begonia aptera var. calleryana (A.DC.) Fern.-Vill.',
#  'Begonia axillipara Ridl.',
#  'Begonia brachybotrys Merr. & L.M.Perry',
#  'Begonia brachyptera Merr. & L.M.Perry',
#  'Begonia calleryana Merr. orth. var.',
#  'Begonia koordersii Warb. ex Koord. nom. nud.',
#  'Begonia koordersii Warb. ex L.B.Sm. & Wassh.',
#  'Begonia lateralis Elmer ex Merr. nom. nud.',
#  'Begonia peekelii Irmsch.',
#  'Begonia pseudolateralis Warb.',
#  'Begonia strictipetiolaris Irmsch.',
#  'Mezierea salaziensis var. calleryana A.DC.',
#  'Begonia sandaunensis H.P.Wilson & Jimbo',
#  'Begonia serratipetala Irmsch.',
#  'Begonia simulans Merr. & L.M.Perry',
#  'Begonia sogerensis Ridl.',
#  'Begonia spilotophylla F.Muell.',
#  'Begonia stilandra Merr. & L.M.Perry',
#  'Begonia strictinervis Irmsch.',
#  'Begonia suffrutescens Merr. & L.M.Perry',
#  'Begonia tafaensis Merr. & L.M.Perry',
#  'Begonia torricellensis Warb.',
#  'Begonia warburgii K.Schum. & Lauterb.',
#  'Begonia wariana Irmsch.',
#  'Begonia weigallii Hemsl.',
#  'Begonia salomonensis Merr. & L.M.Perry',
#  'Sect. Symbegonia',
#  'Symbegonia Warb.',
#  'Begonia arauensis M.Hughes',
#  'Begonia argenteomarginata Tebbitt',
#  'Begonia asaroensis J.Gagul',
#  'Begonia erodifolia Sands',
#  'Begonia fulvo-villosa Warb.',
#  'Symbegonia fulvo-villosa (Warb.) Warb.',
#  'Begonia mooreana (Irmsch.) L.L.Forrest & Hollingsw.',
#  'Symbegonia mooreana Irmsch.',
#  'Begonia strigosa (Warb.) L.L.Forrest & Hollingsw.',
#  'Symbegonia strigosa Warb.',
#  'Begonia symbracteosa L.L.Forrest & Hollingsw.',
#  'Symbegonia bracteosa Warb.',
#  'Begonia symgeraniifolia L.L.Forrest & Hollingsw.',
#  'Symbegonia geraniifolia Ridl.',
#  'Begonia symsanguinea L.L.Forrest & Hollingsw.',
#  'Symbegonia sanguinea Warb.',
#  'Begonia vinkii Sands']

# %% [markdown]
# The text is a python list, so we can access individual elements:

# %%
text[13]
# Out:
# 'Begonia subcyclophylla Irmsch.'

# %% [markdown]
# We need to filter this to just the species names

# %%
Species = []
for i in text:
    if i.startswith("Begonia"):
        Species.append(i)

# %%
len(Species)
# Out:
# 92

# %%
Species[10]
# Out:
# 'Begonia gesnerioides L.B.Sm. & B.G.Schub.'

# %% [markdown]
# We can make this list into a dataframe:
#
#     df2 = df.Dataframe(LIST, columns=["colum_name"])

# %%
#png_beg = pd.DataFrame(Species, columns=['Text'])

# %%
png_beg.head(3)
# Out:
#                              Text
# 0                      Begonia L.
# 1      Begonia sharpeana F.Muell.
# 2  Begonia Sect. Trilobaria A.DC.

# %% [markdown]
# We need to split these strings into columns.  Use:
#
#         df["Column"].str.split("delimitor", expand=True)
#
# This will make as many columns as needed by the number of time the delimitor appears in the string

# %%
#png_all = png_beg["Text"].str.split(" ", expand=True)
png_all.head(10)
# Out:
#          0               1           2      3          4     5     6     7
# 0  Begonia              L.        None   None       None  None  None  None
# 1  Begonia       sharpeana    F.Muell.   None       None  None  None  None
# 2  Begonia           Sect.  Trilobaria  A.DC.       None  None  None  None
# 3  Begonia         acaulis       Merr.      &  L.M.Perry  None  None  None
# 4  Begonia    bartlettiana       Merr.      &  L.M.Perry  None  None  None
# 5  Begonia       kaniensis     Irmsch.   None       None  None  None  None
# 6  Begonia     minjemensis     Irmsch.   None       None  None  None  None
# 7  Begonia  subcyclophylla     Irmsch.   None       None  None  None  None
# 8  Begonia       ulmifolia      Willd.   None       None  None  None  None
# 9  Begonia       dasycarpa       A.DC.   None       None  None  None  None

# %% [markdown]
# It will be helpful to re-name the colmns
#
#    df.columns =['name1', 'name2', 'name3']

# %%
png_all.columns =['Genus', 'Species', 'Auth1', 'And', 'Auth2', 'And2', 'Auth3', 'Stuff']
png_all.head(10)
# Out:
#      Genus         Species       Auth1    And      Auth2  And2 Auth3 Stuff
# 0  Begonia              L.        None   None       None  None  None  None
# 1  Begonia       sharpeana    F.Muell.   None       None  None  None  None
# 2  Begonia           Sect.  Trilobaria  A.DC.       None  None  None  None
# 3  Begonia         acaulis       Merr.      &  L.M.Perry  None  None  None
# 4  Begonia    bartlettiana       Merr.      &  L.M.Perry  None  None  None
# 5  Begonia       kaniensis     Irmsch.   None       None  None  None  None
# 6  Begonia     minjemensis     Irmsch.   None       None  None  None  None
# 7  Begonia  subcyclophylla     Irmsch.   None       None  None  None  None
# 8  Begonia       ulmifolia      Willd.   None       None  None  None  None
# 9  Begonia       dasycarpa       A.DC.   None       None  None  None  None

# %% [markdown]
# Subset the dataframe to just the genus, species and first author name:
#
#     df2=df[["Column1","Column2"]]

# %%
png_species=png_all[["Genus", "Species", "Auth1"]]
png_species.head(10)
# Out:
#      Genus         Species       Auth1
# 0  Begonia              L.        None
# 1  Begonia       sharpeana    F.Muell.
# 2  Begonia           Sect.  Trilobaria
# 3  Begonia         acaulis       Merr.
# 4  Begonia    bartlettiana       Merr.
# 5  Begonia       kaniensis     Irmsch.
# 6  Begonia     minjemensis     Irmsch.
# 7  Begonia  subcyclophylla     Irmsch.
# 8  Begonia       ulmifolia      Willd.
# 9  Begonia       dasycarpa       A.DC.

# %% [markdown]
# We will join this to the genbank list to see what sequences exist for these species.

# %% [markdown]
# Checking the structure of the NCBI file using:
#
#     ! head my_file.txt
#     ! tail my_file.txt

# %%
#! head nuccore_result.txt
# Out:
# 1. Begonia minor voucher L.L. Forrest 161 (E) internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# 764 bp linear DNA
# AF485171.1 GI:33320582
#
# 2. Begonia cubensis voucher L.L. Forrest 159 (E) internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence
# 759 bp linear DNA
# AF485169.1 GI:33320580
#
# 3. Begonia odorata voucher L.L. Forrest 158 (E) internal transcribed spacer 1, partial sequence; 5.8S ribosomal RNA gene, complete sequence; and internal transcribed spacer 2, partial sequence

# %%
#! tail nuccore_result.txt
# Out:
# 673 bp linear DNA
# AB302885.1 GI:187761564
#
# 7143. Fusarium oxysporum f. sp. batatas strain NRRL 25594 elongation factor EF1 alpha-like mRNA, partial sequence
# 650 bp linear mRNA
# AY337717.1 GI:43336389
#
# 7144. Fusarium oxysporum f. sp. batatas strain NRRL 25594 beta-tubulin-like mRNA, partial sequence
# 569 bp linear mRNA
# AY337716.1 GI:43336363

# %% [markdown]
# We want to read this in with the number ignored, the first two words put into columns "Genus' and "species' the next line put into  column.  Read in the file as a table, giving the single column the name "Text"

# %%
#genbank = pd.read_table('../datasets/nuccore_result.txt', header = None, names=["Text"])

# %%
genbank.head(10)
# Out:
#                                                 Text
# 0  1. Begonia minor voucher L.L. Forrest 161 (E) ...
# 1                                 764 bp linear DNA
# 2                             AF485171.1 GI:33320582
# 3  2. Begonia cubensis voucher L.L. Forrest 159 (...
# 4                                 759 bp linear DNA
# 5                             AF485169.1 GI:33320580
# 6  3. Begonia odorata voucher L.L. Forrest 158 (E...
# 7                                 741 bp linear DNA
# 8                             AF485168.1 GI:33320579
# 9  4. Begonia obliqua internal transcribed spacer...

# %%
genbank.describe()
# Out:
#                          0
# count                21432
# unique               15883
# top     606 bp linear DNA
# freq                   153

# %% [markdown]
# This is not handy.  We need to filter for just the rows with "Begonia" in and split the lines into columns.

# %% [markdown]
# To pull out the Begonia rows use:
#
#     df_new = df[df["column"].str.contains("matching_text")]

# %%
beg_gen =  genbank[genbank["Text"].str.contains("Begonia")]

# %%
beg_gen.head(4)
# Out:
#                                                 Text
# 0  1. Begonia minor voucher L.L. Forrest 161 (E) ...
# 3  2. Begonia cubensis voucher L.L. Forrest 159 (...
# 6  3. Begonia odorata voucher L.L. Forrest 158 (E...
# 9  4. Begonia obliqua internal transcribed spacer...

# %% [markdown]
# We need to split these strings into columns.  Use the string splilter as you did earlier:
#
#         df["Column"].str.split("delimitor", expand=True)
#
# The dleimitor on this file should be ";"

# %%
all = beg_gen["Text"].str.split(";", expand=True)

# %%
all.head(3)
# Out:
#                                                    0  \
# 0  1. Begonia minor voucher L.L. Forrest 161 (E) ...
# 3  2. Begonia cubensis voucher L.L. Forrest 159 (...
# 6  3. Begonia odorata voucher L.L. Forrest 158 (E...
#
#                                              1  \
# 0   5.8S ribosomal RNA gene, complete sequence
# 3   5.8S ribosomal RNA gene, complete sequence
# 6   5.8S ribosomal RNA gene, complete sequence
#
#                                                    2     3
# 0   and internal transcribed spacer 2, partial se...  None
# 3   and internal transcribed spacer 2, partial se...  None
# 6   and internal transcribed spacer 2, partial se...  None

# %%
all.tail(3)
# Out:
#                                                        0               1  \
# 20298  6767. Bemisia tabaci isolate 159_ArujaSP_Begon...   mitochondrial
# 20301  6768. Bemisia tabaci isolate 105_GuarulhosSP_B...   mitochondrial
# 20304  6769. Bemisia tabaci isolate 90_LondrinaPR_Beg...   mitochondrial
#
#           2     3
# 20298  None  None
# 20301  None  None
# 20304  None  None

# %%
all.columns =['Sample', 'Locus1', 'Locus2', 'Stuff']
all.head(10)
# Out:
#                                                Sample  \
# 0   1. Begonia minor voucher L.L. Forrest 161 (E) ...
# 3   2. Begonia cubensis voucher L.L. Forrest 159 (...
# 6   3. Begonia odorata voucher L.L. Forrest 158 (E...
# 9   4. Begonia obliqua internal transcribed spacer...
# 12  5. Begonia silletensis subsp. mengyangensis vo...
# 15  6. Begonia cf. breviramosa Forrest 138 interna...
# 18  7. Begonia sp. Forrest 190 voucher L.L. Forres...
# 21  8. Begonia obliqua 26S ribosomal RNA gene, par...
# 24  9. Begonia dregei subsp. homonyma 18S ribosoma...
# 27  10. Begonia luxurians voucher L.L. Forrest 180...
#
#                                                Locus1  \
# 0          5.8S ribosomal RNA gene, complete sequence
# 3          5.8S ribosomal RNA gene, complete sequence
# 6          5.8S ribosomal RNA gene, complete sequence
# 9          5.8S ribosomal RNA gene, complete sequence
# 12         5.8S ribosomal RNA gene, complete sequence
# 15         5.8S ribosomal RNA gene, complete sequence
# 18         5.8S ribosomal RNA gene, complete sequence
# 21                                               None
# 24   internal transcribed spacer 1, 5.8S ribosomal...
# 27         5.8S ribosomal RNA gene, complete sequence
#
#                                                Locus2 Stuff
# 0    and internal transcribed spacer 2, partial se...  None
# 3    and internal transcribed spacer 2, partial se...  None
# 6    and internal transcribed spacer 2, partial se...  None
# 9    and internal transcribed spacer 2, partial se...  None
# 12   and internal transcribed spacer 2, partial se...  None
# 15   and internal transcribed spacer 2, partial se...  None
# 18   and internal transcribed spacer 2, partial se...  None
# 21                                               None  None
# 24       and 28S ribosomal RNA gene, partial sequence  None
# 27   and internal transcribed spacer 2, partial se...  None

# %% [markdown]
# Now you need to split the first column to isolate the species name.  use str.split again, expanding it and chooeing the third item in the series (Python is 0-indexed

# %%
genus = all["Sample"].str.split(" ", expand=True)[1]
species = all["Sample"].str.split(" ", expand=True)[2]

# %%
type(species)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Add this new series to the dataframe

# %%
all = all.assign(Species = species)
all = all.assign(Genus = genus)
all.head(10)
# Out:
#                                                Sample  \
# 0   1. Begonia minor voucher L.L. Forrest 161 (E) ...
# 3   2. Begonia cubensis voucher L.L. Forrest 159 (...
# 6   3. Begonia odorata voucher L.L. Forrest 158 (E...
# 9   4. Begonia obliqua internal transcribed spacer...
# 12  5. Begonia silletensis subsp. mengyangensis vo...
# 15  6. Begonia cf. breviramosa Forrest 138 interna...
# 18  7. Begonia sp. Forrest 190 voucher L.L. Forres...
# 21  8. Begonia obliqua 26S ribosomal RNA gene, par...
# 24  9. Begonia dregei subsp. homonyma 18S ribosoma...
# 27  10. Begonia luxurians voucher L.L. Forrest 180...
#
#                                                Locus1  \
# 0          5.8S ribosomal RNA gene, complete sequence
# 3          5.8S ribosomal RNA gene, complete sequence
# 6          5.8S ribosomal RNA gene, complete sequence
# 9          5.8S ribosomal RNA gene, complete sequence
# 12         5.8S ribosomal RNA gene, complete sequence
# 15         5.8S ribosomal RNA gene, complete sequence
# 18         5.8S ribosomal RNA gene, complete sequence
# 21                                               None
# 24   internal transcribed spacer 1, 5.8S ribosomal...
# 27         5.8S ribosomal RNA gene, complete sequence
#
#                                                Locus2 Stuff      Species  \
# 0    and internal transcribed spacer 2, partial se...  None        minor
# 3    and internal transcribed spacer 2, partial se...  None     cubensis
# 6    and internal transcribed spacer 2, partial se...  None      odorata
# 9    and internal transcribed spacer 2, partial se...  None      obliqua
# 12   and internal transcribed spacer 2, partial se...  None  silletensis
# 15   and internal transcribed spacer 2, partial se...  None          cf.
# 18   and internal transcribed spacer 2, partial se...  None          sp.
# 21                                               None  None      obliqua
# 24       and 28S ribosomal RNA gene, partial sequence  None       dregei
# 27   and internal transcribed spacer 2, partial se...  None    luxurians
#
#       Genus
# 0   Begonia
# 3   Begonia
# 6   Begonia
# 9   Begonia
# 12  Begonia
# 15  Begonia
# 18  Begonia
# 21  Begonia
# 24  Begonia
# 27  Begonia

# %% [markdown]
# Now we just join the dataframes to see which sequences we have for Begonia from Papua New Guinea

# %%
png_species.head(10)
# Out:
#      Genus         Species       Auth1
# 0  Begonia              L.        None
# 1  Begonia       sharpeana    F.Muell.
# 2  Begonia           Sect.  Trilobaria
# 3  Begonia         acaulis       Merr.
# 4  Begonia    bartlettiana       Merr.
# 5  Begonia       kaniensis     Irmsch.
# 6  Begonia     minjemensis     Irmsch.
# 7  Begonia  subcyclophylla     Irmsch.
# 8  Begonia       ulmifolia      Willd.
# 9  Begonia       dasycarpa       A.DC.

# %% [markdown]
# Combine these lists into a dataframe

# %%
result = png_species.merge(all, on ='Species', suffixes=("_PNG", "_in_gen_bank"))
result
# Out:
#     Genus_PNG       Species        Auth1  \
# 0     Begonia     ulmifolia       Willd.
# 1     Begonia     ulmifolia       Willd.
# 2     Begonia     ulmifolia       Willd.
# 3     Begonia     ulmifolia       Willd.
# 4     Begonia     ulmifolia       Willd.
# ..        ...           ...          ...
# 118   Begonia  symsanguinea  L.L.Forrest
# 119   Begonia  symsanguinea  L.L.Forrest
# 120   Begonia  symsanguinea  L.L.Forrest
# 121   Begonia  symsanguinea  L.L.Forrest
# 122   Begonia  symsanguinea  L.L.Forrest
#
#                                                 Sample  \
# 0    61. Begonia ulmifolia voucher L.L. Forrest 169...
# 1    895. Begonia ulmifolia isolate EDNA12-0025425 ...
# 2    1020. Begonia ulmifolia isolate EDNA12-0025425...
# 3    1105. Begonia ulmifolia isolate EDNA120025425 ...
# 4    1271. Begonia ulmifolia trnC-trnD intergenic s...
# ..                                                 ...
# 118  4717. Begonia symsanguinea voucher Glasgow Bot...
# 119  4746. Begonia symsanguinea voucher Glasgow Bot...
# 120  4775. Begonia symsanguinea voucher Glasgow Bot...
# 121  4804. Begonia symsanguinea voucher Glasgow Bot...
# 122  4833. Begonia symsanguinea voucher Glasgow Bot...
#
#                                                 Locus1  \
# 0           5.8S ribosomal RNA gene, complete sequence
# 1                                              plastid
# 2                                              plastid
# 3                                              plastid
# 4                                                 None
# ..                                                 ...
# 118                                      mitochondrial
# 119                                      mitochondrial
# 120                                        chloroplast
# 121   photosystem II 44 kDa protein (psbC), complet...
# 122     petB-petD intergenic spacer, complete sequence
#
#                                                 Locus2         Stuff  \
# 0     and internal transcribed spacer 2, partial se...          None
# 1                                                 None          None
# 2                                                 None          None
# 3                                                 None          None
# 4                                                 None          None
# ..                                                 ...           ...
# 118                                               None          None
# 119                                               None          None
# 120                                               None          None
# 121   and psbC-trnS intergenic spacer, partial sequ...   chloroplast
# 122   cytochrome b6/f complex subunit IV (petD), pa...   chloroplast
#
#     Genus_in_gen_bank
# 0             Begonia
# 1             Begonia
# 2             Begonia
# 3             Begonia
# 4             Begonia
# ..                ...
# 118           Begonia
# 119           Begonia
# 120           Begonia
# 121           Begonia
# 122           Begonia
#
# [123 rows x 8 columns]

# %% [markdown]
# Count the number of Genbank accessions per PNG species

# %%
result['Species'].value_counts()
# Out:
# ulmifolia            30
# aptera               21
# symsanguinea         18
# brevirimosa          12
# koordersii            8
# pseudolateralis       7
# bipinnatifida         6
# serratipetala         6
# gesnerioides          3
# augustae              3
# weigallii             3
# argenteomarginata     3
# strigosa              3
# Name: Species, dtype: int64
