# %% [markdown]
# ## Trialing the new UK Flora dataset for data exploration
# The dataset contains a current inventory of vascular plant species and their attributes present in the flora of Britain and Ireland. The species list is based on the most recent key to the flora of Britain and Ireland, with taxon names linked to unique Kew taxon identifiers and the World Checklist of Vascular Plants, and includes both native and non-native species. Attribute data stem from a variety of sources to give an overview of the current state of the vascular flora. Attributes include functional traits, distribution and ecologically relevant data (e.g. genome size, chromosome numbers, spatial distribution, growth form, hybridization metrics and native/non-native status). The data include previously unpublished genome size measurements, chromosome counts and CSR life strategy assessments. The database aims to provide an up-to-date starting point for flora-wide analyses.
#
# This dataset will be available under the terms of the Open Government Licence https://eidc.ceh.ac.uk/licences/OGL/plain Publication date: 2021-09-20
#
# https://catalogue.ceh.ac.uk/documents/9f097d82-7560-4ed2-af13-604a9110cf6d
#
# Need to register to download the data.
#
# You must always use the following attribution statement to acknowledge the source of the information: "Contains data supplied by Natural Environment Research Council."
#
# You must include any copyright notice identified in the metadata record for the Data on all copies of the Data, publications and reports, including but not limited to, use in presentations to any audience.
#
# You will ensure that citation of any relevant key publications, Digital Object Identifiers and any other required acknowledgments identified in the metadata record for the Data are included in full in the reference list of any reports or publications that describe any research in which the Data have been used.
#
# Downloaded the data and the supporting information

# %%
! ls New_Flora_datasets/data
# Out:
# BI_main.csv      GS_BI.csv        GS_Kew_BI.csv    chrom_num_BI.csv

# %%
! head -3 New_Flora_datasets/data/*.csv
# Out:
# ==> New_Flora_datasets/data/BI_main.csv <==
# kew_id,unclear_species_marker,extinct_species_marker,taxon_name,taxon_name_binom,authors,taxon_name_WCVP,authors_WCVP,order,family,genus,subgenus,section,subsection,series,species,group,aggregate,members_of_agg.,taxonomic_status,accepted_kew_id,accepted_name,accepted_authors,imperfect_match_with_Stace_IV,WCVP_URL,POWO_URL,IPNI_URL,accepted_WCVP_URL,StaceIV_nativity,Atlas_nativity_viaALIENATT_PLANTATT,Stace_Crawley_nativity_aliens,SLA,LDMC,seed_mass,leaf_area,mean_veg_height,max_veg_height,L_PLANTATT,F_PLANTATT,R_PLANTATT,N_PLANTATT,S_PLANTATT,L_Doring,F_Doring,R_Doring,N_Doring,S_Doring,T_Doring,ECPE_CSR,predicted_CSR,growth_form,succulence,life_form,biome,origin,TDWG_level_1_code,GB_Man_hectads_post2000,Ire_hectads_post2000,CI_hectads_post2000,GB_Man_hectads_1987_1999,Ire_hectads_1987_1999,CI_hectads_1987_1999,GB_Man_hectads_2000_2009,Ire_hectads_2000_2009,CI_hectads_2000_2009,GB_Man_hectads_2010_2019,Ire_hectads_2010_2019,CI_hectads_2010_2019,hybrid_propensity,scaled_hybrid_propensity,BOLD_link1,BOLD_link2,BOLD_link3,GS_1C_pg,GS_2C_pg,GS_1C_Mbp,GS_2C_Mbp,from_BI_material,data_source,sporophytic_chromosome_number,infraspecific_variation_chrom_number,other_reported_sporophytic_chromosome_number,source_of_other_chrom_num
# 60468511-2,,,Abies alba Mill.,Abies alba,Mill.,Abies alba,Mill.,Pinales,Pinaceae,Abies,,,,,alba,,,,Accepted,,,,,https://wcvp.science.kew.org/taxon/60468511-2,http://plantsoftheworldonline.org/taxon/60468511-2,https://ipni.org/n/60468511-2,,Neo-natd,AN,Neo,7.698508098,0.529816331,65.61283431,255.0291582,46.84389333,68,NA,NA,NA,NA,NA,3,NA,NA,NA,0,5,NA,S,Tree,NA,phanerophyte / tree,,mountains in C Europe,1,382,230,0,230,28,0,120,179,0,303,89,0,NA,NA,NA,NA,NA,17.27,34.54,16891.68,33783.36,n,�marda et al. 2019,NA,NA,24,"�marda et al. 2019, Zonneveld, 2019"
# 325658-2,,,Abies amabilis Douglas ex J.Forbes,Abies amabilis,Douglas ex J.Forbes,Abies amabilis,(Douglas ex Loudon) J.Forbes,Pinales,Pinaceae,Abies,,,,,amabilis,,,,Accepted,,,,,https://wcvp.science.kew.org/taxon/325658-2,http://plantsoftheworldonline.org/taxon/325658-2,https://ipni.org/n/325658-2,,,,,86.69076923,NA,42.27712579,NA,50.14852174,75,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,Tree,NA,phanerophyte / tree,,W N America,7,11,0,0,7,0,0,5,0,0,8,0,0,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA,NA
#
# ==> New_Flora_datasets/data/GS_BI.csv <==
# kew_id,taxon_name,taxon_name_binom,authors,GS_2C_pg,GS_1C_pg,GS_2C_Mbp,GS_1C_Mbp,from_BI_material,data_source,ID
# 781250-1,Acer campestre L.,Acer campestre,L.,1.62,0.81,1584.36,792.18,y,Kew,1
# 781462-1,Acer pseudoplatanus L.,Acer pseudoplatanus,L.,3.18,1.59,3110.04,1555.02,y,Kew,1
#
# ==> New_Flora_datasets/data/GS_Kew_BI.csv <==
# kew_id,taxon_name,taxon_name_binom,authors,MSB_number,standard_species,standard_2C_pg,buffer,buffer_composition,buffer_origin,GS_2C_pg,GS_1C_pg,GS_2C_Mbp,GS_1C_Mbp,cv_sample,cv_standard,matched_by_synonym,cited_name
# 781250-1,Acer campestre L.,Acer campestre,L.,,Petroselinum crispum (Mill.) Nyman ex A.W.Hill �Champion Moss Curled�,4.5,General purpose buffer 3%PVPBmet,Spermine.4HCl 0.5mM - Sodium citrate 30mM - MOPS 20mM - KCl 80mM - NaCl 20mM - Triton X-100 0.5% - PVP 40 3% - beta-Mercaptoethanol,"Loureiro, J., Rodriguez, E., Dole�el, J. and Santos, C. Two new nuclear isolation buffers for plant DNA flow cytometry: a test with 37 species. Annals of botany, 100(4), 875-888 (2007).",1.62,0.81,1584.36,792.18,2.94,2.7,,
# 781462-1,Acer pseudoplatanus L.,Acer pseudoplatanus,L.,,Petroselinum crispum (Mill.) Nyman ex A.W.Hill �Champion Moss Curled�,4.5,CyStain PI OxProtect,NA,https://eu.sysmex-flowcytometry.com/reagents/cystain-ploidy-dna-analysis/2964/cystain-pi-oxprotect?c=116,3.18,1.59,3110.04,1555.02,2.49,2.43,,
#
# ==> New_Flora_datasets/data/chrom_num_BI.csv <==
# kew_id,taxon_name,cited_name,sporophytic_chromosome_number,notes,unambiguous_match,number_identical_observations,,,,,
# 781250-1,Acer campestre L.,Acer campestre L.,26,,y,1,,,,,
# 77067622-1,Achillea maritima (L.) Ehrhend. & Y.P.Guo,Diotis maritima (L.) Sm.,18,,n,1,,,,,

# %%
# Analysis modules
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
import statsmodels.api as sm
np.set_printoptions(precision=5, suppress=True)  # suppress scientific floatation 
sns.set(color_codes=True)
# %matplotlib inline
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %% [markdown]
# Check the dataframe

# %%
Dtofl = pd.read_csv('New_Flora_datasets/data/BI_main.csv', sep=",", encoding='latin-1')

# %%
Dtofl.head(3)
# Out:
#        kew_id unclear_species_marker extinct_species_marker  \
# 0  60468511-2                    NaN                    NaN
# 1    325658-2                    NaN                    NaN
# 2    261486-1                    NaN                    NaN
#
#                            taxon_name   taxon_name_binom              authors  \
# 0                    Abies alba Mill.         Abies alba                Mill.
# 1  Abies amabilis Douglas ex J.Forbes     Abies amabilis  Douglas ex J.Forbes
# 2            Abies cephalonica Loudon  Abies cephalonica               Loudon
#
#      taxon_name_WCVP                  authors_WCVP    order    family  genus  \
# 0         Abies alba                         Mill.  Pinales  Pinaceae  Abies
# 1     Abies amabilis  (Douglas ex Loudon) J.Forbes  Pinales  Pinaceae  Abies
# 2  Abies cephalonica                        Loudon  Pinales  Pinaceae  Abies
#
#   subgenus section subsection series      species group aggregate  \
# 0      NaN     NaN        NaN    NaN         alba   NaN       NaN
# 1      NaN     NaN        NaN    NaN     amabilis   NaN       NaN
# 2      NaN     NaN        NaN    NaN  cephalonica   NaN       NaN
#
#   members_of_agg. taxonomic_status accepted_kew_id accepted_name  \
# 0             NaN         Accepted             NaN           NaN
# 1             NaN         Accepted             NaN           NaN
# 2             NaN         Accepted             NaN           NaN
#
#   accepted_authors imperfect_match_with_Stace_IV  \
# 0              NaN                           NaN
# 1              NaN                           NaN
# 2              NaN                           NaN
#
#                                         WCVP_URL  \
# 0  https://wcvp.science.kew.org/taxon/60468511-2
# 1    https://wcvp.science.kew.org/taxon/325658-2
# 2    https://wcvp.science.kew.org/taxon/261486-1
#
#                                             POWO_URL  \
# 0  http://plantsoftheworldonline.org/taxon/604685...
# 1   http://plantsoftheworldonline.org/taxon/325658-2
# 2   http://plantsoftheworldonline.org/taxon/261486-1
#
#                         IPNI_URL accepted_WCVP_URL StaceIV_nativity  \
# 0  https://ipni.org/n/60468511-2               NaN         Neo-natd
# 1    https://ipni.org/n/325658-2               NaN              NaN
# 2    https://ipni.org/n/261486-1               NaN         Neo-natd
#
#   Atlas_nativity_viaALIENATT_PLANTATT Stace_Crawley_nativity_aliens  \
# 0                                  AN                           Neo
# 1                                 NaN                           NaN
# 2                                  AN                           Neo
#
#          SLA      LDMC  seed_mass   leaf_area  mean_veg_height  \
# 0   7.698508  0.529816  65.612834  255.029158        46.843893
# 1  86.690769       NaN  42.277126         NaN        50.148522
# 2   6.530926       NaN  71.430000         NaN        25.875000
#
#    max_veg_height  L_PLANTATT  F_PLANTATT  R_PLANTATT  N_PLANTATT  S_PLANTATT  \
# 0            68.0         NaN         NaN         NaN         NaN         NaN
# 1            75.0         NaN         NaN         NaN         NaN         NaN
# 2            40.0         NaN         NaN         NaN         NaN         NaN
#
#    L_Doring  F_Doring  R_Doring  N_Doring  S_Doring  T_Doring ECPE_CSR  \
# 0       3.0       NaN       NaN       NaN       0.0       5.0      NaN
# 1       NaN       NaN       NaN       NaN       NaN       NaN      NaN
# 2       NaN       NaN       NaN       NaN       NaN       NaN      NaN
#
#   predicted_CSR growth_form succulence            life_form biome  \
# 0             S        Tree        NaN  phanerophyte / tree   NaN
# 1           NaN        Tree        NaN  phanerophyte / tree   NaN
# 2           NaN        Tree        NaN  phanerophyte / tree   NaN
#
#                   origin TDWG_level_1_code  GB_Man_hectads_post2000  \
# 0  mountains in C Europe                 1                    382.0
# 1            W N America                 7                     11.0
# 2                 Greece                 1                     11.0
#
#    Ire_hectads_post2000  CI_hectads_post2000  GB_Man_hectads_1987_1999  \
# 0                 230.0                  0.0                     230.0
# 1                   0.0                  0.0                       7.0
# 2                   0.0                  0.0                       6.0
#
#    Ire_hectads_1987_1999  CI_hectads_1987_1999  GB_Man_hectads_2000_2009  \
# 0                   28.0                   0.0                     120.0
# 1                    0.0                   0.0                       5.0
# 2                    0.0                   0.0                       1.0
#
#    Ire_hectads_2000_2009  CI_hectads_2000_2009  GB_Man_hectads_2010_2019  \
# 0                  179.0                   0.0                     303.0
# 1                    0.0                   0.0                       8.0
# 2                    0.0                   0.0                       9.0
#
#    Ire_hectads_2010_2019  CI_hectads_2010_2019  hybrid_propensity  \
# 0                   89.0                   0.0                NaN
# 1                    0.0                   0.0                NaN
# 2                    0.0                   0.0                NaN
#
#    scaled_hybrid_propensity BOLD_link1 BOLD_link2 BOLD_link3  GS_1C_pg  \
# 0                       NaN        NaN        NaN        NaN     17.27
# 1                       NaN        NaN        NaN        NaN       NaN
# 2                       NaN        NaN        NaN        NaN     18.14
#
#    GS_2C_pg  GS_1C_Mbp  GS_2C_Mbp from_BI_material         data_source  \
# 0     34.54   16891.68   33783.36                n  marda et al. 2019
# 1       NaN        NaN        NaN              NaN                 NaN
# 2     36.27   17738.00   35476.00              NaN           C-ValueDB
#
#   sporophytic_chromosome_number infraspecific_variation_chrom_number  \
# 0                           NaN                                  NaN
# 1                           NaN                                  NaN
# 2                           NaN                                  NaN
#
#   other_reported_sporophytic_chromosome_number  \
# 0                                           24
# 1                                          NaN
# 2                                          NaN
#
#              source_of_other_chrom_num
# 0  marda et al. 2019, Zonneveld, 2019
# 1                                  NaN
# 2                                  NaN

# %% [markdown]
# What do we have data on?

# %%
Dtofl.columns
# Out:
# Index(['kew_id', 'unclear_species_marker', 'extinct_species_marker',
#        'taxon_name', 'taxon_name_binom', 'authors', 'taxon_name_WCVP',
#        'authors_WCVP', 'order', 'family', 'genus', 'subgenus', 'section',
#        'subsection', 'series', 'species', 'group', 'aggregate',
#        'members_of_agg.', 'taxonomic_status', 'accepted_kew_id',
#        'accepted_name', 'accepted_authors', 'imperfect_match_with_Stace_IV',
#        'WCVP_URL', 'POWO_URL', 'IPNI_URL', 'accepted_WCVP_URL',
#        'StaceIV_nativity', 'Atlas_nativity_viaALIENATT_PLANTATT',
#        'Stace_Crawley_nativity_aliens', 'SLA', 'LDMC', 'seed_mass',
#        'leaf_area', 'mean_veg_height', 'max_veg_height', 'L_PLANTATT',
#        'F_PLANTATT', 'R_PLANTATT', 'N_PLANTATT', 'S_PLANTATT', 'L_Doring',
#        'F_Doring', 'R_Doring', 'N_Doring', 'S_Doring', 'T_Doring', 'ECPE_CSR',
#        'predicted_CSR', 'growth_form', 'succulence', 'life_form', 'biome',
#        'origin', 'TDWG_level_1_code', 'GB_Man_hectads_post2000',
#        'Ire_hectads_post2000', 'CI_hectads_post2000',
#        'GB_Man_hectads_1987_1999', 'Ire_hectads_1987_1999',
#        'CI_hectads_1987_1999', 'GB_Man_hectads_2000_2009',
#        'Ire_hectads_2000_2009', 'CI_hectads_2000_2009',
#        'GB_Man_hectads_2010_2019', 'Ire_hectads_2010_2019',
#        'CI_hectads_2010_2019', 'hybrid_propensity', 'scaled_hybrid_propensity',
#        'BOLD_link1', 'BOLD_link2', 'BOLD_link3', 'GS_1C_pg', 'GS_2C_pg',
#        'GS_1C_Mbp', 'GS_2C_Mbp', 'from_BI_material', 'data_source',
#        'sporophytic_chromosome_number', 'infraspecific_variation_chrom_number',
#        'other_reported_sporophytic_chromosome_number',
#        'source_of_other_chrom_num'],
#       dtype='object')

# %% [markdown]
# What types are these?

# %%
Dtofl.dtypes
# Out:
# kew_id                                           object
# unclear_species_marker                           object
# extinct_species_marker                           object
# taxon_name                                       object
# taxon_name_binom                                 object
# authors                                          object
# taxon_name_WCVP                                  object
# authors_WCVP                                     object
# order                                            object
# family                                           object
# genus                                            object
# subgenus                                         object
# section                                          object
# subsection                                       object
# series                                           object
# species                                          object
# group                                            object
# aggregate                                        object
# members_of_agg.                                  object
# taxonomic_status                                 object
# accepted_kew_id                                  object
# accepted_name                                    object
# accepted_authors                                 object
# imperfect_match_with_Stace_IV                    object
# WCVP_URL                                         object
# POWO_URL                                         object
# IPNI_URL                                         object
# accepted_WCVP_URL                                object
# StaceIV_nativity                                 object
# Atlas_nativity_viaALIENATT_PLANTATT              object
# Stace_Crawley_nativity_aliens                    object
# SLA                                             float64
# LDMC                                            float64
# seed_mass                                       float64
# leaf_area                                       float64
# mean_veg_height                                 float64
# max_veg_height                                  float64
# L_PLANTATT                                      float64
# F_PLANTATT                                      float64
# R_PLANTATT                                      float64
# N_PLANTATT                                      float64
# S_PLANTATT                                      float64
# L_Doring                                        float64
# F_Doring                                        float64
# R_Doring                                        float64
# N_Doring                                        float64
# S_Doring                                        float64
# T_Doring                                        float64
# ECPE_CSR                                         object
# predicted_CSR                                    object
# growth_form                                      object
# succulence                                       object
# life_form                                        object
# biome                                            object
# origin                                           object
# TDWG_level_1_code                                object
# GB_Man_hectads_post2000                         float64
# Ire_hectads_post2000                            float64
# CI_hectads_post2000                             float64
# GB_Man_hectads_1987_1999                        float64
# Ire_hectads_1987_1999                           float64
# CI_hectads_1987_1999                            float64
# GB_Man_hectads_2000_2009                        float64
# Ire_hectads_2000_2009                           float64
# CI_hectads_2000_2009                            float64
# GB_Man_hectads_2010_2019                        float64
# Ire_hectads_2010_2019                           float64
# CI_hectads_2010_2019                            float64
# hybrid_propensity                               float64
# scaled_hybrid_propensity                        float64
# BOLD_link1                                       object
# BOLD_link2                                       object
# BOLD_link3                                       object
# GS_1C_pg                                        float64
# GS_2C_pg                                        float64
# GS_1C_Mbp                                       float64
# GS_2C_Mbp                                       float64
# from_BI_material                                 object
# data_source                                      object
# sporophytic_chromosome_number                    object
# infraspecific_variation_chrom_number             object
# other_reported_sporophytic_chromosome_number     object
# source_of_other_chrom_num                        object
# dtype: object

# %% [markdown]
# What does the data look like?

# %%
Dtofl.iloc[1]
# Out:
# kew_id                                                                                  325658-2
# unclear_species_marker                                                                       NaN
# extinct_species_marker                                                                       NaN
# taxon_name                                                    Abies amabilis Douglas ex J.Forbes
# taxon_name_binom                                                                  Abies amabilis
# authors                                                                      Douglas ex J.Forbes
# taxon_name_WCVP                                                                   Abies amabilis
# authors_WCVP                                                        (Douglas ex Loudon) J.Forbes
# order                                                                                    Pinales
# family                                                                                  Pinaceae
# genus                                                                                      Abies
# subgenus                                                                                     NaN
# section                                                                                      NaN
# subsection                                                                                   NaN
# series                                                                                       NaN
# species                                                                                 amabilis
# group                                                                                        NaN
# aggregate                                                                                    NaN
# members_of_agg.                                                                              NaN
# taxonomic_status                                                                        Accepted
# accepted_kew_id                                                                              NaN
# accepted_name                                                                                NaN
# accepted_authors                                                                             NaN
# imperfect_match_with_Stace_IV                                                                NaN
# WCVP_URL                                             https://wcvp.science.kew.org/taxon/325658-2
# POWO_URL                                        http://plantsoftheworldonline.org/taxon/325658-2
# IPNI_URL                                                             https://ipni.org/n/325658-2
# accepted_WCVP_URL                                                                            NaN
# StaceIV_nativity                                                                             NaN
# Atlas_nativity_viaALIENATT_PLANTATT                                                          NaN
# Stace_Crawley_nativity_aliens                                                                NaN
# SLA                                                                                    86.690769
# LDMC                                                                                         NaN
# seed_mass                                                                              42.277126
# leaf_area                                                                                    NaN
# mean_veg_height                                                                        50.148522
# max_veg_height                                                                              75.0
# L_PLANTATT                                                                                   NaN
# F_PLANTATT                                                                                   NaN
# R_PLANTATT                                                                                   NaN
# N_PLANTATT                                                                                   NaN
# S_PLANTATT                                                                                   NaN
# L_Doring                                                                                     NaN
# F_Doring                                                                                     NaN
# R_Doring                                                                                     NaN
# N_Doring                                                                                     NaN
# S_Doring                                                                                     NaN
# T_Doring                                                                                     NaN
# ECPE_CSR                                                                                     NaN
# predicted_CSR                                                                                NaN
# growth_form                                                                                 Tree
# succulence                                                                                   NaN
# life_form                                                                    phanerophyte / tree
# biome                                                                                        NaN
# origin                                                                               W N America
# TDWG_level_1_code                                                                              7
# GB_Man_hectads_post2000                                                                     11.0
# Ire_hectads_post2000                                                                         0.0
# CI_hectads_post2000                                                                          0.0
# GB_Man_hectads_1987_1999                                                                     7.0
# Ire_hectads_1987_1999                                                                        0.0
# CI_hectads_1987_1999                                                                         0.0
# GB_Man_hectads_2000_2009                                                                     5.0
# Ire_hectads_2000_2009                                                                        0.0
# CI_hectads_2000_2009                                                                         0.0
# GB_Man_hectads_2010_2019                                                                     8.0
# Ire_hectads_2010_2019                                                                        0.0
# CI_hectads_2010_2019                                                                         0.0
# hybrid_propensity                                                                            NaN
# scaled_hybrid_propensity                                                                     NaN
# BOLD_link1                                                                                   NaN
# BOLD_link2                                                                                   NaN
# BOLD_link3                                                                                   NaN
# GS_1C_pg                                                                                     NaN
# GS_2C_pg                                                                                     NaN
# GS_1C_Mbp                                                                                    NaN
# GS_2C_Mbp                                                                                    NaN
# from_BI_material                                                                             NaN
# data_source                                                                                  NaN
# sporophytic_chromosome_number                                                                NaN
# infraspecific_variation_chrom_number                                                         NaN
# other_reported_sporophytic_chromosome_number                                                 NaN
# source_of_other_chrom_num                                                                    NaN
# Name: 1, dtype: object

# %% [markdown]
# There is much more data in the other data set - root form, stomatal distribution etc...

# %% [markdown]
# Where is there missing data?

# %%
Dtofl.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3227 entries, 0 to 3226
# Data columns (total 83 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   kew_id                                        3227 non-null   object
#  1   unclear_species_marker                        575 non-null    object
#  2   extinct_species_marker                        18 non-null     object
#  3   taxon_name                                    3227 non-null   object
#  4   taxon_name_binom                              3227 non-null   object
#  5   authors                                       3227 non-null   object
#  6   taxon_name_WCVP                               3226 non-null   object
#  7   authors_WCVP                                  3226 non-null   object
#  8   order                                         3215 non-null   object
#  9   family                                        3227 non-null   object
#  10  genus                                         3227 non-null   object
#  11  subgenus                                      335 non-null    object
#  12  section                                       247 non-null    object
#  13  subsection                                    19 non-null     object
#  14  series                                        20 non-null     object
#  15  species                                       3227 non-null   object
#  16  group                                         4 non-null      object
#  17  aggregate                                     112 non-null    object
#  18  members_of_agg.                               12 non-null     object
#  19  taxonomic_status                              3226 non-null   object
#  20  accepted_kew_id                               324 non-null    object
#  21  accepted_name                                 324 non-null    object
#  22  accepted_authors                              316 non-null    object
#  23  imperfect_match_with_Stace_IV                 46 non-null     object
#  24  WCVP_URL                                      3226 non-null   object
#  25  POWO_URL                                      3227 non-null   object
#  26  IPNI_URL                                      3227 non-null   object
#  27  accepted_WCVP_URL                             324 non-null    object
#  28  StaceIV_nativity                              3158 non-null   object
#  29  Atlas_nativity_viaALIENATT_PLANTATT           2639 non-null   object
#  30  Stace_Crawley_nativity_aliens                 1534 non-null   object
#  31  SLA                                           1795 non-null   float64
#  32  LDMC                                          1514 non-null   float64
#  33  seed_mass                                     2174 non-null   float64
#  34  leaf_area                                     1645 non-null   float64
#  35  mean_veg_height                               2415 non-null   float64
#  36  max_veg_height                                2415 non-null   float64
#  37  L_PLANTATT                                    1779 non-null   float64
#  38  F_PLANTATT                                    1779 non-null   float64
#  39  R_PLANTATT                                    1779 non-null   float64
#  40  N_PLANTATT                                    1779 non-null   float64
#  41  S_PLANTATT                                    1779 non-null   float64
#  42  L_Doring                                      1930 non-null   float64
#  43  F_Doring                                      1892 non-null   float64
#  44  R_Doring                                      1770 non-null   float64
#  45  N_Doring                                      1866 non-null   float64
#  46  S_Doring                                      1940 non-null   float64
#  47  T_Doring                                      859 non-null    float64
#  48  ECPE_CSR                                      460 non-null    object
#  49  predicted_CSR                                 1441 non-null   object
#  50  growth_form                                   2754 non-null   object
#  51  succulence                                    16 non-null     object
#  52  life_form                                     3209 non-null   object
#  53  biome                                         1531 non-null   object
#  54  origin                                        1534 non-null   object
#  55  TDWG_level_1_code                             1487 non-null   object
#  56  GB_Man_hectads_post2000                       3130 non-null   float64
#  57  Ire_hectads_post2000                          3130 non-null   float64
#  58  CI_hectads_post2000                           3130 non-null   float64
#  59  GB_Man_hectads_1987_1999                      3130 non-null   float64
#  60  Ire_hectads_1987_1999                         3130 non-null   float64
#  61  CI_hectads_1987_1999                          3130 non-null   float64
#  62  GB_Man_hectads_2000_2009                      3130 non-null   float64
#  63  Ire_hectads_2000_2009                         3130 non-null   float64
#  64  CI_hectads_2000_2009                          3130 non-null   float64
#  65  GB_Man_hectads_2010_2019                      3130 non-null   float64
#  66  Ire_hectads_2010_2019                         3130 non-null   float64
#  67  CI_hectads_2010_2019                          3130 non-null   float64
#  68  hybrid_propensity                             642 non-null    float64
#  69  scaled_hybrid_propensity                      642 non-null    float64
#  70  BOLD_link1                                    1421 non-null   object
#  71  BOLD_link2                                    1330 non-null   object
#  72  BOLD_link3                                    1114 non-null   object
#  73  GS_1C_pg                                      2117 non-null   float64
#  74  GS_2C_pg                                      2117 non-null   float64
#  75  GS_1C_Mbp                                     2117 non-null   float64
#  76  GS_2C_Mbp                                     2117 non-null   float64
#  77  from_BI_material                              2085 non-null   object
#  78  data_source                                   2117 non-null   object
#  79  sporophytic_chromosome_number                 1410 non-null   object
#  80  infraspecific_variation_chrom_number          1410 non-null   object
#  81  other_reported_sporophytic_chromosome_number  1956 non-null   object
#  82  source_of_other_chrom_num                     1956 non-null   object
# dtypes: float64(35), object(48)
# memory usage: 2.0+ MB
# /var/folders/8k/5wbyxggs1q1856w27fftzywh0000gp/T/ipykernel_56403/2074808352.py:1: FutureWarning: null_counts is deprecated. Use show_counts instead
#   Dtofl.info(null_counts=True)

# %% [markdown]
# How many native, invasive etc....?

# %%
28  StaceIV_nativity                              3158 non-null   object 
 29  Atlas_nativity_viaALIENATT_PLANTATT           2639 non-null   object 
 30  Stace_Crawley_nativity_aliens                 1534 non-null   object

# %% [markdown]
# Most data for  StaceIV_nativity

# %%
Dtofl.StaceIV_nativity.value_counts()
# Out:
# N                1407
# Neo-natd          936
# Neo-surv          309
# Neo-casual        260
# Arch-denizen       80
# ?N                 61
# Arch-colonist      61
# Arch-cultd         40
# Neonative           4
# Name: StaceIV_nativity, dtype: int64

# %%
Dtofl.Atlas_nativity_viaALIENATT_PLANTATT.value_counts()
# Out:
# N                   1172
# AN                  1131
# AR                   136
# AC                   103
# NE                    42
# NA (unclear)          41
# AN or AC?              5
# AN?                    3
# AR/N                   1
# AR/AN                  1
# AC (or AN?)            1
# AN (or AC?)            1
# AC change to AN?       1
# AN change to AC?       1
# Name: Atlas_nativity_viaALIENATT_PLANTATT, dtype: int64

# %%
Dtofl.Stace_Crawley_nativity_aliens.value_counts()
# Out:
# Neo-natd         857
# Neo-surv         236
# Neo-casual       227
# Arch-denizen      71
# Neo               55
# Arch-colonist     51
# Arch-cultd        36
# Arch               1
# Name: Stace_Crawley_nativity_aliens, dtype: int64

# %% [markdown]
# Read in old database

# %%
Flora = pd.read_csv('UKFlora_species.csv', sep=",", encoding='latin-1')
# Out:
# /Users/ckidner/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (9,32,53,65,142,154,170,184,185,213,215,232) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
Flora.head(2)
# Out:
#                 AccSpeciesName APG IV level 1 APG IV level 2 APG IV level 3  \
# 0       ACAENA NOVAE-ZELANDIAE       Eudicots  Core Eudicots    Superrosids
# 1  ACAENA NOVAE-ZELANDIAE Kirk            NaN            NaN            NaN
#
#   APG IV level 4 APG IV level 5  Actual EvapoTranspiration  \
# 0         Rosids         Fabids                        NaN
# 1            NaN            NaN                        NaN
#
#   After-ripening requirement  Altitude Altitude (maximum recorded)  \
# 0                        NaN      11.0                         NaN
# 1                        NaN       NaN                         NaN
#
#    Altitude (minimum recorded)  Altitude (typical minimum)  \
# 0                          0.0                         NaN
# 1                          NaN                         NaN
#
#    Annual precipitation Annual seed dispersal Appendages on dispersal unit  \
# 0                 831.0                   NaN                        hooks
# 1                   NaN                   NaN                          NaN
#
#    Average annual relative humidity  \
# 0                              81.0
# 1                               NaN
#
#    Average number of ground frost days per year (sum) (FRS)  \
# 0                                              175.1
# 1                                                NaN
#
#    British distribution (post 1949 records)              Carnivory  \
# 0                                       NaN  does not kill insects
# 1                                       NaN                    NaN
#
#    Change Index  Chromosome cDNA content Chromosome number  Chromosome ploidy  \
# 0           NaN                     0.65                42                NaN
# 1           NaN                      NaN               NaN                NaN
#
#   Cleistogamy                                  Clonality  Cloud cover  \
# 0         NaN  Extensively creeping and rooting at nodes         72.6
# 1         NaN                                        NaN          NaN
#
#   Comments, notes, methods              Dataset (1)          Dataset (2)  \
# 0                      NaN  Royer et al, 2005, 2012  Peppe et al. (2011)
# 1                      NaN                      NaN                  NaN
#
#               Dichogamy Dicliny (monoeceous, dioecious, hermaphrodite)  \
# 0  markedly protogynous                                  hermaphrodite
# 1                   NaN                                            NaN
#
#   Dispersal syndrome (agent) Dispersal unit (dispersule / diaspore) length  \
# 0         carried by mammals                                           NaN
# 1                        NaN                                           NaN
#
#    EW Index  Ecosystem rooting depth  Ellenberg indicator value: Light  \
# 0      3.57                      1.3                               8.0
# 1       NaN                      NaN                               NaN
#
#    Ellenberg indicator value: Moisture  \
# 0                                  NaN
# 1                                  NaN
#
#    Ellenberg indicator value: Salt tolerance  \
# 0                                        NaN
# 1                                        NaN
#
#    Ellenberg indicator value: nitrogen  \
# 0                                  3.0
# 1                                  NaN
#
#    Ellenberg indicator value: pH (reaction)  End of flowering Epoch Exposure  \
# 0                                       NaN               7.0   NaN      NaN
# 1                                       NaN               NaN   NaN      NaN
#
#      Family  Fern  and moss spore width (diameter)   Fertilization  \
# 0  Rosaceae                                    NaN  cross and self
# 1       NaN                                    NaN             NaN
#
#   Fine root diameter  First historical record: 1. date  \
# 0                NaN                            1901.0
# 1                NaN                               NaN
#
#   First historical record: 2. site Flow  Flower pollen ovule ratio  \
# 0                    Yarner, Devon  NaN                        NaN
# 1                              NaN  NaN                        NaN
#
#    Flowering periode: peak month Fossil record: 1. earliest record  \
# 0                            NaN                               NaN
# 1                            NaN                               NaN
#
#   Fossil record: 2. earliest postglacial record  \
# 0                                           NaN
# 1                                           NaN
#
#    Fraction of absorbed photosynthetic active radiation (FAPAR) of the site  \
# 0                                           0.666167
# 1                                                NaN
#
#    GPP of the site Genera growth form Germination requirements 1. chilling  \
# 0              NaN                  S                              partial
# 1              NaN                NaN                                  NaN
#
#   Germination requirements 2. light  \
# 0                          absolute
# 1                               NaN
#
#   Germination requirements 3. temperature fluctuation Germination type  \
# 0                                                NaN           epigeal
# 1                                                NaN               NaN
#
#   Habitat / plot description Heteromorphy Heterophylly  \
# 0                        NaN          NaN          NaN
# 1                        NaN          NaN          NaN
#
#    Identifier within contributed dataset (ID) Inbreeding  \
# 0                                      2601.0        NaN
# 1                                         NaN        NaN
#
#   Incompatibility systems Intensity of mycorrhizal infection  \
# 0                     NaN               normally mycorrhizal
# 1                     NaN                                NaN
#
#    January mean temperature  July mean temperature  Latitude  \
# 0                       3.8                   15.2     -40.5
# 1                       NaN                    NaN       NaN
#
#    Leaf Relative water content (water content / water content at saturation)  \
# 0                                                NaN
# 1                                                NaN
#
#    Leaf Water content (molar) per leaf dry mass (WCd)  \
# 0                                                NaN
# 1                                                NaN
#
#    Leaf Water content saturating (molar) (WCs)  \
# 0                                          NaN
# 1                                          NaN
#
#    Leaf Water content total (molar) (WCt)  Leaf area index of the site (LAI)  \
# 0                                     NaN                           2.689583
# 1                                     NaN                                NaN
#
#   Leaf area: in case of compound leaves undefined if leaf or leaflet; undefined if petiole and rhachis in- or excluded  \
# 0                                                NaN
# 1                                                NaN
#
#    Leaf carbon content per area  Leaf carbon content per dry mass  \
# 0                           NaN                               NaN
# 1                           NaN                               NaN
#
#    Leaf carbon/nitrogen (C/N) ratio  Leaf carotenoid content per dry mass  \
# 0                               NaN                                   NaN
# 1                               NaN                                   NaN
#
#    Leaf chlorophyll a content per dry mass  \
# 0                                      NaN
# 1                                      NaN
#
#    Leaf chlorophyll a+b content per area  Leaf chlorophyll a/b ratio  \
# 0                                    NaN                         NaN
# 1                                    NaN                         NaN
#
#    Leaf chlorophyll b content per dry mass  \
# 0                                      NaN
# 1                                      NaN
#
#    Leaf chlorophyll content (a+b) per dry mass Leaf compoundness  \
# 0                                          NaN          compound
# 1                                          NaN               NaN
#
#    Leaf dry matter content per leaf water-saturated mass (LDMC)  \
# 0                                                NaN
# 1                                                NaN
#
#   Leaf lamina thickness Leaf lifespan (longevity, retention time, LL)  \
# 0                   NaN                                           NaN
# 1                   NaN                                           NaN
#
#    Leaf nitrogen content per area (Narea)  \
# 0                                     NaN
# 1                                     NaN
#
#   Leaf nitrogen content per dry mass (Nmass)  Leaf petiole length  \
# 0                                        NaN                  NaN
# 1                                        NaN                  NaN
#
#   Leaf phenology type  Leaf phosphorus content per area (Parea)  \
# 0           evergreen                                       NaN
# 1                 NaN                                       NaN
#
#   Leaf phosphorus content per dry mass (Pmass) Leaf position  \
# 0                                          NaN           NaN
# 1                                          NaN           NaN
#
#    Leaf respiration per area at leaf temperature  \
# 0                                            NaN
# 1                                            NaN
#
#    Leaf respiration per dry mass Leaf shape: 2. outline  \
# 0                            NaN                toothed
# 1                            NaN                    NaN
#
#   Leaf shape: 3. pointed/round Leaf shape: 4. length versus breadth  \
# 0                      rounded             >3 times as long as wide
# 1                          NaN                                  NaN
#
#   Leaf shape: 5. leaf base Leaf shape: 6. leaf petiole type  Leaf thickness  \
# 0                 truncate                        petiolate             NaN
# 1                      NaN                              NaN             NaN
#
#    Leaf tissue density  Leaf transpiration (molar) per dry mass  \
# 0                  NaN                                      NaN
# 1                  NaN                                      NaN
#
#    Leaf transpiration rate per dry mass (daytime)  \
# 0                                             NaN
# 1                                             NaN
#
#    Leaf water content per leaf dry mass  \
# 0                                   NaN
# 1                                   NaN
#
#    Leaf water content per leaf water-saturated mass (LWC, 1-LDMC)  \
# 0                                                NaN
# 1                                                NaN
#
#    Leaf water content saturating  Leaf water content total  \
# 0                            NaN                       NaN
# 1                            NaN                       NaN
#
#    Leaf water saturation deficit  Length of growing season (LGP)  \
# 0                            NaN                            15.0
# 1                            NaN                             NaN
#
#   Location / Site Name Location Country  Longitude Major Phylogenetic Group  \
# 0       Foxton Estuary      New Zealand      175.2              Angiosperms
# 1                  NaN              NaN        NaN                      NaN
#
#    Maximum Green Vegetation Fraction Maximum depth of leaves in the canopy  \
# 0                                NaN                                   NaN
# 1                                NaN                                   NaN
#
#    Maximum temperature at which 50% seeds germinate  \
# 0                                               NaN
# 1                                               NaN
#
#    Maximum temperature of germination  \
# 0                                 NaN
# 1                                 NaN
#
#    Mean annual sum of potential evapotranspiration (PET)  \
# 0                                                NaN
# 1                                                NaN
#
#    Mean annual temperature (MAT)  \
# 0                            NaN
# 1                            NaN
#
#    Mean clear-sky surface radiation budget from ERBE global: Global shortwave radiation budget data derived from 5 Years of ERBE measurements  \
# 0                                         218.214081
# 1                                                NaN
#
#    Mean cloud forcing surface radiation budget from ERBE global: Global shortwave radiation budget data derived from 5 Years of ERBE measurements  \
# 0                                         -62.396999
# 1                                                NaN
#
#    Mean cloud surface radiation budget from ERBE global: Global shortwave radiation budget data derived from 5 Years of ERBE measurements  \
# 0                                         155.817245
# 1                                                NaN
#
#    Mean number of wet days per year  \
# 0                             185.4
# 1                               NaN
#
#    Mean sum of annual precipitation (PPT / MAP / TAP)  Mid Point  \
# 0                                                NaN         NaN
# 1                                                NaN         NaN
#
#    Minimum temperature at which 50% seeds germinate  \
# 0                                               NaN
# 1                                               NaN
#
#    Minimum temperature germination Mono/poly carpic Mycorrhizal type  \
# 0                              NaN              NaN       arbuscular
# 1                              NaN              NaN              NaN
#
#    NDVI of the site  NPP of the site (2)  \
# 0          0.775755          1110.599976
# 1               NaN                  NaN
#
#    Net primary productivity of the site (NPP) Normal method of propagation  \
# 0                                         NaN                          NaN
# 1                                         NaN                          NaN
#
#   Northern Limit in Britain Northern Limit in Europe  \
# 0                        No                      NaN
# 1                       NaN                      NaN
#
#    Number of European countries in which native  \
# 0                                           NaN
# 1                                           NaN
#
#   Nutrition (autotroph versus heterotroph)  \
# 0                              autotrophic
# 1                                      NaN
#
#   Onset of flowering (first flowering date, beginning of flowering period)  \
# 0                                                  6
# 1                                                NaN
#
#      Order  Photoperiodism: threshold value (h) Photoperiodism: type  \
# 0  Rosales                                  NaN                  NaN
# 1      NaN                                  NaN                  NaN
#
#    Photosynthesis per leaf area at leaf temperature (A_area)  \
# 0                                                NaN
# 1                                                NaN
#
#    Photosynthesis per leaf dry mass (Amass) Physical defences on buds  \
# 0                                       NaN                       NaN
# 1                                       NaN                       NaN
#
#   Physical defences on flowers/fruits Physical defences on leaves  \
# 0                              spines                  soft hairs
# 1                                 NaN                         NaN
#
#   Physical defences on stems  \
# 0                        NaN
# 1                        NaN
#
#   Plant age at first flowering (primary juvenil period) Plant growth form  \
# 0                                                NaN                    H
# 1                                                NaN                  NaN
#
#   Plant height (unspecified if vegetative or reproductive)  \
# 0                                                2.0
# 1                                                NaN
#
#   Plant life form (Raunkiaer life form) Plant photosynthetic pathway  \
# 0                           chamaephyte                           C3
# 1                                   NaN                          NaN
#
#    Plant relative growth rate (RGR) Pollen viability  \
# 0                               NaN              NaN
# 1                               NaN              NaN
#
#   Pollen: 1. mono/di-morphic  Pollen: 2. diameter (um)  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
#
#   Pollination syndrome (pollen vector)  \
# 0                                  NaN
# 1                                  NaN
#
#    Precipitation Seasonality (Coefficient of Variation)  \
# 0                                                NaN
# 1                                                NaN
#
#    Precipitation of Coldest Quarter  Precipitation of Driest Month  \
# 0                               NaN                            NaN
# 1                               NaN                            NaN
#
#    Precipitation of Driest Quarter  Precipitation of Warmest Quarter  \
# 0                              NaN                               NaN
# 1                              NaN                               NaN
#
#    Precipitation of Wettest Month  Precipitation of Wettest Quarter  \
# 0                             NaN                               NaN
# 1                             NaN                               NaN
#
#    Priestley-Taylor alpha coefficient  \
# 0                                 NaN
# 1                                 NaN
#
#   Range: 1. european countries where native  \
# 0                                       NaN
# 1                                       NaN
#
#   Range: 2. european countries where introduced  \
# 0                                           NaN
# 1                                           NaN
#
#   Range: 3. continents where native Range: 4. continents where introduced  \
# 0                       Australasia                                Europe
# 1                               NaN                                   NaN
#
#                                   Reference / source  \
# 0  Gynn EG, Richards AJ 1985 Journal of Ecology 7...
# 1                                                NaN
#
#   Root architecture / root system / root habit Root hair length Root hairs  \
# 0                                          NaN              NaN        NaN
# 1                                          NaN              NaN        NaN
#
#   Root persistence (livespan, longevity) Root rooting depth   \
# 0                                    NaN                0-10
# 1                                    NaN                 NaN
#
#    SLA: undefined if petiole in- or excluded  SN Index Salinity Tolerance  \
# 0                                  78.616352      2.85                NaN
# 1                                        NaN       NaN                NaN
#
#   Seed / ovule ratio Seed dry mass Seed length (largest dimension length)  \
# 0                NaN          0.92                                    2.0
# 1                NaN           NaN                                    NaN
#
#   Seed number per plant Seed shedding season (time of seed dispersal)  \
# 0            1000-10000                                        autumn
# 1                   NaN                                           NaN
#
#   Seed viability Seedbank density Seedbank longevity Seedbank type  \
# 0           high              NaN                NaN           NaN
# 1            NaN              NaN                NaN           NaN
#
#   Seeds per flower  Soil C content per ground area  \
# 0                1                          6.6873
# 1              NaN                             NaN
#
#    Soil N content per ground area  Soil bulk density  Soil field capacity  \
# 0                      556.625977            1.49266           249.729996
# 1                             NaN                NaN                  NaN
#
#    Soil ph  \
# 0    5.372
# 1      NaN
#
#    Soil plant available water capacity of rooting zone (derived from remote sensing) 1  \
# 0                                         225.699997
# 1                                                NaN
#
#    Soil plant available water capacity of rooting zone (derived from remote sensing) 2  \
# 0                                         262.100006
# 1                                                NaN
#
#    Soil profile available water capacity  Soil thermal capacity  \
# 0                             174.516998                1.22082
# 1                                    NaN                    NaN
#
#    Soil water content (SWC)  Soil wilting point  \
# 0                       NaN           75.212303
# 1                       NaN                 NaN
#
#    Solar radiation (kJ m-2 day-1) Southern Limit in Europe  \
# 0                             NaN                      NaN
# 1                             NaN                      NaN
#
#   Species conservation status Species continentality Species eastern limit  \
# 0                         NaN        Not continental          Hyperoceanic
# 1                         NaN                    NaN                   NaN
#
#   Species nutrient requirements (in soil)  \
# 0                                     NaN
# 1                                     NaN
#
#   Species nutrient requirements (in water)  \
# 0                                      NaN
# 1                                      NaN
#
#   Species occurance dynamics (increasing / decreasing)  \
# 0                                                NaN
# 1                                                NaN
#
#                   Species origin  \
# 0                            NaN
# 1  Archeophyt in British Islands
#
#   Species pH requirement ( soil, extreme minimum)  \
# 0                                             5.5
# 1                                             NaN
#
#    Species pH requirement ( soil, typical minimum)  \
# 0                                              NaN
# 1                                              NaN
#
#   Species pH requirement (soil, extreme maximum)  \
# 0                                            8.6
# 1                                            NaN
#
#    Species pH requirement (soil, typical maximum)  \
# 0                                             NaN
# 1                                             NaN
#
#    Species pH requirement (water, extreme maximum)  \
# 0                                              NaN
# 1                                              NaN
#
#    Species pH requirement (water, extreme minimum)  \
# 0                                              NaN
# 1                                              NaN
#
#    Species pH requirement (water, typical maximum)  \
# 0                                              NaN
# 1                                              NaN
#
#    Species pH requirement (water, typical minimum) Species rarity status  \
# 0                                              NaN                   NaN
# 1                                              NaN                   NaN
#
#   Species soil moisture requirements (drainage)  \
# 0                                 free-draining
# 1                                           NaN
#
#   Species soil moisture requirements (supply)  \
# 0                                         NaN
# 1                                         NaN
#
#   Species soil moisture requirements (water table)  \
# 0                                              NaN
# 1                                              NaN
#
#   Species status (nativity at growth location)  \
# 0                                  naturalised
# 1                                          NaN
#
#   Species synonyms (alternative name)  \
# 0                                 NaN
# 1                                 NaN
#
#   Spread (plant height versus plant width relationshp)) Stem longevity  \
# 0                                     height < width               NaN
# 1                                                NaN               NaN
#
#   Stem self-supporting  Stomata density Stomata density on lower surface  \
# 0           procumbent              NaN                              NaN
# 1                  NaN              NaN                              NaN
#
#   Stomata density on upper surface Stomata distribution (surfaces present)  \
# 0                              NaN                                     NaN
# 1                              NaN                                     NaN
#
#       Subclass  Temperature sum of growing degree days (GDD)  \
# 0  Magnoliidae                                        2452.0
# 1          NaN                                           NaN
#
#    Temperature: Annual Range  Temperature: Isothermality (BIO2/BIO7) (* 100)  \
# 0                        NaN                                             NaN
# 1                        NaN                                             NaN
#
#    Temperature: Max Temperature of Warmest Month  \
# 0                                            NaN
# 1                                            NaN
#
#    Temperature: Mean Diurnal Range (Mean of monthly (max temp - min temp))  \
# 0                                                NaN
# 1                                                NaN
#
#    Temperature: Mean Temperature of Coldest Quarter  \
# 0                                               NaN
# 1                                               NaN
#
#    Temperature: Mean Temperature of Driest Quarter  \
# 0                                              NaN
# 1                                              NaN
#
#    Temperature: Mean Temperature of Warmest Quarter  \
# 0                                               NaN
# 1                                               NaN
#
#    Temperature: Mean Temperature of Wettest Quarter  \
# 0                                               NaN
# 1                                               NaN
#
#    Temperature: Min Temperature of Coldest Month  \
# 0                                            NaN
# 1                                            NaN
#
#    Temperature: Seasonality (standard deviation *100)  \
# 0                                                NaN
# 1                                                NaN
#
#    Terrestrial chlorophyll index of the site  \
# 0                                   3.180153
# 1                                        NaN
#
#   Time (season) of germination (seedling emergence)  \
# 0                                            spring
# 1                                               NaN
#
#   Tolerance (resistance) to heavy metals Tolerance to drought  \
# 0                                    NaN                  NaN
# 1                                    NaN                  NaN
#
#   Tolerance to frost (non-woody tissue) Tolerance to frost (seedlings)  \
# 0                             sensitive                            NaN
# 1                                   NaN                            NaN
#
#   Tolerance to grazing Tolerance to shade  \
# 0                  NaN               none
# 1                  NaN                NaN
#
#   Typical abundance where naturally occurring Vegetation type / Biome  \
# 0                                         NaN                       4
# 1                                         NaN                     NaN
#
#   Vegetative regeneration / reproduction (clonal spread)  \
# 0                                            stolons
# 1                                                NaN
#
#   Vegetative reproduction: pattern forming  Water vapor pressure (kPa)  \
# 0                                      NaN                         NaN
# 1                                      NaN                         NaN
#
#    Wetness/Humidity/Aridity of area where samples were taken  \
# 0                                                0.0
# 1                                                NaN
#
#    Wind speed (m s-1) Woodiness
# 0                 NaN     woody
# 1                 NaN       NaN

# %%
Dtofl.head(2)
# Out:
#        kew_id unclear_species_marker extinct_species_marker  \
# 0  60468511-2                    NaN                    NaN
# 1    325658-2                    NaN                    NaN
#
#                            taxon_name taxon_name_binom              authors  \
# 0                    Abies alba Mill.       Abies alba                Mill.
# 1  Abies amabilis Douglas ex J.Forbes   Abies amabilis  Douglas ex J.Forbes
#
#   taxon_name_WCVP                  authors_WCVP    order    family  genus  \
# 0      Abies alba                         Mill.  Pinales  Pinaceae  Abies
# 1  Abies amabilis  (Douglas ex Loudon) J.Forbes  Pinales  Pinaceae  Abies
#
#   subgenus section subsection series   species group aggregate  \
# 0      NaN     NaN        NaN    NaN      alba   NaN       NaN
# 1      NaN     NaN        NaN    NaN  amabilis   NaN       NaN
#
#   members_of_agg. taxonomic_status accepted_kew_id accepted_name  \
# 0             NaN         Accepted             NaN           NaN
# 1             NaN         Accepted             NaN           NaN
#
#   accepted_authors imperfect_match_with_Stace_IV  \
# 0              NaN                           NaN
# 1              NaN                           NaN
#
#                                         WCVP_URL  \
# 0  https://wcvp.science.kew.org/taxon/60468511-2
# 1    https://wcvp.science.kew.org/taxon/325658-2
#
#                                             POWO_URL  \
# 0  http://plantsoftheworldonline.org/taxon/604685...
# 1   http://plantsoftheworldonline.org/taxon/325658-2
#
#                         IPNI_URL accepted_WCVP_URL StaceIV_nativity  \
# 0  https://ipni.org/n/60468511-2               NaN         Neo-natd
# 1    https://ipni.org/n/325658-2               NaN              NaN
#
#   Atlas_nativity_viaALIENATT_PLANTATT Stace_Crawley_nativity_aliens  \
# 0                                  AN                           Neo
# 1                                 NaN                           NaN
#
#          SLA      LDMC  seed_mass   leaf_area  mean_veg_height  \
# 0   7.698508  0.529816  65.612834  255.029158        46.843893
# 1  86.690769       NaN  42.277126         NaN        50.148522
#
#    max_veg_height  L_PLANTATT  F_PLANTATT  R_PLANTATT  N_PLANTATT  S_PLANTATT  \
# 0            68.0         NaN         NaN         NaN         NaN         NaN
# 1            75.0         NaN         NaN         NaN         NaN         NaN
#
#    L_Doring  F_Doring  R_Doring  N_Doring  S_Doring  T_Doring ECPE_CSR  \
# 0       3.0       NaN       NaN       NaN       0.0       5.0      NaN
# 1       NaN       NaN       NaN       NaN       NaN       NaN      NaN
#
#   predicted_CSR growth_form succulence            life_form biome  \
# 0             S        Tree        NaN  phanerophyte / tree   NaN
# 1           NaN        Tree        NaN  phanerophyte / tree   NaN
#
#                   origin TDWG_level_1_code  GB_Man_hectads_post2000  \
# 0  mountains in C Europe                 1                    382.0
# 1            W N America                 7                     11.0
#
#    Ire_hectads_post2000  CI_hectads_post2000  GB_Man_hectads_1987_1999  \
# 0                 230.0                  0.0                     230.0
# 1                   0.0                  0.0                       7.0
#
#    Ire_hectads_1987_1999  CI_hectads_1987_1999  GB_Man_hectads_2000_2009  \
# 0                   28.0                   0.0                     120.0
# 1                    0.0                   0.0                       5.0
#
#    Ire_hectads_2000_2009  CI_hectads_2000_2009  GB_Man_hectads_2010_2019  \
# 0                  179.0                   0.0                     303.0
# 1                    0.0                   0.0                       8.0
#
#    Ire_hectads_2010_2019  CI_hectads_2010_2019  hybrid_propensity  \
# 0                   89.0                   0.0                NaN
# 1                    0.0                   0.0                NaN
#
#    scaled_hybrid_propensity BOLD_link1 BOLD_link2 BOLD_link3  GS_1C_pg  \
# 0                       NaN        NaN        NaN        NaN     17.27
# 1                       NaN        NaN        NaN        NaN       NaN
#
#    GS_2C_pg  GS_1C_Mbp  GS_2C_Mbp from_BI_material         data_source  \
# 0     34.54   16891.68   33783.36                n  marda et al. 2019
# 1       NaN        NaN        NaN              NaN                 NaN
#
#   sporophytic_chromosome_number infraspecific_variation_chrom_number  \
# 0                           NaN                                  NaN
# 1                           NaN                                  NaN
#
#   other_reported_sporophytic_chromosome_number  \
# 0                                           24
# 1                                          NaN
#
#              source_of_other_chrom_num
# 0  marda et al. 2019, Zonneveld, 2019
# 1                                  NaN

# %%
Flora.shape
# Out:
# (3031, 262)

# %%
Dtofl.shape
# Out:
# (3227, 83)

# %% [markdown]
# Can I transform the taxon_name_binom to  AccSpeciesName and merge?
# Need to make caps
# Need to split into 2 columns (losing the authorship detail)

# %%
Flora[['Genus', 'Species']] = Flora['AccSpeciesName'].str.split(' ', 1, expand=True)

# %%
Dtofl[['Genus', 'Species']] = Dtofl['taxon_name_binom'].str.split(' ', 1, expand=True)

# %%
Flora.head(2)
# Out:
#                 AccSpeciesName APG IV level 1 APG IV level 2 APG IV level 3  \
# 0       ACAENA NOVAE-ZELANDIAE       Eudicots  Core Eudicots    Superrosids
# 1  ACAENA NOVAE-ZELANDIAE Kirk            NaN            NaN            NaN
#
#   APG IV level 4 APG IV level 5  Actual EvapoTranspiration  \
# 0         Rosids         Fabids                        NaN
# 1            NaN            NaN                        NaN
#
#   After-ripening requirement  Altitude Altitude (maximum recorded)  \
# 0                        NaN      11.0                         NaN
# 1                        NaN       NaN                         NaN
#
#    Altitude (minimum recorded)  Altitude (typical minimum)  \
# 0                          0.0                         NaN
# 1                          NaN                         NaN
#
#    Annual precipitation Annual seed dispersal Appendages on dispersal unit  \
# 0                 831.0                   NaN                        hooks
# 1                   NaN                   NaN                          NaN
#
#    Average annual relative humidity  \
# 0                              81.0
# 1                               NaN
#
#    Average number of ground frost days per year (sum) (FRS)  \
# 0                                              175.1
# 1                                                NaN
#
#    British distribution (post 1949 records)              Carnivory  \
# 0                                       NaN  does not kill insects
# 1                                       NaN                    NaN
#
#    Change Index  Chromosome cDNA content Chromosome number  Chromosome ploidy  \
# 0           NaN                     0.65                42                NaN
# 1           NaN                      NaN               NaN                NaN
#
#   Cleistogamy                                  Clonality  Cloud cover  \
# 0         NaN  Extensively creeping and rooting at nodes         72.6
# 1         NaN                                        NaN          NaN
#
#   Comments, notes, methods              Dataset (1)          Dataset (2)  \
# 0                      NaN  Royer et al, 2005, 2012  Peppe et al. (2011)
# 1                      NaN                      NaN                  NaN
#
#               Dichogamy Dicliny (monoeceous, dioecious, hermaphrodite)  \
# 0  markedly protogynous                                  hermaphrodite
# 1                   NaN                                            NaN
#
#   Dispersal syndrome (agent) Dispersal unit (dispersule / diaspore) length  \
# 0         carried by mammals                                           NaN
# 1                        NaN                                           NaN
#
#    EW Index  Ecosystem rooting depth  Ellenberg indicator value: Light  \
# 0      3.57                      1.3                               8.0
# 1       NaN                      NaN                               NaN
#
#    Ellenberg indicator value: Moisture  \
# 0                                  NaN
# 1                                  NaN
#
#    Ellenberg indicator value: Salt tolerance  \
# 0                                        NaN
# 1                                        NaN
#
#    Ellenberg indicator value: nitrogen  \
# 0                                  3.0
# 1                                  NaN
#
#    Ellenberg indicator value: pH (reaction)  End of flowering Epoch Exposure  \
# 0                                       NaN               7.0   NaN      NaN
# 1                                       NaN               NaN   NaN      NaN
#
#      Family  Fern  and moss spore width (diameter)   Fertilization  \
# 0  Rosaceae                                    NaN  cross and self
# 1       NaN                                    NaN             NaN
#
#   Fine root diameter  First historical record: 1. date  \
# 0                NaN                            1901.0
# 1                NaN                               NaN
#
#   First historical record: 2. site Flow  Flower pollen ovule ratio  \
# 0                    Yarner, Devon  NaN                        NaN
# 1                              NaN  NaN                        NaN
#
#    Flowering periode: peak month Fossil record: 1. earliest record  \
# 0                            NaN                               NaN
# 1                            NaN                               NaN
#
#   Fossil record: 2. earliest postglacial record  \
# 0                                           NaN
# 1                                           NaN
#
#    Fraction of absorbed photosynthetic active radiation (FAPAR) of the site  \
# 0                                           0.666167
# 1                                                NaN
#
#    GPP of the site Genera growth form Germination requirements 1. chilling  \
# 0              NaN                  S                              partial
# 1              NaN                NaN                                  NaN
#
#   Germination requirements 2. light  \
# 0                          absolute
# 1                               NaN
#
#   Germination requirements 3. temperature fluctuation Germination type  \
# 0                                                NaN           epigeal
# 1                                                NaN               NaN
#
#   Habitat / plot description Heteromorphy Heterophylly  \
# 0                        NaN          NaN          NaN
# 1                        NaN          NaN          NaN
#
#    Identifier within contributed dataset (ID) Inbreeding  \
# 0                                      2601.0        NaN
# 1                                         NaN        NaN
#
#   Incompatibility systems Intensity of mycorrhizal infection  \
# 0                     NaN               normally mycorrhizal
# 1                     NaN                                NaN
#
#    January mean temperature  July mean temperature  Latitude  \
# 0                       3.8                   15.2     -40.5
# 1                       NaN                    NaN       NaN
#
#    Leaf Relative water content (water content / water content at saturation)  \
# 0                                                NaN
# 1                                                NaN
#
#    Leaf Water content (molar) per leaf dry mass (WCd)  \
# 0                                                NaN
# 1                                                NaN
#
#    Leaf Water content saturating (molar) (WCs)  \
# 0                                          NaN
# 1                                          NaN
#
#    Leaf Water content total (molar) (WCt)  Leaf area index of the site (LAI)  \
# 0                                     NaN                           2.689583
# 1                                     NaN                                NaN
#
#   Leaf area: in case of compound leaves undefined if leaf or leaflet; undefined if petiole and rhachis in- or excluded  \
# 0                                                NaN
# 1                                                NaN
#
#    Leaf carbon content per area  Leaf carbon content per dry mass  \
# 0                           NaN                               NaN
# 1                           NaN                               NaN
#
#    Leaf carbon/nitrogen (C/N) ratio  Leaf carotenoid content per dry mass  \
# 0                               NaN                                   NaN
# 1                               NaN                                   NaN
#
#    Leaf chlorophyll a content per dry mass  \
# 0                                      NaN
# 1                                      NaN
#
#    Leaf chlorophyll a+b content per area  Leaf chlorophyll a/b ratio  \
# 0                                    NaN                         NaN
# 1                                    NaN                         NaN
#
#    Leaf chlorophyll b content per dry mass  \
# 0                                      NaN
# 1                                      NaN
#
#    Leaf chlorophyll content (a+b) per dry mass Leaf compoundness  \
# 0                                          NaN          compound
# 1                                          NaN               NaN
#
#    Leaf dry matter content per leaf water-saturated mass (LDMC)  \
# 0                                                NaN
# 1                                                NaN
#
#   Leaf lamina thickness Leaf lifespan (longevity, retention time, LL)  \
# 0                   NaN                                           NaN
# 1                   NaN                                           NaN
#
#    Leaf nitrogen content per area (Narea)  \
# 0                                     NaN
# 1                                     NaN
#
#   Leaf nitrogen content per dry mass (Nmass)  Leaf petiole length  \
# 0                                        NaN                  NaN
# 1                                        NaN                  NaN
#
#   Leaf phenology type  Leaf phosphorus content per area (Parea)  \
# 0           evergreen                                       NaN
# 1                 NaN                                       NaN
#
#   Leaf phosphorus content per dry mass (Pmass) Leaf position  \
# 0                                          NaN           NaN
# 1                                          NaN           NaN
#
#    Leaf respiration per area at leaf temperature  \
# 0                                            NaN
# 1                                            NaN
#
#    Leaf respiration per dry mass Leaf shape: 2. outline  \
# 0                            NaN                toothed
# 1                            NaN                    NaN
#
#   Leaf shape: 3. pointed/round Leaf shape: 4. length versus breadth  \
# 0                      rounded             >3 times as long as wide
# 1                          NaN                                  NaN
#
#   Leaf shape: 5. leaf base Leaf shape: 6. leaf petiole type  Leaf thickness  \
# 0                 truncate                        petiolate             NaN
# 1                      NaN                              NaN             NaN
#
#    Leaf tissue density  Leaf transpiration (molar) per dry mass  \
# 0                  NaN                                      NaN
# 1                  NaN                                      NaN
#
#    Leaf transpiration rate per dry mass (daytime)  \
# 0                                             NaN
# 1                                             NaN
#
#    Leaf water content per leaf dry mass  \
# 0                                   NaN
# 1                                   NaN
#
#    Leaf water content per leaf water-saturated mass (LWC, 1-LDMC)  \
# 0                                                NaN
# 1                                                NaN
#
#    Leaf water content saturating  Leaf water content total  \
# 0                            NaN                       NaN
# 1                            NaN                       NaN
#
#    Leaf water saturation deficit  Length of growing season (LGP)  \
# 0                            NaN                            15.0
# 1                            NaN                             NaN
#
#   Location / Site Name Location Country  Longitude Major Phylogenetic Group  \
# 0       Foxton Estuary      New Zealand      175.2              Angiosperms
# 1                  NaN              NaN        NaN                      NaN
#
#    Maximum Green Vegetation Fraction Maximum depth of leaves in the canopy  \
# 0                                NaN                                   NaN
# 1                                NaN                                   NaN
#
#    Maximum temperature at which 50% seeds germinate  \
# 0                                               NaN
# 1                                               NaN
#
#    Maximum temperature of germination  \
# 0                                 NaN
# 1                                 NaN
#
#    Mean annual sum of potential evapotranspiration (PET)  \
# 0                                                NaN
# 1                                                NaN
#
#    Mean annual temperature (MAT)  \
# 0                            NaN
# 1                            NaN
#
#    Mean clear-sky surface radiation budget from ERBE global: Global shortwave radiation budget data derived from 5 Years of ERBE measurements  \
# 0                                         218.214081
# 1                                                NaN
#
#    Mean cloud forcing surface radiation budget from ERBE global: Global shortwave radiation budget data derived from 5 Years of ERBE measurements  \
# 0                                         -62.396999
# 1                                                NaN
#
#    Mean cloud surface radiation budget from ERBE global: Global shortwave radiation budget data derived from 5 Years of ERBE measurements  \
# 0                                         155.817245
# 1                                                NaN
#
#    Mean number of wet days per year  \
# 0                             185.4
# 1                               NaN
#
#    Mean sum of annual precipitation (PPT / MAP / TAP)  Mid Point  \
# 0                                                NaN         NaN
# 1                                                NaN         NaN
#
#    Minimum temperature at which 50% seeds germinate  \
# 0                                               NaN
# 1                                               NaN
#
#    Minimum temperature germination Mono/poly carpic Mycorrhizal type  \
# 0                              NaN              NaN       arbuscular
# 1                              NaN              NaN              NaN
#
#    NDVI of the site  NPP of the site (2)  \
# 0          0.775755          1110.599976
# 1               NaN                  NaN
#
#    Net primary productivity of the site (NPP) Normal method of propagation  \
# 0                                         NaN                          NaN
# 1                                         NaN                          NaN
#
#   Northern Limit in Britain Northern Limit in Europe  \
# 0                        No                      NaN
# 1                       NaN                      NaN
#
#    Number of European countries in which native  \
# 0                                           NaN
# 1                                           NaN
#
#   Nutrition (autotroph versus heterotroph)  \
# 0                              autotrophic
# 1                                      NaN
#
#   Onset of flowering (first flowering date, beginning of flowering period)  \
# 0                                                  6
# 1                                                NaN
#
#      Order  Photoperiodism: threshold value (h) Photoperiodism: type  \
# 0  Rosales                                  NaN                  NaN
# 1      NaN                                  NaN                  NaN
#
#    Photosynthesis per leaf area at leaf temperature (A_area)  \
# 0                                                NaN
# 1                                                NaN
#
#    Photosynthesis per leaf dry mass (Amass) Physical defences on buds  \
# 0                                       NaN                       NaN
# 1                                       NaN                       NaN
#
#   Physical defences on flowers/fruits Physical defences on leaves  \
# 0                              spines                  soft hairs
# 1                                 NaN                         NaN
#
#   Physical defences on stems  \
# 0                        NaN
# 1                        NaN
#
#   Plant age at first flowering (primary juvenil period) Plant growth form  \
# 0                                                NaN                    H
# 1                                                NaN                  NaN
#
#   Plant height (unspecified if vegetative or reproductive)  \
# 0                                                2.0
# 1                                                NaN
#
#   Plant life form (Raunkiaer life form) Plant photosynthetic pathway  \
# 0                           chamaephyte                           C3
# 1                                   NaN                          NaN
#
#    Plant relative growth rate (RGR) Pollen viability  \
# 0                               NaN              NaN
# 1                               NaN              NaN
#
#   Pollen: 1. mono/di-morphic  Pollen: 2. diameter (um)  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
#
#   Pollination syndrome (pollen vector)  \
# 0                                  NaN
# 1                                  NaN
#
#    Precipitation Seasonality (Coefficient of Variation)  \
# 0                                                NaN
# 1                                                NaN
#
#    Precipitation of Coldest Quarter  Precipitation of Driest Month  \
# 0                               NaN                            NaN
# 1                               NaN                            NaN
#
#    Precipitation of Driest Quarter  Precipitation of Warmest Quarter  \
# 0                              NaN                               NaN
# 1                              NaN                               NaN
#
#    Precipitation of Wettest Month  Precipitation of Wettest Quarter  \
# 0                             NaN                               NaN
# 1                             NaN                               NaN
#
#    Priestley-Taylor alpha coefficient  \
# 0                                 NaN
# 1                                 NaN
#
#   Range: 1. european countries where native  \
# 0                                       NaN
# 1                                       NaN
#
#   Range: 2. european countries where introduced  \
# 0                                           NaN
# 1                                           NaN
#
#   Range: 3. continents where native Range: 4. continents where introduced  \
# 0                       Australasia                                Europe
# 1                               NaN                                   NaN
#
#                                   Reference / source  \
# 0  Gynn EG, Richards AJ 1985 Journal of Ecology 7...
# 1                                                NaN
#
#   Root architecture / root system / root habit Root hair length Root hairs  \
# 0                                          NaN              NaN        NaN
# 1                                          NaN              NaN        NaN
#
#   Root persistence (livespan, longevity) Root rooting depth   \
# 0                                    NaN                0-10
# 1                                    NaN                 NaN
#
#    SLA: undefined if petiole in- or excluded  SN Index Salinity Tolerance  \
# 0                                  78.616352      2.85                NaN
# 1                                        NaN       NaN                NaN
#
#   Seed / ovule ratio Seed dry mass Seed length (largest dimension length)  \
# 0                NaN          0.92                                    2.0
# 1                NaN           NaN                                    NaN
#
#   Seed number per plant Seed shedding season (time of seed dispersal)  \
# 0            1000-10000                                        autumn
# 1                   NaN                                           NaN
#
#   Seed viability Seedbank density Seedbank longevity Seedbank type  \
# 0           high              NaN                NaN           NaN
# 1            NaN              NaN                NaN           NaN
#
#   Seeds per flower  Soil C content per ground area  \
# 0                1                          6.6873
# 1              NaN                             NaN
#
#    Soil N content per ground area  Soil bulk density  Soil field capacity  \
# 0                      556.625977            1.49266           249.729996
# 1                             NaN                NaN                  NaN
#
#    Soil ph  \
# 0    5.372
# 1      NaN
#
#    Soil plant available water capacity of rooting zone (derived from remote sensing) 1  \
# 0                                         225.699997
# 1                                                NaN
#
#    Soil plant available water capacity of rooting zone (derived from remote sensing) 2  \
# 0                                         262.100006
# 1                                                NaN
#
#    Soil profile available water capacity  Soil thermal capacity  \
# 0                             174.516998                1.22082
# 1                                    NaN                    NaN
#
#    Soil water content (SWC)  Soil wilting point  \
# 0                       NaN           75.212303
# 1                       NaN                 NaN
#
#    Solar radiation (kJ m-2 day-1) Southern Limit in Europe  \
# 0                             NaN                      NaN
# 1                             NaN                      NaN
#
#   Species conservation status Species continentality Species eastern limit  \
# 0                         NaN        Not continental          Hyperoceanic
# 1                         NaN                    NaN                   NaN
#
#   Species nutrient requirements (in soil)  \
# 0                                     NaN
# 1                                     NaN
#
#   Species nutrient requirements (in water)  \
# 0                                      NaN
# 1                                      NaN
#
#   Species occurance dynamics (increasing / decreasing)  \
# 0                                                NaN
# 1                                                NaN
#
#                   Species origin  \
# 0                            NaN
# 1  Archeophyt in British Islands
#
#   Species pH requirement ( soil, extreme minimum)  \
# 0                                             5.5
# 1                                             NaN
#
#    Species pH requirement ( soil, typical minimum)  \
# 0                                              NaN
# 1                                              NaN
#
#   Species pH requirement (soil, extreme maximum)  \
# 0                                            8.6
# 1                                            NaN
#
#    Species pH requirement (soil, typical maximum)  \
# 0                                             NaN
# 1                                             NaN
#
#    Species pH requirement (water, extreme maximum)  \
# 0                                              NaN
# 1                                              NaN
#
#    Species pH requirement (water, extreme minimum)  \
# 0                                              NaN
# 1                                              NaN
#
#    Species pH requirement (water, typical maximum)  \
# 0                                              NaN
# 1                                              NaN
#
#    Species pH requirement (water, typical minimum) Species rarity status  \
# 0                                              NaN                   NaN
# 1                                              NaN                   NaN
#
#   Species soil moisture requirements (drainage)  \
# 0                                 free-draining
# 1                                           NaN
#
#   Species soil moisture requirements (supply)  \
# 0                                         NaN
# 1                                         NaN
#
#   Species soil moisture requirements (water table)  \
# 0                                              NaN
# 1                                              NaN
#
#   Species status (nativity at growth location)  \
# 0                                  naturalised
# 1                                          NaN
#
#   Species synonyms (alternative name)  \
# 0                                 NaN
# 1                                 NaN
#
#   Spread (plant height versus plant width relationshp)) Stem longevity  \
# 0                                     height < width               NaN
# 1                                                NaN               NaN
#
#   Stem self-supporting  Stomata density Stomata density on lower surface  \
# 0           procumbent              NaN                              NaN
# 1                  NaN              NaN                              NaN
#
#   Stomata density on upper surface Stomata distribution (surfaces present)  \
# 0                              NaN                                     NaN
# 1                              NaN                                     NaN
#
#       Subclass  Temperature sum of growing degree days (GDD)  \
# 0  Magnoliidae                                        2452.0
# 1          NaN                                           NaN
#
#    Temperature: Annual Range  Temperature: Isothermality (BIO2/BIO7) (* 100)  \
# 0                        NaN                                             NaN
# 1                        NaN                                             NaN
#
#    Temperature: Max Temperature of Warmest Month  \
# 0                                            NaN
# 1                                            NaN
#
#    Temperature: Mean Diurnal Range (Mean of monthly (max temp - min temp))  \
# 0                                                NaN
# 1                                                NaN
#
#    Temperature: Mean Temperature of Coldest Quarter  \
# 0                                               NaN
# 1                                               NaN
#
#    Temperature: Mean Temperature of Driest Quarter  \
# 0                                              NaN
# 1                                              NaN
#
#    Temperature: Mean Temperature of Warmest Quarter  \
# 0                                               NaN
# 1                                               NaN
#
#    Temperature: Mean Temperature of Wettest Quarter  \
# 0                                               NaN
# 1                                               NaN
#
#    Temperature: Min Temperature of Coldest Month  \
# 0                                            NaN
# 1                                            NaN
#
#    Temperature: Seasonality (standard deviation *100)  \
# 0                                                NaN
# 1                                                NaN
#
#    Terrestrial chlorophyll index of the site  \
# 0                                   3.180153
# 1                                        NaN
#
#   Time (season) of germination (seedling emergence)  \
# 0                                            spring
# 1                                               NaN
#
#   Tolerance (resistance) to heavy metals Tolerance to drought  \
# 0                                    NaN                  NaN
# 1                                    NaN                  NaN
#
#   Tolerance to frost (non-woody tissue) Tolerance to frost (seedlings)  \
# 0                             sensitive                            NaN
# 1                                   NaN                            NaN
#
#   Tolerance to grazing Tolerance to shade  \
# 0                  NaN               none
# 1                  NaN                NaN
#
#   Typical abundance where naturally occurring Vegetation type / Biome  \
# 0                                         NaN                       4
# 1                                         NaN                     NaN
#
#   Vegetative regeneration / reproduction (clonal spread)  \
# 0                                            stolons
# 1                                                NaN
#
#   Vegetative reproduction: pattern forming  Water vapor pressure (kPa)  \
# 0                                      NaN                         NaN
# 1                                      NaN                         NaN
#
#    Wetness/Humidity/Aridity of area where samples were taken  \
# 0                                                0.0
# 1                                                NaN
#
#    Wind speed (m s-1) Woodiness   Genus               Species
# 0                 NaN     woody  ACAENA       NOVAE-ZELANDIAE
# 1                 NaN       NaN  ACAENA  NOVAE-ZELANDIAE Kirk

# %% [markdown]
# Has not lost the authorship detail.  Repeat

# %%
Flora[['species', 'Author']] = Flora['Species'].str.split(' ', 1, expand=True)

# %%
Flora = Flora.drop('Species', 1)
# Out:
# /var/folders/8k/5wbyxggs1q1856w27fftzywh0000gp/T/ipykernel_56403/1732581978.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   Flora = Flora.drop('Species', 1)

# %%
Flora['Key'] = Flora['Genus'] + " " +Flora['species']

# %%
Flora.head(2)
# Out:
#                 AccSpeciesName APG IV level 1 APG IV level 2 APG IV level 3  \
# 0       ACAENA NOVAE-ZELANDIAE       Eudicots  Core Eudicots    Superrosids
# 1  ACAENA NOVAE-ZELANDIAE Kirk            NaN            NaN            NaN
#
#   APG IV level 4 APG IV level 5  Actual EvapoTranspiration  \
# 0         Rosids         Fabids                        NaN
# 1            NaN            NaN                        NaN
#
#   After-ripening requirement  Altitude Altitude (maximum recorded)  \
# 0                        NaN      11.0                         NaN
# 1                        NaN       NaN                         NaN
#
#    Altitude (minimum recorded)  Altitude (typical minimum)  \
# 0                          0.0                         NaN
# 1                          NaN                         NaN
#
#    Annual precipitation Annual seed dispersal Appendages on dispersal unit  \
# 0                 831.0                   NaN                        hooks
# 1                   NaN                   NaN                          NaN
#
#    Average annual relative humidity  \
# 0                              81.0
# 1                               NaN
#
#    Average number of ground frost days per year (sum) (FRS)  \
# 0                                              175.1
# 1                                                NaN
#
#    British distribution (post 1949 records)              Carnivory  \
# 0                                       NaN  does not kill insects
# 1                                       NaN                    NaN
#
#    Change Index  Chromosome cDNA content Chromosome number  Chromosome ploidy  \
# 0           NaN                     0.65                42                NaN
# 1           NaN                      NaN               NaN                NaN
#
#   Cleistogamy                                  Clonality  Cloud cover  \
# 0         NaN  Extensively creeping and rooting at nodes         72.6
# 1         NaN                                        NaN          NaN
#
#   Comments, notes, methods              Dataset (1)          Dataset (2)  \
# 0                      NaN  Royer et al, 2005, 2012  Peppe et al. (2011)
# 1                      NaN                      NaN                  NaN
#
#               Dichogamy Dicliny (monoeceous, dioecious, hermaphrodite)  \
# 0  markedly protogynous                                  hermaphrodite
# 1                   NaN                                            NaN
#
#   Dispersal syndrome (agent) Dispersal unit (dispersule / diaspore) length  \
# 0         carried by mammals                                           NaN
# 1                        NaN                                           NaN
#
#    EW Index  Ecosystem rooting depth  Ellenberg indicator value: Light  \
# 0      3.57                      1.3                               8.0
# 1       NaN                      NaN                               NaN
#
#    Ellenberg indicator value: Moisture  \
# 0                                  NaN
# 1                                  NaN
#
#    Ellenberg indicator value: Salt tolerance  \
# 0                                        NaN
# 1                                        NaN
#
#    Ellenberg indicator value: nitrogen  \
# 0                                  3.0
# 1                                  NaN
#
#    Ellenberg indicator value: pH (reaction)  End of flowering Epoch Exposure  \
# 0                                       NaN               7.0   NaN      NaN
# 1                                       NaN               NaN   NaN      NaN
#
#      Family  Fern  and moss spore width (diameter)   Fertilization  \
# 0  Rosaceae                                    NaN  cross and self
# 1       NaN                                    NaN             NaN
#
#   Fine root diameter  First historical record: 1. date  \
# 0                NaN                            1901.0
# 1                NaN                               NaN
#
#   First historical record: 2. site Flow  Flower pollen ovule ratio  \
# 0                    Yarner, Devon  NaN                        NaN
# 1                              NaN  NaN                        NaN
#
#    Flowering periode: peak month Fossil record: 1. earliest record  \
# 0                            NaN                               NaN
# 1                            NaN                               NaN
#
#   Fossil record: 2. earliest postglacial record  \
# 0                                           NaN
# 1                                           NaN
#
#    Fraction of absorbed photosynthetic active radiation (FAPAR) of the site  \
# 0                                           0.666167
# 1                                                NaN
#
#    GPP of the site Genera growth form Germination requirements 1. chilling  \
# 0              NaN                  S                              partial
# 1              NaN                NaN                                  NaN
#
#   Germination requirements 2. light  \
# 0                          absolute
# 1                               NaN
#
#   Germination requirements 3. temperature fluctuation Germination type  \
# 0                                                NaN           epigeal
# 1                                                NaN               NaN
#
#   Habitat / plot description Heteromorphy Heterophylly  \
# 0                        NaN          NaN          NaN
# 1                        NaN          NaN          NaN
#
#    Identifier within contributed dataset (ID) Inbreeding  \
# 0                                      2601.0        NaN
# 1                                         NaN        NaN
#
#   Incompatibility systems Intensity of mycorrhizal infection  \
# 0                     NaN               normally mycorrhizal
# 1                     NaN                                NaN
#
#    January mean temperature  July mean temperature  Latitude  \
# 0                       3.8                   15.2     -40.5
# 1                       NaN                    NaN       NaN
#
#    Leaf Relative water content (water content / water content at saturation)  \
# 0                                                NaN
# 1                                                NaN
#
#    Leaf Water content (molar) per leaf dry mass (WCd)  \
# 0                                                NaN
# 1                                                NaN
#
#    Leaf Water content saturating (molar) (WCs)  \
# 0                                          NaN
# 1                                          NaN
#
#    Leaf Water content total (molar) (WCt)  Leaf area index of the site (LAI)  \
# 0                                     NaN                           2.689583
# 1                                     NaN                                NaN
#
#   Leaf area: in case of compound leaves undefined if leaf or leaflet; undefined if petiole and rhachis in- or excluded  \
# 0                                                NaN
# 1                                                NaN
#
#    Leaf carbon content per area  Leaf carbon content per dry mass  \
# 0                           NaN                               NaN
# 1                           NaN                               NaN
#
#    Leaf carbon/nitrogen (C/N) ratio  Leaf carotenoid content per dry mass  \
# 0                               NaN                                   NaN
# 1                               NaN                                   NaN
#
#    Leaf chlorophyll a content per dry mass  \
# 0                                      NaN
# 1                                      NaN
#
#    Leaf chlorophyll a+b content per area  Leaf chlorophyll a/b ratio  \
# 0                                    NaN                         NaN
# 1                                    NaN                         NaN
#
#    Leaf chlorophyll b content per dry mass  \
# 0                                      NaN
# 1                                      NaN
#
#    Leaf chlorophyll content (a+b) per dry mass Leaf compoundness  \
# 0                                          NaN          compound
# 1                                          NaN               NaN
#
#    Leaf dry matter content per leaf water-saturated mass (LDMC)  \
# 0                                                NaN
# 1                                                NaN
#
#   Leaf lamina thickness Leaf lifespan (longevity, retention time, LL)  \
# 0                   NaN                                           NaN
# 1                   NaN                                           NaN
#
#    Leaf nitrogen content per area (Narea)  \
# 0                                     NaN
# 1                                     NaN
#
#   Leaf nitrogen content per dry mass (Nmass)  Leaf petiole length  \
# 0                                        NaN                  NaN
# 1                                        NaN                  NaN
#
#   Leaf phenology type  Leaf phosphorus content per area (Parea)  \
# 0           evergreen                                       NaN
# 1                 NaN                                       NaN
#
#   Leaf phosphorus content per dry mass (Pmass) Leaf position  \
# 0                                          NaN           NaN
# 1                                          NaN           NaN
#
#    Leaf respiration per area at leaf temperature  \
# 0                                            NaN
# 1                                            NaN
#
#    Leaf respiration per dry mass Leaf shape: 2. outline  \
# 0                            NaN                toothed
# 1                            NaN                    NaN
#
#   Leaf shape: 3. pointed/round Leaf shape: 4. length versus breadth  \
# 0                      rounded             >3 times as long as wide
# 1                          NaN                                  NaN
#
#   Leaf shape: 5. leaf base Leaf shape: 6. leaf petiole type  Leaf thickness  \
# 0                 truncate                        petiolate             NaN
# 1                      NaN                              NaN             NaN
#
#    Leaf tissue density  Leaf transpiration (molar) per dry mass  \
# 0                  NaN                                      NaN
# 1                  NaN                                      NaN
#
#    Leaf transpiration rate per dry mass (daytime)  \
# 0                                             NaN
# 1                                             NaN
#
#    Leaf water content per leaf dry mass  \
# 0                                   NaN
# 1                                   NaN
#
#    Leaf water content per leaf water-saturated mass (LWC, 1-LDMC)  \
# 0                                                NaN
# 1                                                NaN
#
#    Leaf water content saturating  Leaf water content total  \
# 0                            NaN                       NaN
# 1                            NaN                       NaN
#
#    Leaf water saturation deficit  Length of growing season (LGP)  \
# 0                            NaN                            15.0
# 1                            NaN                             NaN
#
#   Location / Site Name Location Country  Longitude Major Phylogenetic Group  \
# 0       Foxton Estuary      New Zealand      175.2              Angiosperms
# 1                  NaN              NaN        NaN                      NaN
#
#    Maximum Green Vegetation Fraction Maximum depth of leaves in the canopy  \
# 0                                NaN                                   NaN
# 1                                NaN                                   NaN
#
#    Maximum temperature at which 50% seeds germinate  \
# 0                                               NaN
# 1                                               NaN
#
#    Maximum temperature of germination  \
# 0                                 NaN
# 1                                 NaN
#
#    Mean annual sum of potential evapotranspiration (PET)  \
# 0                                                NaN
# 1                                                NaN
#
#    Mean annual temperature (MAT)  \
# 0                            NaN
# 1                            NaN
#
#    Mean clear-sky surface radiation budget from ERBE global: Global shortwave radiation budget data derived from 5 Years of ERBE measurements  \
# 0                                         218.214081
# 1                                                NaN
#
#    Mean cloud forcing surface radiation budget from ERBE global: Global shortwave radiation budget data derived from 5 Years of ERBE measurements  \
# 0                                         -62.396999
# 1                                                NaN
#
#    Mean cloud surface radiation budget from ERBE global: Global shortwave radiation budget data derived from 5 Years of ERBE measurements  \
# 0                                         155.817245
# 1                                                NaN
#
#    Mean number of wet days per year  \
# 0                             185.4
# 1                               NaN
#
#    Mean sum of annual precipitation (PPT / MAP / TAP)  Mid Point  \
# 0                                                NaN         NaN
# 1                                                NaN         NaN
#
#    Minimum temperature at which 50% seeds germinate  \
# 0                                               NaN
# 1                                               NaN
#
#    Minimum temperature germination Mono/poly carpic Mycorrhizal type  \
# 0                              NaN              NaN       arbuscular
# 1                              NaN              NaN              NaN
#
#    NDVI of the site  NPP of the site (2)  \
# 0          0.775755          1110.599976
# 1               NaN                  NaN
#
#    Net primary productivity of the site (NPP) Normal method of propagation  \
# 0                                         NaN                          NaN
# 1                                         NaN                          NaN
#
#   Northern Limit in Britain Northern Limit in Europe  \
# 0                        No                      NaN
# 1                       NaN                      NaN
#
#    Number of European countries in which native  \
# 0                                           NaN
# 1                                           NaN
#
#   Nutrition (autotroph versus heterotroph)  \
# 0                              autotrophic
# 1                                      NaN
#
#   Onset of flowering (first flowering date, beginning of flowering period)  \
# 0                                                  6
# 1                                                NaN
#
#      Order  Photoperiodism: threshold value (h) Photoperiodism: type  \
# 0  Rosales                                  NaN                  NaN
# 1      NaN                                  NaN                  NaN
#
#    Photosynthesis per leaf area at leaf temperature (A_area)  \
# 0                                                NaN
# 1                                                NaN
#
#    Photosynthesis per leaf dry mass (Amass) Physical defences on buds  \
# 0                                       NaN                       NaN
# 1                                       NaN                       NaN
#
#   Physical defences on flowers/fruits Physical defences on leaves  \
# 0                              spines                  soft hairs
# 1                                 NaN                         NaN
#
#   Physical defences on stems  \
# 0                        NaN
# 1                        NaN
#
#   Plant age at first flowering (primary juvenil period) Plant growth form  \
# 0                                                NaN                    H
# 1                                                NaN                  NaN
#
#   Plant height (unspecified if vegetative or reproductive)  \
# 0                                                2.0
# 1                                                NaN
#
#   Plant life form (Raunkiaer life form) Plant photosynthetic pathway  \
# 0                           chamaephyte                           C3
# 1                                   NaN                          NaN
#
#    Plant relative growth rate (RGR) Pollen viability  \
# 0                               NaN              NaN
# 1                               NaN              NaN
#
#   Pollen: 1. mono/di-morphic  Pollen: 2. diameter (um)  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
#
#   Pollination syndrome (pollen vector)  \
# 0                                  NaN
# 1                                  NaN
#
#    Precipitation Seasonality (Coefficient of Variation)  \
# 0                                                NaN
# 1                                                NaN
#
#    Precipitation of Coldest Quarter  Precipitation of Driest Month  \
# 0                               NaN                            NaN
# 1                               NaN                            NaN
#
#    Precipitation of Driest Quarter  Precipitation of Warmest Quarter  \
# 0                              NaN                               NaN
# 1                              NaN                               NaN
#
#    Precipitation of Wettest Month  Precipitation of Wettest Quarter  \
# 0                             NaN                               NaN
# 1                             NaN                               NaN
#
#    Priestley-Taylor alpha coefficient  \
# 0                                 NaN
# 1                                 NaN
#
#   Range: 1. european countries where native  \
# 0                                       NaN
# 1                                       NaN
#
#   Range: 2. european countries where introduced  \
# 0                                           NaN
# 1                                           NaN
#
#   Range: 3. continents where native Range: 4. continents where introduced  \
# 0                       Australasia                                Europe
# 1                               NaN                                   NaN
#
#                                   Reference / source  \
# 0  Gynn EG, Richards AJ 1985 Journal of Ecology 7...
# 1                                                NaN
#
#   Root architecture / root system / root habit Root hair length Root hairs  \
# 0                                          NaN              NaN        NaN
# 1                                          NaN              NaN        NaN
#
#   Root persistence (livespan, longevity) Root rooting depth   \
# 0                                    NaN                0-10
# 1                                    NaN                 NaN
#
#    SLA: undefined if petiole in- or excluded  SN Index Salinity Tolerance  \
# 0                                  78.616352      2.85                NaN
# 1                                        NaN       NaN                NaN
#
#   Seed / ovule ratio Seed dry mass Seed length (largest dimension length)  \
# 0                NaN          0.92                                    2.0
# 1                NaN           NaN                                    NaN
#
#   Seed number per plant Seed shedding season (time of seed dispersal)  \
# 0            1000-10000                                        autumn
# 1                   NaN                                           NaN
#
#   Seed viability Seedbank density Seedbank longevity Seedbank type  \
# 0           high              NaN                NaN           NaN
# 1            NaN              NaN                NaN           NaN
#
#   Seeds per flower  Soil C content per ground area  \
# 0                1                          6.6873
# 1              NaN                             NaN
#
#    Soil N content per ground area  Soil bulk density  Soil field capacity  \
# 0                      556.625977            1.49266           249.729996
# 1                             NaN                NaN                  NaN
#
#    Soil ph  \
# 0    5.372
# 1      NaN
#
#    Soil plant available water capacity of rooting zone (derived from remote sensing) 1  \
# 0                                         225.699997
# 1                                                NaN
#
#    Soil plant available water capacity of rooting zone (derived from remote sensing) 2  \
# 0                                         262.100006
# 1                                                NaN
#
#    Soil profile available water capacity  Soil thermal capacity  \
# 0                             174.516998                1.22082
# 1                                    NaN                    NaN
#
#    Soil water content (SWC)  Soil wilting point  \
# 0                       NaN           75.212303
# 1                       NaN                 NaN
#
#    Solar radiation (kJ m-2 day-1) Southern Limit in Europe  \
# 0                             NaN                      NaN
# 1                             NaN                      NaN
#
#   Species conservation status Species continentality Species eastern limit  \
# 0                         NaN        Not continental          Hyperoceanic
# 1                         NaN                    NaN                   NaN
#
#   Species nutrient requirements (in soil)  \
# 0                                     NaN
# 1                                     NaN
#
#   Species nutrient requirements (in water)  \
# 0                                      NaN
# 1                                      NaN
#
#   Species occurance dynamics (increasing / decreasing)  \
# 0                                                NaN
# 1                                                NaN
#
#                   Species origin  \
# 0                            NaN
# 1  Archeophyt in British Islands
#
#   Species pH requirement ( soil, extreme minimum)  \
# 0                                             5.5
# 1                                             NaN
#
#    Species pH requirement ( soil, typical minimum)  \
# 0                                              NaN
# 1                                              NaN
#
#   Species pH requirement (soil, extreme maximum)  \
# 0                                            8.6
# 1                                            NaN
#
#    Species pH requirement (soil, typical maximum)  \
# 0                                             NaN
# 1                                             NaN
#
#    Species pH requirement (water, extreme maximum)  \
# 0                                              NaN
# 1                                              NaN
#
#    Species pH requirement (water, extreme minimum)  \
# 0                                              NaN
# 1                                              NaN
#
#    Species pH requirement (water, typical maximum)  \
# 0                                              NaN
# 1                                              NaN
#
#    Species pH requirement (water, typical minimum) Species rarity status  \
# 0                                              NaN                   NaN
# 1                                              NaN                   NaN
#
#   Species soil moisture requirements (drainage)  \
# 0                                 free-draining
# 1                                           NaN
#
#   Species soil moisture requirements (supply)  \
# 0                                         NaN
# 1                                         NaN
#
#   Species soil moisture requirements (water table)  \
# 0                                              NaN
# 1                                              NaN
#
#   Species status (nativity at growth location)  \
# 0                                  naturalised
# 1                                          NaN
#
#   Species synonyms (alternative name)  \
# 0                                 NaN
# 1                                 NaN
#
#   Spread (plant height versus plant width relationshp)) Stem longevity  \
# 0                                     height < width               NaN
# 1                                                NaN               NaN
#
#   Stem self-supporting  Stomata density Stomata density on lower surface  \
# 0           procumbent              NaN                              NaN
# 1                  NaN              NaN                              NaN
#
#   Stomata density on upper surface Stomata distribution (surfaces present)  \
# 0                              NaN                                     NaN
# 1                              NaN                                     NaN
#
#       Subclass  Temperature sum of growing degree days (GDD)  \
# 0  Magnoliidae                                        2452.0
# 1          NaN                                           NaN
#
#    Temperature: Annual Range  Temperature: Isothermality (BIO2/BIO7) (* 100)  \
# 0                        NaN                                             NaN
# 1                        NaN                                             NaN
#
#    Temperature: Max Temperature of Warmest Month  \
# 0                                            NaN
# 1                                            NaN
#
#    Temperature: Mean Diurnal Range (Mean of monthly (max temp - min temp))  \
# 0                                                NaN
# 1                                                NaN
#
#    Temperature: Mean Temperature of Coldest Quarter  \
# 0                                               NaN
# 1                                               NaN
#
#    Temperature: Mean Temperature of Driest Quarter  \
# 0                                              NaN
# 1                                              NaN
#
#    Temperature: Mean Temperature of Warmest Quarter  \
# 0                                               NaN
# 1                                               NaN
#
#    Temperature: Mean Temperature of Wettest Quarter  \
# 0                                               NaN
# 1                                               NaN
#
#    Temperature: Min Temperature of Coldest Month  \
# 0                                            NaN
# 1                                            NaN
#
#    Temperature: Seasonality (standard deviation *100)  \
# 0                                                NaN
# 1                                                NaN
#
#    Terrestrial chlorophyll index of the site  \
# 0                                   3.180153
# 1                                        NaN
#
#   Time (season) of germination (seedling emergence)  \
# 0                                            spring
# 1                                               NaN
#
#   Tolerance (resistance) to heavy metals Tolerance to drought  \
# 0                                    NaN                  NaN
# 1                                    NaN                  NaN
#
#   Tolerance to frost (non-woody tissue) Tolerance to frost (seedlings)  \
# 0                             sensitive                            NaN
# 1                                   NaN                            NaN
#
#   Tolerance to grazing Tolerance to shade  \
# 0                  NaN               none
# 1                  NaN                NaN
#
#   Typical abundance where naturally occurring Vegetation type / Biome  \
# 0                                         NaN                       4
# 1                                         NaN                     NaN
#
#   Vegetative regeneration / reproduction (clonal spread)  \
# 0                                            stolons
# 1                                                NaN
#
#   Vegetative reproduction: pattern forming  Water vapor pressure (kPa)  \
# 0                                      NaN                         NaN
# 1                                      NaN                         NaN
#
#    Wetness/Humidity/Aridity of area where samples were taken  \
# 0                                                0.0
# 1                                                NaN
#
#    Wind speed (m s-1) Woodiness   Genus          species Author  \
# 0                 NaN     woody  ACAENA  NOVAE-ZELANDIAE   None
# 1                 NaN       NaN  ACAENA  NOVAE-ZELANDIAE   Kirk
#
#                       Key
# 0  ACAENA NOVAE-ZELANDIAE
# 1  ACAENA NOVAE-ZELANDIAE

# %%
Dtofl['Key'] = Dtofl['Genus'] + " " + Dtofl['Species']

# %%
Dtofl.head(2)
# Out:
#        kew_id unclear_species_marker extinct_species_marker  \
# 0  60468511-2                    NaN                    NaN
# 1    325658-2                    NaN                    NaN
#
#                            taxon_name taxon_name_binom              authors  \
# 0                    Abies alba Mill.       Abies alba                Mill.
# 1  Abies amabilis Douglas ex J.Forbes   Abies amabilis  Douglas ex J.Forbes
#
#   taxon_name_WCVP                  authors_WCVP    order    family  genus  \
# 0      Abies alba                         Mill.  Pinales  Pinaceae  Abies
# 1  Abies amabilis  (Douglas ex Loudon) J.Forbes  Pinales  Pinaceae  Abies
#
#   subgenus section subsection series   species group aggregate  \
# 0      NaN     NaN        NaN    NaN      alba   NaN       NaN
# 1      NaN     NaN        NaN    NaN  amabilis   NaN       NaN
#
#   members_of_agg. taxonomic_status accepted_kew_id accepted_name  \
# 0             NaN         Accepted             NaN           NaN
# 1             NaN         Accepted             NaN           NaN
#
#   accepted_authors imperfect_match_with_Stace_IV  \
# 0              NaN                           NaN
# 1              NaN                           NaN
#
#                                         WCVP_URL  \
# 0  https://wcvp.science.kew.org/taxon/60468511-2
# 1    https://wcvp.science.kew.org/taxon/325658-2
#
#                                             POWO_URL  \
# 0  http://plantsoftheworldonline.org/taxon/604685...
# 1   http://plantsoftheworldonline.org/taxon/325658-2
#
#                         IPNI_URL accepted_WCVP_URL StaceIV_nativity  \
# 0  https://ipni.org/n/60468511-2               NaN         Neo-natd
# 1    https://ipni.org/n/325658-2               NaN              NaN
#
#   Atlas_nativity_viaALIENATT_PLANTATT Stace_Crawley_nativity_aliens  \
# 0                                  AN                           Neo
# 1                                 NaN                           NaN
#
#          SLA      LDMC  seed_mass   leaf_area  mean_veg_height  \
# 0   7.698508  0.529816  65.612834  255.029158        46.843893
# 1  86.690769       NaN  42.277126         NaN        50.148522
#
#    max_veg_height  L_PLANTATT  F_PLANTATT  R_PLANTATT  N_PLANTATT  S_PLANTATT  \
# 0            68.0         NaN         NaN         NaN         NaN         NaN
# 1            75.0         NaN         NaN         NaN         NaN         NaN
#
#    L_Doring  F_Doring  R_Doring  N_Doring  S_Doring  T_Doring ECPE_CSR  \
# 0       3.0       NaN       NaN       NaN       0.0       5.0      NaN
# 1       NaN       NaN       NaN       NaN       NaN       NaN      NaN
#
#   predicted_CSR growth_form succulence            life_form biome  \
# 0             S        Tree        NaN  phanerophyte / tree   NaN
# 1           NaN        Tree        NaN  phanerophyte / tree   NaN
#
#                   origin TDWG_level_1_code  GB_Man_hectads_post2000  \
# 0  mountains in C Europe                 1                    382.0
# 1            W N America                 7                     11.0
#
#    Ire_hectads_post2000  CI_hectads_post2000  GB_Man_hectads_1987_1999  \
# 0                 230.0                  0.0                     230.0
# 1                   0.0                  0.0                       7.0
#
#    Ire_hectads_1987_1999  CI_hectads_1987_1999  GB_Man_hectads_2000_2009  \
# 0                   28.0                   0.0                     120.0
# 1                    0.0                   0.0                       5.0
#
#    Ire_hectads_2000_2009  CI_hectads_2000_2009  GB_Man_hectads_2010_2019  \
# 0                  179.0                   0.0                     303.0
# 1                    0.0                   0.0                       8.0
#
#    Ire_hectads_2010_2019  CI_hectads_2010_2019  hybrid_propensity  \
# 0                   89.0                   0.0                NaN
# 1                    0.0                   0.0                NaN
#
#    scaled_hybrid_propensity BOLD_link1 BOLD_link2 BOLD_link3  GS_1C_pg  \
# 0                       NaN        NaN        NaN        NaN     17.27
# 1                       NaN        NaN        NaN        NaN       NaN
#
#    GS_2C_pg  GS_1C_Mbp  GS_2C_Mbp from_BI_material         data_source  \
# 0     34.54   16891.68   33783.36                n  marda et al. 2019
# 1       NaN        NaN        NaN              NaN                 NaN
#
#   sporophytic_chromosome_number infraspecific_variation_chrom_number  \
# 0                           NaN                                  NaN
# 1                           NaN                                  NaN
#
#   other_reported_sporophytic_chromosome_number  \
# 0                                           24
# 1                                          NaN
#
#              source_of_other_chrom_num  Genus   Species             Key
# 0  marda et al. 2019, Zonneveld, 2019  Abies      alba      Abies alba
# 1                                  NaN  Abies  amabilis  Abies amabilis

# %%
df_merged = pd.merge(Dtofl, Flora, left_on=Dtofl["Key"].str.lower(), right_on=Flora["Key"].str.lower(), how="left")

# %%
df_merged.shape
# Out:
# (3302, 353)

# %%
df_merged.head()
# Out:
#                key_0      kew_id unclear_species_marker  \
# 0         abies alba  60468511-2                    NaN
# 1     abies amabilis    325658-2                    NaN
# 2  abies cephalonica    261486-1                    NaN
# 3      abies fraseri   1030488-2                    NaN
# 4      abies grandis   1033427-2                    NaN
#
#   extinct_species_marker                               taxon_name  \
# 0                    NaN                         Abies alba Mill.
# 1                    NaN       Abies amabilis Douglas ex J.Forbes
# 2                    NaN                 Abies cephalonica Loudon
# 3                    NaN              Abies fraseri (Pursh) Poir.
# 4                    NaN  Abies grandis (Douglas ex D.Don) Lindl.
#
#     taxon_name_binom                    authors    taxon_name_WCVP  \
# 0         Abies alba                      Mill.         Abies alba
# 1     Abies amabilis        Douglas ex J.Forbes     Abies amabilis
# 2  Abies cephalonica                     Loudon  Abies cephalonica
# 3      Abies fraseri              (Pursh) Poir.      Abies fraseri
# 4      Abies grandis  (Douglas ex D.Don) Lindl.      Abies grandis
#
#                    authors_WCVP    order    family  genus subgenus section  \
# 0                         Mill.  Pinales  Pinaceae  Abies      NaN     NaN
# 1  (Douglas ex Loudon) J.Forbes  Pinales  Pinaceae  Abies      NaN     NaN
# 2                        Loudon  Pinales  Pinaceae  Abies      NaN     NaN
# 3                 (Pursh) Poir.  Pinales  Pinaceae  Abies      NaN     NaN
# 4     (Douglas ex D.Don) Lindl.  Pinales  Pinaceae  Abies      NaN     NaN
#
#   subsection series    species_x group aggregate members_of_agg.  \
# 0        NaN    NaN         alba   NaN       NaN             NaN
# 1        NaN    NaN     amabilis   NaN       NaN             NaN
# 2        NaN    NaN  cephalonica   NaN       NaN             NaN
# 3        NaN    NaN      fraseri   NaN       NaN             NaN
# 4        NaN    NaN      grandis   NaN       NaN             NaN
#
#   taxonomic_status accepted_kew_id accepted_name accepted_authors  \
# 0         Accepted             NaN           NaN              NaN
# 1         Accepted             NaN           NaN              NaN
# 2         Accepted             NaN           NaN              NaN
# 3         Accepted             NaN           NaN              NaN
# 4         Accepted             NaN           NaN              NaN
#
#   imperfect_match_with_Stace_IV  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
#
#                                         WCVP_URL  \
# 0  https://wcvp.science.kew.org/taxon/60468511-2
# 1    https://wcvp.science.kew.org/taxon/325658-2
# 2    https://wcvp.science.kew.org/taxon/261486-1
# 3   https://wcvp.science.kew.org/taxon/1030488-2
# 4   https://wcvp.science.kew.org/taxon/1033427-2
#
#                                             POWO_URL  \
# 0  http://plantsoftheworldonline.org/taxon/604685...
# 1   http://plantsoftheworldonline.org/taxon/325658-2
# 2   http://plantsoftheworldonline.org/taxon/261486-1
# 3  http://plantsoftheworldonline.org/taxon/1030488-2
# 4  http://plantsoftheworldonline.org/taxon/1033427-2
#
#                         IPNI_URL accepted_WCVP_URL StaceIV_nativity  \
# 0  https://ipni.org/n/60468511-2               NaN         Neo-natd
# 1    https://ipni.org/n/325658-2               NaN              NaN
# 2    https://ipni.org/n/261486-1               NaN         Neo-natd
# 3   https://ipni.org/n/1030488-2               NaN         Neo-surv
# 4   https://ipni.org/n/1033427-2               NaN         Neo-surv
#
#   Atlas_nativity_viaALIENATT_PLANTATT Stace_Crawley_nativity_aliens  \
# 0                                  AN                           Neo
# 1                                 NaN                           NaN
# 2                                  AN                           Neo
# 3                                  AN                           Neo
# 4                                  AN                           Neo
#
#          SLA      LDMC  seed_mass   leaf_area  mean_veg_height  \
# 0   7.698508  0.529816  65.612834  255.029158        46.843893
# 1  86.690769       NaN  42.277126         NaN        50.148522
# 2   6.530926       NaN  71.430000         NaN        25.875000
# 3   6.071000       NaN   7.202712   22.801836        20.138400
# 4  11.056371       NaN  22.444655   59.856000        27.373643
#
#    max_veg_height  L_PLANTATT  F_PLANTATT  R_PLANTATT  N_PLANTATT  S_PLANTATT  \
# 0            68.0         NaN         NaN         NaN         NaN         NaN
# 1            75.0         NaN         NaN         NaN         NaN         NaN
# 2            40.0         NaN         NaN         NaN         NaN         NaN
# 3            27.0         NaN         NaN         NaN         NaN         NaN
# 4           100.0         NaN         NaN         NaN         NaN         NaN
#
#    L_Doring  F_Doring  R_Doring  N_Doring  S_Doring  T_Doring ECPE_CSR  \
# 0       3.0       NaN       NaN       NaN       0.0       5.0      NaN
# 1       NaN       NaN       NaN       NaN       NaN       NaN      NaN
# 2       NaN       NaN       NaN       NaN       NaN       NaN      NaN
# 3       NaN       NaN       NaN       NaN       NaN       NaN      NaN
# 4       NaN       NaN       NaN       NaN       NaN       NaN      NaN
#
#   predicted_CSR growth_form succulence            life_form biome  \
# 0             S        Tree        NaN  phanerophyte / tree   NaN
# 1           NaN        Tree        NaN  phanerophyte / tree   NaN
# 2           NaN        Tree        NaN  phanerophyte / tree   NaN
# 3           NaN        Tree        NaN  phanerophyte / tree   NaN
# 4           NaN        Tree        NaN  phanerophyte / tree   NaN
#
#                   origin TDWG_level_1_code  GB_Man_hectads_post2000  \
# 0  mountains in C Europe                 1                    382.0
# 1            W N America                 7                     11.0
# 2                 Greece                 1                     11.0
# 3            E N America                 7                      2.0
# 4            W N America                 7                    567.0
#
#    Ire_hectads_post2000  CI_hectads_post2000  GB_Man_hectads_1987_1999  \
# 0                 230.0                  0.0                     230.0
# 1                   0.0                  0.0                       7.0
# 2                   0.0                  0.0                       6.0
# 3                   0.0                  0.0                       0.0
# 4                  73.0                  0.0                     327.0
#
#    Ire_hectads_1987_1999  CI_hectads_1987_1999  GB_Man_hectads_2000_2009  \
# 0                   28.0                   0.0                     120.0
# 1                    0.0                   0.0                       5.0
# 2                    0.0                   0.0                       1.0
# 3                    0.0                   0.0                       0.0
# 4                   11.0                   0.0                     268.0
#
#    Ire_hectads_2000_2009  CI_hectads_2000_2009  GB_Man_hectads_2010_2019  \
# 0                  179.0                   0.0                     303.0
# 1                    0.0                   0.0                       8.0
# 2                    0.0                   0.0                       9.0
# 3                    0.0                   0.0                       2.0
# 4                   35.0                   0.0                     436.0
#
#    Ire_hectads_2010_2019  CI_hectads_2010_2019  hybrid_propensity  \
# 0                   89.0                   0.0                NaN
# 1                    0.0                   0.0                NaN
# 2                    0.0                   0.0                NaN
# 3                    0.0                   0.0                NaN
# 4                   40.0                   0.0                NaN
#
#    scaled_hybrid_propensity BOLD_link1 BOLD_link2 BOLD_link3  GS_1C_pg  \
# 0                       NaN        NaN        NaN        NaN     17.27
# 1                       NaN        NaN        NaN        NaN       NaN
# 2                       NaN        NaN        NaN        NaN     18.14
# 3                       NaN        NaN        NaN        NaN     17.24
# 4                       NaN        NaN        NaN        NaN     17.55
#
#    GS_2C_pg  GS_1C_Mbp  GS_2C_Mbp from_BI_material         data_source  \
# 0     34.54   16891.68   33783.36                n  marda et al. 2019
# 1       NaN        NaN        NaN              NaN                 NaN
# 2     36.27   17738.00   35476.00              NaN           C-ValueDB
# 3     34.47   16856.00   33712.00              NaN           C-ValueDB
# 4     35.10   17163.90   34327.80                n     Zonneveld, 2019
#
#   sporophytic_chromosome_number infraspecific_variation_chrom_number  \
# 0                           NaN                                  NaN
# 1                           NaN                                  NaN
# 2                           NaN                                  NaN
# 3                           NaN                                  NaN
# 4                           NaN                                  NaN
#
#   other_reported_sporophytic_chromosome_number  \
# 0                                           24
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                           24
#
#              source_of_other_chrom_num Genus_x      Species  \
# 0  marda et al. 2019, Zonneveld, 2019   Abies         alba
# 1                                  NaN   Abies     amabilis
# 2                                  NaN   Abies  cephalonica
# 3                                  NaN   Abies      fraseri
# 4                      Zonneveld, 2019   Abies      grandis
#
#                Key_x AccSpeciesName APG IV level 1 APG IV level 2  \
# 0         Abies alba     Abies alba            NaN            NaN
# 1     Abies amabilis            NaN            NaN            NaN
# 2  Abies cephalonica            NaN            NaN            NaN
# 3      Abies fraseri            NaN            NaN            NaN
# 4      Abies grandis  Abies grandis            NaN            NaN
#
#   APG IV level 3 APG IV level 4 APG IV level 5  Actual EvapoTranspiration  \
# 0            NaN            NaN            NaN                      657.0
# 1            NaN            NaN            NaN                        NaN
# 2            NaN            NaN            NaN                        NaN
# 3            NaN            NaN            NaN                        NaN
# 4            NaN            NaN            NaN                      597.0
#
#   After-ripening requirement  Altitude Altitude (maximum recorded)  \
# 0                        NaN    1434.0                         NaN
# 1                        NaN       NaN                         NaN
# 2                        NaN       NaN                         NaN
# 3                        NaN       NaN                         NaN
# 4                        NaN    1446.0                        1830
#
#    Altitude (minimum recorded)  Altitude (typical minimum)  \
# 0                          NaN                         NaN
# 1                          NaN                         NaN
# 2                          NaN                         NaN
# 3                          NaN                         NaN
# 4                          NaN                       200.0
#
#    Annual precipitation Annual seed dispersal Appendages on dispersal unit  \
# 0                   NaN                  mast                        wings
# 1                   NaN                   NaN                          NaN
# 2                   NaN                   NaN                          NaN
# 3                   NaN                   NaN                          NaN
# 4                   NaN             irregular                        wings
#
#    Average annual relative humidity  \
# 0                              69.0
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                              71.0
#
#    Average number of ground frost days per year (sum) (FRS)  \
# 0                                              242.1
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                              277.1
#
#    British distribution (post 1949 records)              Carnivory  \
# 0                                       NaN  does not kill insects
# 1                                       NaN                    NaN
# 2                                       NaN                    NaN
# 3                                       NaN                    NaN
# 4                                       NaN                    NaN
#
#    Change Index  Chromosome cDNA content Chromosome number  Chromosome ploidy  \
# 0           NaN                34.465333                24                2.0
# 1           NaN                      NaN               NaN                NaN
# 2           NaN                      NaN               NaN                NaN
# 3           NaN                      NaN               NaN                NaN
# 4           NaN                34.465333                24                2.0
#
#   Cleistogamy Clonality  Cloud cover Comments, notes, methods Dataset (1)  \
# 0         NaN       NaN         62.3                      NaN  TRY db 091
# 1         NaN       NaN          NaN                      NaN         NaN
# 2         NaN       NaN          NaN                      NaN         NaN
# 3         NaN       NaN          NaN                      NaN         NaN
# 4         NaN       NaN         71.4                      NaN  TRY db 068
#
#                                          Dataset (2) Dichogamy  \
# 0  Pe?uelas J. Catalonian Mediterranean Forest Tr...       NaN
# 1                                                NaN       NaN
# 2                                                NaN       NaN
# 3                                                NaN       NaN
# 4  Wirth C. The Functional Ecology of Trees (FET)...       NaN
#
#   Dicliny (monoeceous, dioecious, hermaphrodite) Dispersal syndrome (agent)  \
# 0                                     monoecious                        NaN
# 1                                            NaN                        NaN
# 2                                            NaN                        NaN
# 3                                            NaN                        NaN
# 4                                     monoecious                       wind
#
#   Dispersal unit (dispersule / diaspore) length  EW Index  \
# 0                                          32.0       NaN
# 1                                           NaN       NaN
# 2                                           NaN       NaN
# 3                                           NaN       NaN
# 4                                           NaN       NaN
#
#    Ecosystem rooting depth  Ellenberg indicator value: Light  \
# 0                      1.1                               NaN
# 1                      NaN                               NaN
# 2                      NaN                               NaN
# 3                      NaN                               NaN
# 4                      1.5                               NaN
#
#    Ellenberg indicator value: Moisture  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#    Ellenberg indicator value: Salt tolerance  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    Ellenberg indicator value: nitrogen  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#    Ellenberg indicator value: pH (reaction)  End of flowering Epoch Exposure  \
# 0                                       NaN               NaN   NaN      NaN
# 1                                       NaN               NaN   NaN      NaN
# 2                                       NaN               NaN   NaN      NaN
# 3                                       NaN               NaN   NaN      NaN
# 4                                       NaN               7.0   NaN      NaN
#
#      Family  Fern  and moss spore width (diameter) Fertilization  \
# 0  Pinaceae                                    NaN           NaN
# 1       NaN                                    NaN           NaN
# 2       NaN                                    NaN           NaN
# 3       NaN                                    NaN           NaN
# 4  Pinaceae                                    NaN           NaN
#
#   Fine root diameter  First historical record: 1. date  \
# 0                NaN                            1603.0
# 1                NaN                               NaN
# 2                NaN                               NaN
# 3                NaN                               NaN
# 4                NaN                            1831.0
#
#   First historical record: 2. site Flow  Flower pollen ovule ratio  \
# 0                            vc 55  NaN                        NaN
# 1                              NaN  NaN                        NaN
# 2                              NaN  NaN                        NaN
# 3                              NaN  NaN                        NaN
# 4                            vc 16  NaN                        NaN
#
#    Flowering periode: peak month Fossil record: 1. earliest record  \
# 0                            NaN                               NaN
# 1                            NaN                               NaN
# 2                            NaN                               NaN
# 3                            NaN                               NaN
# 4                            6.0                               NaN
#
#   Fossil record: 2. earliest postglacial record  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    Fraction of absorbed photosynthetic active radiation (FAPAR) of the site  \
# 0                                           0.456000
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                           0.663069
#
#    GPP of the site Genera growth form Germination requirements 1. chilling  \
# 0           1306.5                NaN                                  NaN
# 1              NaN                NaN                                  NaN
# 2              NaN                NaN                                  NaN
# 3              NaN                NaN                                  NaN
# 4           1373.2                NaN                                  NaN
#
#   Germination requirements 2. light  \
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                           partial
#
#   Germination requirements 3. temperature fluctuation Germination type  \
# 0                                                NaN               NaN
# 1                                                NaN               NaN
# 2                                                NaN               NaN
# 3                                                NaN               NaN
# 4                                                NaN               NaN
#
#   Habitat / plot description Heteromorphy Heterophylly  \
# 0                        NaN          NaN         none
# 1                        NaN          NaN          NaN
# 2                        NaN          NaN          NaN
# 3                        NaN          NaN          NaN
# 4                        NaN          NaN         None
#
#    Identifier within contributed dataset (ID) Inbreeding  \
# 0                                     34547.0        NaN
# 1                                         NaN        NaN
# 2                                         NaN        NaN
# 3                                         NaN        NaN
# 4                                     31599.5        NaN
#
#   Incompatibility systems Intensity of mycorrhizal infection  \
# 0                     NaN                                NaN
# 1                     NaN                                NaN
# 2                     NaN                                NaN
# 3                     NaN                                NaN
# 4                     NaN                                NaN
#
#    January mean temperature  July mean temperature  Latitude  \
# 0                       NaN                    NaN  42.71645
# 1                       NaN                    NaN       NaN
# 2                       NaN                    NaN       NaN
# 3                       NaN                    NaN       NaN
# 4                       NaN                    NaN  44.00000
#
#    Leaf Relative water content (water content / water content at saturation)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Leaf Water content (molar) per leaf dry mass (WCd)  \
# 0                                         299.889826
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Leaf Water content saturating (molar) (WCs)  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    Leaf Water content total (molar) (WCt)  Leaf area index of the site (LAI)  \
# 0                                     NaN                           1.576528
# 1                                     NaN                                NaN
# 2                                     NaN                                NaN
# 3                                     NaN                                NaN
# 4                                     NaN                           2.693194
#
#   Leaf area: in case of compound leaves undefined if leaf or leaflet; undefined if petiole and rhachis in- or excluded  \
# 0                                              0.1-1
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                1.5
#
#    Leaf carbon content per area  Leaf carbon content per dry mass  \
# 0                           NaN                             50.45
# 1                           NaN                               NaN
# 2                           NaN                               NaN
# 3                           NaN                               NaN
# 4                           NaN                               NaN
#
#    Leaf carbon/nitrogen (C/N) ratio  Leaf carotenoid content per dry mass  \
# 0                         43.094524                                   NaN
# 1                               NaN                                   NaN
# 2                               NaN                                   NaN
# 3                               NaN                                   NaN
# 4                               NaN                                   NaN
#
#    Leaf chlorophyll a content per dry mass  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    Leaf chlorophyll a+b content per area  Leaf chlorophyll a/b ratio  \
# 0                                    NaN                         NaN
# 1                                    NaN                         NaN
# 2                                    NaN                         NaN
# 3                                    NaN                         NaN
# 4                                    NaN                         NaN
#
#    Leaf chlorophyll b content per dry mass  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    Leaf chlorophyll content (a+b) per dry mass Leaf compoundness  \
# 0                                          NaN            simple
# 1                                          NaN               NaN
# 2                                          NaN               NaN
# 3                                          NaN               NaN
# 4                                          NaN            simple
#
#    Leaf dry matter content per leaf water-saturated mass (LDMC)  \
# 0                                             331.93
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Leaf lamina thickness Leaf lifespan (longevity, retention time, LL)  \
# 0               0.2-0.5                                           NaN
# 1                   NaN                                           NaN
# 2                   NaN                                           NaN
# 3                   NaN                                           NaN
# 4                   NaN                                           >24
#
#    Leaf nitrogen content per area (Narea)  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   Leaf nitrogen content per dry mass (Nmass)  Leaf petiole length  \
# 0                                     0.9536                  0.0
# 1                                        NaN                  NaN
# 2                                        NaN                  NaN
# 3                                        NaN                  NaN
# 4                                      10-20                  NaN
#
#   Leaf phenology type  Leaf phosphorus content per area (Parea)  \
# 0           evergreen                                       NaN
# 1                 NaN                                       NaN
# 2                 NaN                                       NaN
# 3                 NaN                                       NaN
# 4           evergreen                                       NaN
#
#   Leaf phosphorus content per dry mass (Pmass) Leaf position  \
# 0                                       0.1041           NaN
# 1                                          NaN           NaN
# 2                                          NaN           NaN
# 3                                          NaN           NaN
# 4                                            2           NaN
#
#    Leaf respiration per area at leaf temperature  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    Leaf respiration per dry mass Leaf shape: 2. outline  \
# 0                            NaN                 entire
# 1                            NaN                    NaN
# 2                            NaN                    NaN
# 3                            NaN                    NaN
# 4                            NaN                 entire
#
#   Leaf shape: 3. pointed/round Leaf shape: 4. length versus breadth  \
# 0                      rounded             >3 times as long as wide
# 1                          NaN                                  NaN
# 2                          NaN                                  NaN
# 3                          NaN                                  NaN
# 4                   emarginate             >3 times as long as wide
#
#   Leaf shape: 5. leaf base Leaf shape: 6. leaf petiole type  Leaf thickness  \
# 0           parallel sided                          sessile        0.469016
# 1                      NaN                              NaN             NaN
# 2                      NaN                              NaN             NaN
# 3                      NaN                              NaN             NaN
# 4                      NaN                       subsessile        0.473800
#
#    Leaf tissue density  Leaf transpiration (molar) per dry mass  \
# 0           269.585355                                      NaN
# 1                  NaN                                      NaN
# 2                  NaN                                      NaN
# 3                  NaN                                      NaN
# 4           345.500000                                      NaN
#
#    Leaf transpiration rate per dry mass (daytime)  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    Leaf water content per leaf dry mass  \
# 0                              2.012683
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                              1.928860
#
#    Leaf water content per leaf water-saturated mass (LWC, 1-LDMC)  \
# 0                                             66.807
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                             65.450
#
#    Leaf water content saturating  Leaf water content total  \
# 0                            NaN                       NaN
# 1                            NaN                       NaN
# 2                            NaN                       NaN
# 3                            NaN                       NaN
# 4                            NaN                       NaN
#
#    Leaf water saturation deficit  Length of growing season (LGP)  \
# 0                            NaN                             8.0
# 1                            NaN                             NaN
# 2                            NaN                             NaN
# 3                            NaN                             NaN
# 4                            NaN                             5.0
#
#                                 Location / Site Name Location Country  \
# 0                                                NaN            Spain
# 1                                                NaN              NaN
# 2                                                NaN              NaN
# 3                                                NaN              NaN
# 4  Warsaw University of Life Sciences Arboretum i...              USA
#
#     Longitude Major Phylogenetic Group  Maximum Green Vegetation Fraction  \
# 0    0.852721              Gymnosperms                               97.0
# 1         NaN                      NaN                                NaN
# 2         NaN                      NaN                                NaN
# 3         NaN                      NaN                                NaN
# 4 -122.000000              Gymnosperms                              100.0
#
#   Maximum depth of leaves in the canopy  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#    Maximum temperature at which 50% seeds germinate  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    Maximum temperature of germination  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#    Mean annual sum of potential evapotranspiration (PET)  \
# 0                                              720.0
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                              864.0
#
#    Mean annual temperature (MAT)  \
# 0                       7.595833
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                       5.787500
#
#    Mean clear-sky surface radiation budget from ERBE global: Global shortwave radiation budget data derived from 5 Years of ERBE measurements  \
# 0                                         191.827423
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                         186.887253
#
#    Mean cloud forcing surface radiation budget from ERBE global: Global shortwave radiation budget data derived from 5 Years of ERBE measurements  \
# 0                                         -53.757248
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                         -49.299667
#
#    Mean cloud surface radiation budget from ERBE global: Global shortwave radiation budget data derived from 5 Years of ERBE measurements  \
# 0                                         138.071335
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                         137.590668
#
#    Mean number of wet days per year  \
# 0                             126.1
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                              96.1
#
#    Mean sum of annual precipitation (PPT / MAP / TAP)  Mid Point  \
# 0                                             1144.0         NaN
# 1                                                NaN         NaN
# 2                                                NaN         NaN
# 3                                                NaN         NaN
# 4                                             1388.0         NaN
#
#    Minimum temperature at which 50% seeds germinate  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#    Minimum temperature germination Mono/poly carpic Mycorrhizal type  \
# 0                              NaN       polycarpic             Ecto
# 1                              NaN              NaN              NaN
# 2                              NaN              NaN              NaN
# 3                              NaN              NaN              NaN
# 4                              NaN       polycarpic    ecto, ectendo
#
#    NDVI of the site  NPP of the site (2)  \
# 0          0.564135           758.900024
# 1               NaN                  NaN
# 2               NaN                  NaN
# 3               NaN                  NaN
# 4          0.764138           348.799988
#
#    Net primary productivity of the site (NPP) Normal method of propagation  \
# 0                                       724.7                         seed
# 1                                         NaN                          NaN
# 2                                         NaN                          NaN
# 3                                         NaN                          NaN
# 4                                       738.6                         seed
#
#   Northern Limit in Britain Northern Limit in Europe  \
# 0                       NaN                      NaN
# 1                       NaN                      NaN
# 2                       NaN                      NaN
# 3                       NaN                      NaN
# 4                       NaN                      NaN
#
#    Number of European countries in which native  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           0.0
#
#   Nutrition (autotroph versus heterotroph)  \
# 0                              autotrophic
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                              autotrophic
#
#   Onset of flowering (first flowering date, beginning of flowering period)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#      Order  Photoperiodism: threshold value (h) Photoperiodism: type  \
# 0  Pinales                                  NaN                  NaN
# 1      NaN                                  NaN                  NaN
# 2      NaN                                  NaN                  NaN
# 3      NaN                                  NaN                  NaN
# 4  Pinales                                  NaN                  NaN
#
#    Photosynthesis per leaf area at leaf temperature (A_area)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Photosynthesis per leaf dry mass (Amass) Physical defences on buds  \
# 0                                     49.00                       NaN
# 1                                       NaN                       NaN
# 2                                       NaN                       NaN
# 3                                       NaN                       NaN
# 4                                     51.74                       NaN
#
#   Physical defences on flowers/fruits Physical defences on leaves  \
# 0                            glabrous                         NaN
# 1                                 NaN                         NaN
# 2                                 NaN                         NaN
# 3                                 NaN                         NaN
# 4                                 NaN                         NaN
#
#   Physical defences on stems  \
# 0                 soft hairs
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
#
#   Plant age at first flowering (primary juvenil period) Plant growth form  \
# 0                                                >20                    T
# 1                                                NaN                  NaN
# 2                                                NaN                  NaN
# 3                                                NaN                  NaN
# 4                                                >20                    T
#
#   Plant height (unspecified if vegetative or reproductive)  \
# 0                                             2500.0
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                             5400.0
#
#   Plant life form (Raunkiaer life form) Plant photosynthetic pathway  \
# 0                      Megaphanerophyte                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                          phanerophyte                          NaN
#
#    Plant relative growth rate (RGR) Pollen viability  \
# 0                               NaN              NaN
# 1                               NaN              NaN
# 2                               NaN              NaN
# 3                               NaN              NaN
# 4                               NaN              NaN
#
#   Pollen: 1. mono/di-morphic  Pollen: 2. diameter (um)  \
# 0                        NaN                     124.8
# 1                        NaN                       NaN
# 2                        NaN                       NaN
# 3                        NaN                       NaN
# 4                        NaN                       NaN
#
#   Pollination syndrome (pollen vector)  \
# 0                                 wind
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
#
#    Precipitation Seasonality (Coefficient of Variation)  \
# 0                                          15.634624
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                          66.168616
#
#    Precipitation of Coldest Quarter  Precipitation of Driest Month  \
# 0                             268.0                           69.0
# 1                               NaN                            NaN
# 2                               NaN                            NaN
# 3                               NaN                            NaN
# 4                             622.0                           23.0
#
#    Precipitation of Driest Quarter  Precipitation of Warmest Quarter  \
# 0                            246.0                             246.0
# 1                              NaN                               NaN
# 2                              NaN                               NaN
# 3                              NaN                               NaN
# 4                            106.0                             108.0
#
#    Precipitation of Wettest Month  Precipitation of Wettest Quarter  \
# 0                           120.0                             329.0
# 1                             NaN                               NaN
# 2                             NaN                               NaN
# 3                             NaN                               NaN
# 4                           238.0                             669.0
#
#    Priestley-Taylor alpha coefficient  \
# 0                                93.0
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                69.0
#
#   Range: 1. european countries where native  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   Range: 2. european countries where introduced  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   Range: 3. continents where native Range: 4. continents where introduced  \
# ...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                         258.700012
#
#    Soil profile available water capacity  Soil thermal capacity  \
# 0                             268.582001                1.05500
# 1                                    NaN                    NaN
# 2                                    NaN                    NaN
# 3                                    NaN                    NaN
# 4                             251.917999                0.95252
#
#    Soil water content (SWC)  Soil wilting point  \
# 0                      97.0          182.792007
# 1                       NaN                 NaN
# 2                       NaN                 NaN
# 3                       NaN                 NaN
# 4                      78.0          133.485992
#
#    Solar radiation (kJ m-2 day-1) Southern Limit in Europe  \
# 0                    14539.666667                      NaN
# 1                             NaN                      NaN
# 2                             NaN                      NaN
# 3                             NaN                      NaN
# 4                    14165.666667                      NaN
#
#   Species conservation status Species continentality Species eastern limit  \
# 0                         NaN                    NaN                   NaN
# 1                         NaN                    NaN                   NaN
# 2                         NaN                    NaN                   NaN
# 3                         NaN                    NaN                   NaN
# 4                         NaN                    NaN                   NaN
#
#   Species nutrient requirements (in soil)  \
# 0                                 fertile
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                 fertile
#
#   Species nutrient requirements (in water)  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   Species occurance dynamics (increasing / decreasing)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                   Species origin  \
# 0  Archeophyt in British Islands
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4  Archeophyt in British Islands
#
#   Species pH requirement ( soil, extreme minimum)  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                               5
#
#    Species pH requirement ( soil, typical minimum)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   Species pH requirement (soil, extreme maximum)  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    Species pH requirement (soil, typical maximum)  \
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#    Species pH requirement (water, extreme maximum)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    Species pH requirement (water, extreme minimum)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    Species pH requirement (water, typical maximum)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    Species pH requirement (water, typical minimum) Species rarity status  \
# 0                                              NaN                   NaN
# 1                                              NaN                   NaN
# 2                                              NaN                   NaN
# 3                                              NaN                   NaN
# 4                                              NaN                   NaN
#
#   Species soil moisture requirements (drainage)  \
# 0                                 free draining
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   Species soil moisture requirements (supply)  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   Species soil moisture requirements (water table)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                periodically high
#
#   Species status (nativity at growth location)  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   Species synonyms (alternative name)  \
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
#   Spread (plant height versus plant width relationshp)) Stem longevity  \
# 0                                        ht >> width           100-500
# 1                                                NaN               NaN
# 2                                                NaN               NaN
# 3                                                NaN               NaN
# 4                                     height > width           100-500
#
#   Stem self-supporting  Stomata density Stomata density on lower surface  \
# 0      self supporting              NaN                               64
# 1                  NaN              NaN                              NaN
# 2                  NaN              NaN                              NaN
# 3                  NaN              NaN                              NaN
# 4      self-supporting              NaN                              NaN
#
#   Stomata density on upper surface Stomata distribution (surfaces present)  \
# 0                              NaN                                   lower
# 1                              NaN                                     NaN
# 2                              NaN                                     NaN
# 3                              NaN                                     NaN
# 4                              NaN                                   lower
#
#   Subclass  Temperature sum of growing degree days (GDD)  \
# 0  Pinidae                                        1230.0
# 1      NaN                                           NaN
# 2      NaN                                           NaN
# 3      NaN                                           NaN
# 4  Pinidae                                        1247.0
#
#    Temperature: Annual Range  Temperature: Isothermality (BIO2/BIO7) (* 100)  \
# 0                       22.8                                       34.178187
# 1                        NaN                                             NaN
# 2                        NaN                                             NaN
# 3                        NaN                                             NaN
# 4                       23.9                                       43.619246
#
#    Temperature: Max Temperature of Warmest Month  \
# 0                                      19.700001
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                      17.500000
#
#    Temperature: Mean Diurnal Range (Mean of monthly (max temp - min temp))  \
# 0                                              7.625
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                             10.425
#
#    Temperature: Mean Temperature of Coldest Quarter  \
# 0                                          1.783333
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                          0.166667
#
#    Temperature: Mean Temperature of Driest Quarter  \
# 0                                        14.466667
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                        12.283333
#
#    Temperature: Mean Temperature of Warmest Quarter  \
# 0                                             15.25
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                             12.90
#
#    Temperature: Mean Temperature of Wettest Quarter  \
# 0                                          5.133333
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                          0.833333
#
#    Temperature: Min Temperature of Coldest Month  \
# 0                                           -3.5
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                           -6.4
#
#    Temperature: Seasonality (standard deviation *100)  \
# 0                                         564.534523
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                         528.957491
#
#    Terrestrial chlorophyll index of the site  \
# 0                                   2.180596
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                   2.455260
#
#   Time (season) of germination (seedling emergence)  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#   Tolerance (resistance) to heavy metals Tolerance to drought  \
# 0                                    NaN                  NaN
# 1                                    NaN                  NaN
# 2                                    NaN                  NaN
# 3                                    NaN                  NaN
# 4                                    NaN              resists
#
#   Tolerance to frost (non-woody tissue) Tolerance to frost (seedlings)  \
# 0                             resistant                            NaN
# 1                                   NaN                            NaN
# 2                                   NaN                            NaN
# 3                                   NaN                            NaN
# 4                                   NaN                            NaN
#
#   Tolerance to grazing Tolerance to shade  \
# 0                  NaN                NaN
# 1                  NaN                NaN
# 2                  NaN                NaN
# 3                  NaN                NaN
# 4                  NaN                NaN
#
#   Typical abundance where naturally occurring Vegetation type / Biome  \
# 0                                         NaN                       4
# 1                                         NaN                     NaN
# 2                                         NaN                     NaN
# 3                                         NaN                     NaN
# 4                                         NaN                       5
#
#   Vegetative regeneration / reproduction (clonal spread)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Vegetative reproduction: pattern forming  Water vapor pressure (kPa)  \
# 0                                no ramets                    0.750833
# 1                                      NaN                         NaN
# 2                                      NaN                         NaN
# 3                                      NaN                         NaN
# 4                                      NaN                    0.587500
#
#    Wetness/Humidity/Aridity of area where samples were taken  \
# 0                                             1.5465
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                             1.6643
#
#    Wind speed (m s-1) Woodiness Genus_y species_y Author          Key_y
# 0            4.458333     woody   Abies      alba   None     Abies alba
# 1                 NaN       NaN     NaN       NaN    NaN            NaN
# 2                 NaN       NaN     NaN       NaN    NaN            NaN
# 3                 NaN       NaN     NaN       NaN    NaN            NaN
# 4            3.508333     woody   Abies   grandis   None  Abies grandis

# %%
df_merged.to_csv("merged_db.csv", index=False)
