# %% [markdown]
# ## Class 2
# Downloading and entering data
# Basic stats and plots

# %% [markdown]
# In the last class you entered data yourself.  Most of the data analysis you will be doing in this class, and likely in the future, will be using available datasets from which you can extract the data you want to examine.  In the class you will practise downloading data sets and opening them as pandas dataframe ready for cleaning and subsetting (next week).  We start with a few examples but feel free to find your own datasets to experiment with.

# %%
# Analysis modules
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Easy start.
# Pandas has a method for directly reading in excel sheets
#
#     df = pd.read_excel('my_data.xls')
#
# and for reading in comma delineated files
#
#     df = pd.read_csv('my_data.csv')
#
# read in count.xls and count.csv
#
# They are in the folder Datasets, which is in the folder above this one so the full path is:
#     ../Datasets/count.xls

# %%
df = pd.read_excel('../Datasets/count.xls')

# %%
df
# Out:
#    Field  Sheep  Goats  Barley  Oats
# 0      1     45     44     103   521
# 1      2      5      2     233   324
# 2      3     67     23     432   734
# 3      4      8      6     612   123
# 4      5     23      7     332   243
# 5      6      4      9      12   734
# 6      7     55      3       4   128
# 7      8      1     11     543   223
# 8      9      2     34     723   316
# 9     10     67      3     126   402

# %% [markdown]
# and for reading in comma delineated files

# %%
df = pd.read_csv('../Datasets/count.csv')

# %%
df
# Out:
#    Field  Sheep  Goats  Barley  Oats
# 0      1     45     44     103   521
# 1      2      5      2     233   324
# 2      3     67     23     432   734
# 3      4      8      6     612   123
# 4      5     23      7     332   243
# 5      6      4      9      12   734
# 6      7     55      3       4   128
# 7      8      1     11     543   223
# 8      9      2     34     723   316
# 9     10     67      3     126   402

# %% [markdown]
# But this only works if comma delimited.  This file is tab delinated.  Can you fix the read in command?

# %%
df = pd.read_csv('../Datasets/count.txt')

# %%
df
# Out:
#   Field\tSheep\tGoats\tBarley\tOats
# 0               1\t45\t44\t103\t521
# 1                 2\t5\t2\t233\t324
# 2               3\t67\t23\t432\t734
# 3                 4\t8\t6\t612\t123
# 4                5\t23\t7\t332\t243
# 5                  6\t4\t9\t12\t734
# 6                  7\t55\t3\t4\t128
# 7                8\t1\t11\t543\t223
# 8                9\t2\t34\t723\t316
# 9               10\t67\t3\t126\t402

# %% [markdown]
# We need to specify what the delimiter is, in this case, tabs. the parameter for delimiter is:
#
#        sep =

# %% [markdown]
# You can also read in tab delinitaed files using pd.read_table().  Check this.

# %% [markdown]
# Once it's in you can check the file structure is as you expect using
#
#     df.info()
#
# which gives you the full story, or
#
#     df.dtypes
#
# which tells you how pandas has coded each column of data
#
# Compare both outputs.

# %% [markdown]
# There are 3 duff datasets in ../Datasets/
#
#     count_duff1.txt
#     count_duff2.txt
#     count_duff3.txt
#
#
# Read each into a dataframe with header, counts as integers and the field number as a string.

# %% [markdown]
# Useful parameters:
#
#     field separator: sep =
#     specify the null values: na_values =
#     set column headers: header=None (or specify a list)
#     Make data a specified type: dtype={'Column_A': 'string'})
#     ignore problematic rows: error_bad_lines=False

# %%
### Advice

count_duff1.txt has missing data as asterixs. The asterixes are causing pandas to code the columns as objects - it won't be possible to do calculations with this data.
We can specify that Pandas should treat the asterixs as missing data.

df = pd.read_csv('../Datasets/count_duff2.txt',sep ='\t', dtype={'Field': 'string'})

duff2 has an extra value on a row, so will not load.
df = pd.read_csv("count_duff3.txt", error_bad_lines=False)

duff3 needs column anmes attached
col_names = ["Meadow", "Pigs","Cows", "Potatoes","Turnips"]
df = pd.read_csv('../Datasets/count_duff3.txt',sep ='\t', header=None, names = col_names)
df

# %% [markdown]
# ### The parts of a dataframe
# We've defined column headers, but there are also row labels in the left-most column.  This is the dataframe index

# %%
col_names = ["Meadow", "Pigs","Cows", "Potatoes","Turnips"]
df = pd.read_csv('../Datasets/count_things.txt',sep ='\t', header=None, names = col_names)
df
# Out:
#         Meadow  Pigs  Cows  Potatoes  Turnips
# 0    Waun_fach  45.0  44.0     103.0    521.0
# 1    Ffos_fawr   NaN   2.0     233.0    324.0
# 2   Aberheidol  67.0  23.0     432.0    734.0
# 3      Hen_cae   8.0   6.0     612.0    123.0
# 4       Glynan  23.0   NaN     332.0    243.0
# 5       Derwen   4.0   9.0      12.0    734.0
# 6   Llanwenant  55.0   NaN       NaN    128.0
# 7  Heol-y-bryn   1.0  11.0     543.0    223.0
# 8    Lan-y-mor   2.0  34.0     723.0    316.0
# 9   Pen-y-garn  67.0   3.0       NaN      NaN

# %% [markdown]
# We can call the columns as a list and the index as a list

# %%
df.columns
# Out:
# Index(['Meadow', 'Pigs', 'Cows', 'Potatoes', 'Turnips'], dtype='object')

# %% [markdown]
# What does the index look like?

# %% [markdown]
# The column and row headers are python sequences and you can pull out individual lables the same way you would access part of the python list

# %%
df.columns[3]
# Out:
# 'Potatoes'

# %%
df.index[3]
# Out:
# 3

# %% [markdown]
# You can re-name the index to more informative values - the field numbers

# %%
df.set_index('Meadow', inplace=True)

# %% [markdown]
# what happens if you don't set inplace=True?

# %%
df
# Out:
#              Pigs  Cows  Potatoes  Turnips
# Meadow
# Waun_fach    45.0  44.0     103.0    521.0
# Ffos_fawr     NaN   2.0     233.0    324.0
# Aberheidol   67.0  23.0     432.0    734.0
# Hen_cae       8.0   6.0     612.0    123.0
# Glynan       23.0   NaN     332.0    243.0
# Derwen        4.0   9.0      12.0    734.0
# Llanwenant   55.0   NaN       NaN    128.0
# Heol-y-bryn   1.0  11.0     543.0    223.0
# Lan-y-mor     2.0  34.0     723.0    316.0
# Pen-y-garn   67.0   3.0       NaN      NaN

# %% [markdown]
# We can pick out individual values by specifiying column and index

# %% [markdown]
# How many Cows in Meadow Hen_cae?

# %%
df.at['Hen_cae','Cows']
# Out:
# 6.0

# %% [markdown]
# change this, adding a cow to the Hen_cae.  Use
#
#     df.at[index, column] =

# %% [markdown]
# ### Trickier.
# Downloading data from a website and opening it.
# NCBI has a list of sequence genomes and their assembly metrics:
#
#     INTRODUCTION
# -------------
# species_genome_size.txt.gz provides the expected genome size for each species
# taxid with at least four assemblies in GenBank. The expected genome size range
# is used to identify outliers for a species that can result from errors. More
# information about how the genome size ranges are calculated can be found
# https://www.ncbi.nlm.nih.gov/assembly/help/genome-size-check/.
#
#
# The species_genome_size.txt.gz file has 5 tab-delimited columns.
# Header rows begin with '#".
#
# Column  1: species_taxid
#    Taxonomic identifier of each species
#
# Column  2: min_ungapped_length
#    Minimum expected ungapped genome size of an assembly for the species
#
# Column  3: max_ungapped_length
#    Maximum expected ungapped genome size of an assembly for the species
#
# Column  4: expected_ungapped_length
#    Median genome assembly size of assemblies for the species
#
# Column  5: number_of_genomes
#    Number of genomes used to calculate the expected size range

# %% [markdown]
# We will down load the file (using wget), unzip it (using gunzip), check it's structure (using head) and read it in.

# %% [markdown]
# Using "!" at the start of a line informs the notebook that the following is bash and not python

# %%
! wget https://ftp.ncbi.nlm.nih.gov/genomes/ASSEMBLY_REPORTS/species_genome_size.txt.gz
# Out:
# --2023-08-04 11:11:16--  https://ftp.ncbi.nlm.nih.gov/genomes/ASSEMBLY_REPORTS/species_genome_size.txt.gz
# Resolving ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)... 165.112.9.228, 130.14.250.13
# Connecting to ftp.ncbi.nlm.nih.gov (ftp.ncbi.nlm.nih.gov)|165.112.9.228|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 59264 (58K) [application/x-gzip]
# Saving to: ‘species_genome_size.txt.gz’
#
# species_genome_size 100%[===================>]  57.88K   267KB/s    in 0.2s
#
# 2023-08-04 11:11:17 (267 KB/s) - ‘species_genome_size.txt.gz’ saved [59264/59264]

# %% [markdown]
# Unzip the datafile

# %%
! gunzip species_genome_size.txt.gz

# %%
Use "! ls" to check what files you have now

# %% [markdown]
# Check the data file's format using head as a bash command

# %%
! head -3 species_genome_size.txt
# Out:
# #species_taxid	min_ungapped_length	max_ungapped_length	expected_ungapped_length	number_of_genomes	method_determined
# 9	318000	956000	636876	80	automatic
# 23	3680000	5522000	4631520	5	automatic

# %% [markdown]
# Read the data in. Which pd.read format would be best?

# %%
df = pd.read_table("species_genome_size.txt")

# %% [markdown]
# Check that pandas has interpreted the type of data correctly using dtypes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4037 entries, 0 to 4036
# Data columns (total 6 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   #species_taxid            4037 non-null   int64
#  1   min_ungapped_length       4037 non-null   int64
#  2   max_ungapped_length       4037 non-null   int64
#  3   expected_ungapped_length  4037 non-null   int64
#  4   number_of_genomes         4037 non-null   int64
#  5   method_determined         4037 non-null   object
# dtypes: int64(5), object(1)
# memory usage: 189.4+ KB

# %% [markdown]
# #### What is the species with the most sequenced genomes?

# %% [markdown]
# df.max()['column'] will give you the maxiumum value for a column, but you want to also know the species id for this value.
#
# Try sorting the whole dataframe using
#
#     df.sort_values(by=['Column_name'])
#
# You can use
#
#     .tail(N)
#
# to show just N rows
#
# You can use
#
#     ascending=False
#
# to show the highest values at the top

# %% [markdown]
# Make a quick histogram of the number of genomes using:
#
#     sns.histplot(data=df, y="number_of_genomes")

# %%
sns.boxplot(x=df["number_of_genomes"])
# Out:
# <AxesSubplot:xlabel='number_of_genomes'>

# %% [markdown]
# You can check the identity of any genome at NCBI:
#
#     https://www.ncbi.nlm.nih.gov/assembly/
#
# search by txid[species_taxid]
# txid[3707] is mustard, Brassica juncea

# %% [markdown]
# Not all data is as tidy as the NCBI download.  Sometimes you need to exclude lines when you read in data.

# %% [markdown]
# ### Tricky file formats

# %% [markdown]
# Open the excel sheet of data on agricultural productivy in the UK since 1973.
# This is from:
#
#    https://assets.publishing.service.gov.uk/government/uploads/system/uploads/attachment_data/file/1004686/AUK-Chapter5-13jul23.ods
#
# This was originally in ods format file. It COULD be read in directly by installing the odf engine, but to save complictions I've provided it as an excel file.

# %%
../Datasets/AUK-Chapter5-13jul23.xlsx'

# %%
df = pd.read_excel('../Datasets/AUK-Chapter5-13jul23.xlsx')
df.head(10)
# Out:
#                         Date of update: 13 July 2023  Unnamed: 1   Unnamed: 2  \
# 0                             Next update: July 2024         NaN          NaN
# 1                                                NaN         NaN          NaN
# 2  Data for Tables 5.1 to 5.2 and Figures 5.1 to ...         NaN          NaN
# 3                                                NaN         NaN          NaN
# 4   Enquiries: Tim Buttanshaw on +44 (0)20 8026 3601         NaN          NaN
# 5                                                NaN         NaN          NaN
# 6                                         1973 = 100         NaN          NaN
# 7                                                NaN      1973.0  1974.000000
# 8                                1 Output of cereals       100.0   106.495639
# 9                                              wheat       100.0   111.061991
#
#     Unnamed: 3   Unnamed: 4   Unnamed: 5                        Unnamed: 6  \
# 0          NaN          NaN          NaN                               NaN
# 1          NaN          NaN          NaN                               NaN
# 2          NaN          NaN          NaN                               NaN
# 3          NaN          NaN          NaN                               NaN
# 4          NaN          NaN          NaN  Email: farmaccounts@defra.gov.uk
# 5          NaN          NaN          NaN                               NaN
# 6          NaN          NaN          NaN                               NaN
# 7  1975.000000  1976.000000  1977.000000                              1978
# 8    96.861286    89.477469   110.017057                        119.097829
# 9    98.020137    92.535909    99.814874                        118.013991
#
#     Unnamed: 7   Unnamed: 8   Unnamed: 9  ...  Unnamed: 41  Unnamed: 42  \
# 0          NaN          NaN          NaN  ...          NaN          NaN
# 1          NaN          NaN          NaN  ...          NaN          NaN
# 2          NaN          NaN          NaN  ...          NaN          NaN
# 3          NaN          NaN          NaN  ...          NaN          NaN
# 4          NaN          NaN          NaN  ...          NaN          NaN
# 5          NaN          NaN          NaN  ...          NaN          NaN
# 6          NaN          NaN          NaN  ...          NaN          NaN
# 7  1979.000000  1980.000000  1981.000000  ...  2013.000000  2014.000000
# 8   123.214382   145.505545   153.275035  ...   159.185468   204.371418
# 9   136.718803   167.555883   169.366646  ...   221.868376   320.422202
#
#    Unnamed: 43  Unnamed: 44  Unnamed: 45  Unnamed: 46  Unnamed: 47  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN
# 5          NaN          NaN          NaN          NaN          NaN
# 6          NaN          NaN          NaN          NaN          NaN
# 7  2015.000000  2016.000000  2017.000000  2018.000000  2019.000000
# 8   207.873040   183.962101   187.381859   167.727641   206.282808
# 9   320.214118   282.738719   284.765282   254.079302   307.525725
#
#    Unnamed: 48  Unnamed: 49  Unnamed: 50
# 0          NaN          NaN          NaN
# 1          NaN          NaN          NaN
# 2          NaN          NaN          NaN
# 3          NaN          NaN          NaN
# 4          NaN          NaN          NaN
# 5          NaN          NaN          NaN
# 6          NaN          NaN          NaN
# 7  2020.000000  2021.000000  2022.000000
# 8   143.027317   175.497720   183.789535
# 9   175.039016   262.137395   266.115915
#
# [10 rows x 51 columns]

# %% [markdown]
# At least it reads in, but it's clearly not right - the first few rows are not data.  We need to exclude them, here we do this by setting as header the first line of data.
#
# Specify which of the input rows should be the header with
#
#     header = N
#
# Remember that pandas is 0-indexed.

# %%
df = pd.read_excel('../Datasets/AUK-Chapter5-13jul23.xlsx', header =8)
df.head(3)
# Out:
#             Unnamed: 0   1973        1974       1975       1976        1977  \
# 0  1 Output of cereals  100.0  106.495639  96.861286  89.477469  110.017058
# 1                wheat  100.0  111.061991  98.020137  92.535909   99.814874
# 2                 rye   100.0   80.000000  80.000000  90.000000  130.000000
#
#          1978        1979        1980        1981  ...        2012  \
# 0  119.097829  123.214382  145.505545  153.275035  ...  159.446117
# 1  118.013991  136.718803  167.555883  169.366646  ...  257.804953
# 2  160.000000  140.000000  140.000000  140.000000  ...  150.000000
#
#          2013        2014        2015        2016        2017        2018  \
# 0  159.185468  204.371418  207.873040  183.962101  187.381859  167.727641
# 1  221.868376  320.422202  320.214117  282.738719  284.765281  254.079302
# 2  200.000000  200.000000  200.000000  200.000000  170.000000  200.000000
#
#          2019        2020        2021
# 0  206.282808  143.025361  175.620653
# 1  307.525725  175.034456  265.165192
# 2  200.000000  170.000000  170.000000
#
# [3 rows x 50 columns]

# %% [markdown]
# We could also skip rows using
#
#     skiprows=N
#
# What should N be here?

# %%
df = pd.read_excel('../Datasets/AUK-Chapter5-13jul23.xlsx', skiprows=8)
df.head(3)
# Out:
#             Unnamed: 0   1973        1974       1975       1976        1977  \
# 0  1 Output of cereals  100.0  106.495639  96.861286  89.477469  110.017058
# 1                wheat  100.0  111.061991  98.020137  92.535909   99.814874
# 2                 rye   100.0   80.000000  80.000000  90.000000  130.000000
#
#          1978        1979        1980        1981  ...        2012  \
# 0  119.097829  123.214382  145.505545  153.275035  ...  159.446117
# 1  118.013991  136.718803  167.555883  169.366646  ...  257.804953
# 2  160.000000  140.000000  140.000000  140.000000  ...  150.000000
#
#          2013        2014        2015        2016        2017        2018  \
# 0  159.185468  204.371418  207.873040  183.962101  187.381859  167.727641
# 1  221.868376  320.422202  320.214117  282.738719  284.765281  254.079302
# 2  200.000000  200.000000  200.000000  200.000000  170.000000  200.000000
#
#          2019        2020        2021
# 0  206.282808  143.025361  175.620653
# 1  307.525725  175.034456  265.165192
# 2  200.000000  170.000000  170.000000
#
# [3 rows x 50 columns]

# %% [markdown]
# The end of the file is untidy as well

# %%
df.tail(10)
# Out:
#                                            Unnamed: 0   1973        1974  \
# 61  Productivity by capital consumption (11 divide...  100.0  100.436272
# 62          Productivity by labour (11 divided by 23)  100.0  104.915892
# 63            Productivity by land (11 divided by 24)  100.0  100.740438
# 64                                                       NaN         NaN
# 65  (a) This table presents volume indices for all...    NaN         NaN
# 66  (b) To increase the usability and transparity ...    NaN         NaN
# 67  (c) AHDB stopped producing potato yield data a...    NaN         NaN
# 68  (d) We have renamed cattle, sheep, and pigs pr...    NaN         NaN
# 69                                                NaN    NaN         NaN
# 70                             © Crown copyright 2022    NaN         NaN
#
#           1975        1976        1977        1978        1979        1980  \
# 61   95.213292   91.518622   96.232506   99.003838   99.954277  102.084655
# 62  102.630282  101.920775  110.686948  117.045602  121.915979  128.373984
# 63   97.074194   94.570771  101.351266  105.924040  108.467968  111.874632
# 64         NaN         NaN         NaN         NaN         NaN         NaN
# 65         NaN         NaN         NaN         NaN         NaN         NaN
# 66         NaN         NaN         NaN         NaN         NaN         NaN
# 67         NaN         NaN         NaN         NaN         NaN         NaN
# 68         NaN         NaN         NaN         NaN         NaN         NaN
# 69         NaN         NaN         NaN         NaN         NaN         NaN
# 70         NaN         NaN         NaN         NaN         NaN         NaN
#
#           1981  ...        2012        2013        2014        2015  \
# 61  101.683516  ...  109.835561  109.863074  116.119230  116.754599
# 62  130.988725  ...  240.800285  247.138732  264.299931  268.108751
# 63  112.091873  ...  126.740968  128.533235  137.807161  141.254010
# 64         NaN  ...         NaN         NaN         NaN         NaN
# 65         NaN  ...         NaN         NaN         NaN         NaN
# 66         NaN  ...         NaN         NaN         NaN         NaN
# 67         NaN  ...         NaN         NaN         NaN         NaN
# 68         NaN  ...         NaN         NaN         NaN         NaN
# 69         NaN  ...         NaN         NaN         NaN         NaN
# 70         NaN  ...         NaN         NaN         NaN         NaN
#
#           2016        2017        2018        2019        2020        2021
# 61  112.773776  115.308385  111.330628  114.804065  108.909504  111.420744
# 62  262.130803  271.174793  263.851852  273.587776  260.177585  267.253146
# 63  135.571561  140.046280  137.736987  142.170019  136.177301  140.092633
# 64         NaN         NaN         NaN         NaN         NaN         NaN
# 65         NaN         NaN         NaN         NaN         NaN         NaN
# 66         NaN         NaN         NaN         NaN         NaN         NaN
# 67         NaN         NaN         NaN         NaN         NaN         NaN
# 68         NaN         NaN         NaN         NaN         NaN         NaN
# 69         NaN         NaN         NaN         NaN         NaN         NaN
# 70         NaN         NaN         NaN         NaN         NaN         NaN
#
# [10 rows x 50 columns]

# %% [markdown]
# Use
#
#     skipfooter=
#
# To tidy this up

# %%
df = pd.read_excel('../Datasets/AUK-Chapter5-13jul23.xlsx',  skiprows=8, skipfooter=8)
df.tail(5)
# Out:
#                                            Unnamed: 0  1973        1974  \
# 59       Total factor productivity (11 divided by 25)   100  106.270373
# 60  Productivity by intermediate consumption (11 d...   100  107.877523
# 61  Productivity by capital consumption (11 divide...   100  100.436272
# 62          Productivity by labour (11 divided by 23)   100  104.915892
# 63            Productivity by land (11 divided by 24)   100  100.740438
#
#           1975        1976        1977        1978        1979        1980  \
# 59  102.466371   98.229813  105.162556  109.321832  109.610859  114.700987
# 60  103.645620   97.716844  104.270679  107.745413  105.913039  111.075551
# 61   95.213292   91.518623   96.232506   99.003838   99.954276  102.084655
# 62  102.630282  101.920775  110.686948  117.045601  121.915979  128.373983
# 63   97.074194   94.570771  101.351266  105.924040  108.467968  111.874632
#
#           1981  ...        2013        2014        2015        2016  \
# 59  116.733463  ...  146.359263  155.247590  156.507594  151.431257
# 60  113.443675  ...  119.363257  125.972545  126.305593  121.709854
# 61  101.683516  ...  109.856220  116.111985  116.747315  112.766740
# 62  130.988725  ...  247.123313  264.283442  268.092024  262.114449
# 63  112.091873  ...  128.525216  137.798562  141.245197  135.563103
#
#           2017        2018        2019        2020        2021        2022
# 59  156.934681  155.578564  161.639211  154.313081  161.788666  167.271345
# 60  126.688681  127.769954  133.220825  127.189961  135.353791  143.498895
# 61  115.301191  111.317076  114.797672  109.211889  112.098037  112.170125
# 62  271.157874  263.819732  273.572541  261.050528  269.367027  269.005389
# 63  140.037542  137.720219  142.162102  136.635014  141.715292  144.899441
#
# [5 rows x 51 columns]

# %% [markdown]
# Check the dataframe is as you expect using df.info()

# %% [markdown]
# Empty rows are automatically skipped (compare the excel file with what is read in), but rows which are moslty empty are filled with NaN.  We can remove these.
# (inplace=True) makes the change happend on the original dataframe

# %%
df.dropna(inplace=True)

# %% [markdown]
# or drop just the columns where there are missing values:

# %%
df.dropna(axis='columns',inplace=True)

# %% [markdown]
# or the rows with more than 2 missing values

# %%
df.dropna(thresh=2,inplace=True)

# %% [markdown]
# or rows with missing values in specific columns

# %%
df.dropna(subset=[1983, 1997],inplace=True)

# %% [markdown]
# To examine this data it makes more sense to have outputs as columns.  We can transpose the dataframe using df.T

# %%
df = df.T

# %% [markdown]
# use
#
#     df.head(N)
#
# to check this has worked.

# %%
df.head(3)
# Out:
#                              0           1     2           3   \
# Unnamed: 0  1 Output of cereals       wheat  rye       barley
# 1973                        100         100   100         100
# 1974                 106.495639  111.061991  80.0  102.990299
#
#                                          4              5   \
# Unnamed: 0  oats and summer cereal mixtures  other cereals
# 1973                                    100            100
# 1974                              87.693467          100.0
#
#                                       6           7             8   \
# Unnamed: 0  2 Output of industrial crops  oil seeds   oilseed rape
# 1973                                 100         100           100
# 1974                           77.171516  170.967742    170.967742
#
#                          9   ...             54                         55  \
# Unnamed: 0  other oil seeds  ...  23 All Labour  Compensation of employees
# 1973                    100  ...            100                        100
# 1974                  100.0  ...      98.277063                  98.010011
#
#                                                            56          57  \
# Unnamed: 0  Entrepreneurial workers (farm and specialist c...     24 Land
# 1973                                                      100         100
# 1974                                                98.502774  102.350415
#
#                                                   58  \
# Unnamed: 0  25 All Inputs and Entrepreneurial Labour
# 1973                                             100
# 1974                                       97.024461
#
#                                                       59  \
# Unnamed: 0  Total factor productivity (11 divided by 25)
# 1973                                                 100
# 1974                                          106.270373
#
#                                                            60  \
# Unnamed: 0  Productivity by intermediate consumption (11 d...
# 1973                                                      100
# 1974                                               107.877523
#
#                                                            61  \
# Unnamed: 0  Productivity by capital consumption (11 divide...
# 1973                                                      100
# 1974                                               100.436272
#
#                                                    62  \
# Unnamed: 0  Productivity by labour (11 divided by 23)
# 1973                                              100
# 1974                                       104.915892
#
#                                                  63
# Unnamed: 0  Productivity by land (11 divided by 24)
# 1973                                            100
# 1974                                     100.740438
#
# [3 rows x 64 columns]

# %% [markdown]
# Now we have the years as the row names, and the types of output as row one.
# How to fix this and make the types of output column headers?

# %% [markdown]
# iloc[N]  gives row N values as a list.  We can use this to specify new column names.

# %%
df.columns = df.iloc[0]

# %% [markdown]
# Check with df.head

# %%
df.head(3)
# Out:
# Unnamed: 0  1 Output of cereals       wheat  rye       barley  \
# Unnamed: 0  1 Output of cereals       wheat  rye       barley
# 1973                        100         100   100         100
# 1974                 106.495639  111.061991  80.0  102.990299
#
# Unnamed: 0  oats and summer cereal mixtures  other cereals  \
# Unnamed: 0  oats and summer cereal mixtures  other cereals
# 1973                                    100            100
# 1974                              87.693467          100.0
#
# Unnamed: 0  2 Output of industrial crops  oil seeds   oilseed rape  \
# Unnamed: 0  2 Output of industrial crops  oil seeds   oilseed rape
# 1973                                 100         100           100
# 1974                           77.171516  170.967742    170.967742
#
# Unnamed: 0  other oil seeds  ...  23 All Labour  Compensation of employees  \
# Unnamed: 0  other oil seeds  ...  23 All Labour  Compensation of employees
# 1973                    100  ...            100                        100
# 1974                  100.0  ...      98.277063                  98.010011
#
# Unnamed: 0 Entrepreneurial workers (farm and specialist contractor)  \
# Unnamed: 0  Entrepreneurial workers (farm and specialist c...
# 1973                                                      100
# 1974                                                98.502774
#
# Unnamed: 0     24 Land  25 All Inputs and Entrepreneurial Labour  \
# Unnamed: 0     24 Land  25 All Inputs and Entrepreneurial Labour
# 1973               100                                       100
# 1974        102.350415                                 97.024461
#
# Unnamed: 0  Total factor productivity (11 divided by 25)  \
# Unnamed: 0  Total factor productivity (11 divided by 25)
# 1973                                                 100
# 1974                                          106.270373
#
# Unnamed: 0 Productivity by intermediate consumption (11 divided by 21)  \
# Unnamed: 0  Productivity by intermediate consumption (11 d...
# 1973                                                      100
# 1974                                               107.877523
#
# Unnamed: 0 Productivity by capital consumption (11 divided by 22)  \
# Unnamed: 0  Productivity by capital consumption (11 divide...
# 1973                                                      100
# 1974                                               100.436272
#
# Unnamed: 0  Productivity by labour (11 divided by 23)  \
# Unnamed: 0  Productivity by labour (11 divided by 23)
# 1973                                              100
# 1974                                       104.915892
#
# Unnamed: 0  Productivity by land (11 divided by 24)
# Unnamed: 0  Productivity by land (11 divided by 24)
# 1973                                            100
# 1974                                     100.740438
#
# [3 rows x 64 columns]

# %% [markdown]
# We can now drop the redundant row 1.  There are lots of ways to do this!
#
# Drop by index name of row

# %%
hm = df.drop(['Unnamed: 0'])

# %%
hm.head(3)
# Out:
# Unnamed: 0 1 Output of cereals       wheat  rye       barley  \
# 1973                       100         100   100         100
# 1974                106.495639  111.061991  80.0  102.990299
# 1975                 96.861286   98.020137  80.0   96.847398
#
# Unnamed: 0 oats and summer cereal mixtures other cereals  \
# 1973                                   100           100
# 1974                             87.693467         100.0
# 1975                               62.6791         100.0
#
# Unnamed: 0 2 Output of industrial crops  oil seeds  oilseed rape  \
# 1973                                100         100          100
# 1974                          77.171516  170.967742   170.967742
# 1975                          81.083126  216.129032   216.129032
#
# Unnamed: 0 other oil seeds  ... 23 All Labour Compensation of employees  \
# 1973                   100  ...           100                       100
# 1974                 100.0  ...     98.277062                 98.010011
# 1975                 100.0  ...     96.592017                 96.102746
#
# Unnamed: 0 Entrepreneurial workers (farm and specialist contractor)  \
# 1973                                                      100
# 1974                                                98.502774
# 1975                                                97.005548
#
# Unnamed: 0     24 Land 25 All Inputs and Entrepreneurial Labour  \
# 1973               100                                      100
# 1974        102.350415                                97.024461
# 1975        102.120508                                96.746531
#
# Unnamed: 0 Total factor productivity (11 divided by 25)  \
# 1973                                                100
# 1974                                         106.270373
# 1975                                         102.466371
#
# Unnamed: 0 Productivity by intermediate consumption (11 divided by 21)  \
# 1973                                                      100
# 1974                                               107.877523
# 1975                                                103.64562
#
# Unnamed: 0 Productivity by capital consumption (11 divided by 22)  \
# 1973                                                      100
# 1974                                               100.436272
# 1975                                                95.213292
#
# Unnamed: 0 Productivity by labour (11 divided by 23)  \
# 1973                                             100
# 1974                                      104.915892
# 1975                                      102.630282
#
# Unnamed: 0 Productivity by land (11 divided by 24)
# 1973                                           100
# 1974                                    100.740438
# 1975                                     97.074194
#
# [3 rows x 64 columns]

# %% [markdown]
# Drop by index range

# %%
gr = df[1:]

# %%
gr.head(3)
# Out:
# Unnamed: 0 1 Output of cereals       wheat  rye       barley  \
# 1973                       100         100   100         100
# 1974                106.495639  111.061991  80.0  102.990299
# 1975                 96.861286   98.020137  80.0   96.847398
#
# Unnamed: 0 oats and summer cereal mixtures other cereals  \
# 1973                                   100           100
# 1974                             87.693467         100.0
# 1975                               62.6791         100.0
#
# Unnamed: 0 2 Output of industrial crops  oil seeds  oilseed rape  \
# 1973                                100         100          100
# 1974                          77.171516  170.967742   170.967742
# 1975                          81.083126  216.129032   216.129032
#
# Unnamed: 0 other oil seeds  ... 23 All Labour Compensation of employees  \
# 1973                   100  ...           100                       100
# 1974                 100.0  ...     98.277063                 98.010011
# 1975                 100.0  ...     96.592017                 96.102746
#
# Unnamed: 0 Entrepreneurial workers (farm and specialist contractor)  \
# 1973                                                      100
# 1974                                                98.502774
# 1975                                                97.005548
#
# Unnamed: 0     24 Land 25 All Inputs and Entrepreneurial Labour  \
# 1973               100                                      100
# 1974        102.350415                                97.024461
# 1975        102.120508                                96.746531
#
# Unnamed: 0 Total factor productivity (11 divided by 25)  \
# 1973                                                100
# 1974                                         106.270373
# 1975                                         102.466371
#
# Unnamed: 0 Productivity by intermediate consumption (11 divided by 21)  \
# 1973                                                      100
# 1974                                               107.877523
# 1975                                                103.64562
#
# Unnamed: 0 Productivity by capital consumption (11 divided by 22)  \
# 1973                                                      100
# 1974                                               100.436272
# 1975                                                95.213292
#
# Unnamed: 0 Productivity by labour (11 divided by 23)  \
# 1973                                             100
# 1974                                      104.915892
# 1975                                      102.630282
#
# Unnamed: 0 Productivity by land (11 divided by 24)
# 1973                                           100
# 1974                                    100.740438
# 1975                                     97.074194
#
# [3 rows x 64 columns]

# %% [markdown]
# Drop by index location

# %%
ha = df.drop(df.index[0])

# %%
ha.head(3)
# Out:
# Unnamed: 0 1 Output of cereals       wheat  rye       barley  \
# 1973                       100         100   100         100
# 1974                106.495639  111.061991  80.0  102.990299
# 1975                 96.861286   98.020137  80.0   96.847398
#
# Unnamed: 0 oats and summer cereal mixtures other cereals  \
# 1973                                   100           100
# 1974                             87.693467         100.0
# 1975                               62.6791         100.0
#
# Unnamed: 0 2 Output of industrial crops  oil seeds  oilseed rape  \
# 1973                                100         100          100
# 1974                          77.171516  170.967742   170.967742
# 1975                          81.083126  216.129032   216.129032
#
# Unnamed: 0 other oil seeds  ... 23 All Labour Compensation of employees  \
# 1973                   100  ...           100                       100
# 1974                 100.0  ...     98.277063                 98.010011
# 1975                 100.0  ...     96.592017                 96.102746
#
# Unnamed: 0 Entrepreneurial workers (farm and specialist contractor)  \
# 1973                                                      100
# 1974                                                98.502774
# 1975                                                97.005548
#
# Unnamed: 0     24 Land 25 All Inputs and Entrepreneurial Labour  \
# 1973               100                                      100
# 1974        102.350415                                97.024461
# 1975        102.120508                                96.746531
#
# Unnamed: 0 Total factor productivity (11 divided by 25)  \
# 1973                                                100
# 1974                                         106.270373
# 1975                                         102.466371
#
# Unnamed: 0 Productivity by intermediate consumption (11 divided by 21)  \
# 1973                                                      100
# 1974                                               107.877523
# 1975                                                103.64562
#
# Unnamed: 0 Productivity by capital consumption (11 divided by 22)  \
# 1973                                                      100
# 1974                                               100.436272
# 1975                                                95.213292
#
# Unnamed: 0 Productivity by labour (11 divided by 23)  \
# 1973                                             100
# 1974                                      104.915892
# 1975                                      102.630282
#
# Unnamed: 0 Productivity by land (11 divided by 24)
# 1973                                           100
# 1974                                    100.740438
# 1975                                     97.074194
#
# [3 rows x 64 columns]

# %% [markdown]
# It will be useful to have the years as a column, not an index

# %% [markdown]
# Make the index into a new column using df.rest_index().  Check it's worked.

# %%
df=ha.reset_index()

# %%
df.head(3)
# Out:
# Unnamed: 0  index 1 Output of cereals       wheat  rye       barley  \
# 0            1973                 100         100   100         100
# 1            1974          106.495639  111.061991  80.0  102.990299
# 2            1975           96.861286   98.020137  80.0   96.847398
#
# Unnamed: 0 oats and summer cereal mixtures other cereals  \
# 0                                      100           100
# 1                                87.693467         100.0
# 2                                  62.6791         100.0
#
# Unnamed: 0 2 Output of industrial crops  oil seeds  oilseed rape  ...  \
# 0                                   100         100          100  ...
# 1                             77.171516  170.967742   170.967742  ...
# 2                             81.083126  216.129032   216.129032  ...
#
# Unnamed: 0 23 All Labour Compensation of employees  \
# 0                    100                       100
# 1              98.277063                 98.010011
# 2              96.592017                 96.102746
#
# Unnamed: 0 Entrepreneurial workers (farm and specialist contractor)  \
# 0                                                         100
# 1                                                   98.502774
# 2                                                   97.005548
#
# Unnamed: 0     24 Land 25 All Inputs and Entrepreneurial Labour  \
# 0                  100                                      100
# 1           102.350415                                97.024461
# 2           102.120508                                96.746531
#
# Unnamed: 0 Total factor productivity (11 divided by 25)  \
# 0                                                   100
# 1                                            106.270373
# 2                                            102.466371
#
# Unnamed: 0 Productivity by intermediate consumption (11 divided by 21)  \
# 0                                                         100
# 1                                                  107.877523
# 2                                                   103.64562
#
# Unnamed: 0 Productivity by capital consumption (11 divided by 22)  \
# 0                                                         100
# 1                                                  100.436272
# 2                                                   95.213292
#
# Unnamed: 0 Productivity by labour (11 divided by 23)  \
# 0                                                100
# 1                                         104.915892
# 2                                         102.630282
#
# Unnamed: 0 Productivity by land (11 divided by 24)
# 0                                              100
# 1                                       100.740438
# 2                                        97.074194
#
# [3 rows x 65 columns]

# %% [markdown]
# We also need to rename the new column. Specify which column to work on by putting the index in the square brackets and specify the new name.
#
#     df.columns.values[ ] = "New_Name"

# %%
df.columns.values[0] = "Year"

# %%
df.head(3)
# Out:
# Unnamed: 0  Year 1 Output of cereals       wheat  rye       barley  \
# 0           1973                 100         100   100         100
# 1           1974          106.495639  111.061991  80.0  102.990299
# 2           1975           96.861286   98.020137  80.0   96.847398
#
# Unnamed: 0 oats and summer cereal mixtures other cereals  \
# 0                                      100           100
# 1                                87.693467         100.0
# 2                                  62.6791         100.0
#
# Unnamed: 0 2 Output of industrial crops  oil seeds  oilseed rape  ...  \
# 0                                   100         100          100  ...
# 1                             77.171516  170.967742   170.967742  ...
# 2                             81.083126  216.129032   216.129032  ...
#
# Unnamed: 0 23 All Labour Compensation of employees  \
# 0                    100                       100
# 1              98.277062                 98.010011
# 2              96.592017                 96.102746
#
# Unnamed: 0 Entrepreneurial workers (farm and specialist contractor)  \
# 0                                                         100
# 1                                                   98.502774
# 2                                                   97.005548
#
# Unnamed: 0     24 Land 25 All Inputs and Entrepreneurial Labour  \
# 0                  100                                      100
# 1           102.350415                                97.024461
# 2           102.120508                                96.746531
#
# Unnamed: 0 Total factor productivity (11 divided by 25)  \
# 0                                                   100
# 1                                            106.270373
# 2                                            102.466371
#
# Unnamed: 0 Productivity by intermediate consumption (11 divided by 21)  \
# 0                                                         100
# 1                                                  107.877523
# 2                                                   103.64562
#
# Unnamed: 0 Productivity by capital consumption (11 divided by 22)  \
# 0                                                         100
# 1                                                  100.436272
# 2                                                   95.213292
#
# Unnamed: 0 Productivity by labour (11 divided by 23)  \
# 0                                                100
# 1                                         104.915892
# 2                                         102.630282
#
# Unnamed: 0 Productivity by land (11 divided by 24)
# 0                                              100
# 1                                       100.740438
# 2                                        97.074194
#
# [3 rows x 65 columns]

# %% [markdown]
# Now we can check what we have.  Use
#
#     df.info()
#
# to see what the columns are and which are numeric

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 65 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   Year                                                         50 non-null     int64
#  1   1 Output of cereals                                          50 non-null     object
#  2   wheat                                                        50 non-null     object
#  3   rye                                                          50 non-null     object
#  4   barley                                                       50 non-null     object
#  5   oats and summer cereal mixtures                              50 non-null     object
#  6   other cereals                                                50 non-null     object
#  7   2 Output of industrial crops                                 50 non-null     object
#  8   oil seeds                                                    50 non-null     object
#  9   oilseed rape                                                 50 non-null     object
#  10  other oil seeds                                              50 non-null     object
#  11  protein crops                                                50 non-null     object
#  12  sugar beet                                                   50 non-null     object
#  13  other industrial crops                                       50 non-null     object
#  14  3 Output of forage plants                                    50 non-null     object
#  15  4 Output of vegetables and horticultural products            50 non-null     object
#  16  fresh vegetables                                             50 non-null     object
#  17  plants and flowers                                           50 non-null     object
#  18  5 Output of potatoes (c)                                     50 non-null     object
#  19  6 Output of fruit                                            50 non-null     object
#  20  7 Output of other crop products                              50 non-null     object
#  21  Total crop output (sum 1 - 7)                                50 non-null     object
#  22  8 Output of livestock (meat) (d)                             50 non-null     object
#  23  cattle                                                       50 non-null     object
#  24  pigs                                                         50 non-null     object
#  25  sheep                                                        50 non-null     object
#  26  poultry                                                      50 non-null     object
#  27  other animals                                                50 non-null     object
#  28  9 Output of livestock products                               50 non-null     object
#  29  milk                                                         50 non-null     object
#  30  eggs                                                         50 non-null     object
#  31  raw wool                                                     50 non-null     object
#  32  other animal products                                        50 non-null     object
#  33  Total livestock output (8 + 9)                               50 non-null     object
#  34  10 Inseparable non-agricultural activities                   50 non-null     object
#  35  11 All outputs                                               50 non-null     object
#  36  12 Seeds                                                     50 non-null     object
#  37  13 Energy                                                    50 non-null     object
#  38  electricity and fuels for heating                            50 non-null     object
#  39  motor and machinery fuels                                    50 non-null     object
#  40  14 Fertilisers                                               50 non-null     object
#  41  15 Plant protection products                                 50 non-null     object
#  42  16 Veterinary expenses                                       50 non-null     object
#  43  17 Animal feed                                               50 non-null     object
#  44  compounds                                                    50 non-null     object
#  45  straights                                                    50 non-null     object
#  46  18 Total maintenance                                         50 non-null     object
#  47  materials                                                    50 non-null     object
#  48  buildings                                                    50 non-null     object
#  49  19 FISIM                                                     50 non-null     object
#  50  20 Other goods and services                                  50 non-null     object
#  51  21 Intermediate consumption (excl Agricultural services)     50 non-null     object
#  52  22 Consumption of fixed capital (excluding livestock)        50 non-null     object
#  53  equipment                                                    50 non-null     object
#  54  buildings                                                    50 non-null     object
#  55  23 All Labour                                                50 non-null     object
#  56  Compensation of employees                                    50 non-null     object
#  57  Entrepreneurial workers (farm and specialist contractor)     50 non-null     object
#  58  24 Land                                                      50 non-null     object
#  59  25 All Inputs and Entrepreneurial Labour                     50 non-null     object
#  60  Total factor productivity (11 divided by 25)                 50 non-null     object
#  61  Productivity by intermediate consumption (11 divided by 21)  50 non-null     object
#  62  Productivity by capital consumption (11 divided by 22)       50 non-null     object
#  63  Productivity by labour (11 divided by 23)                    50 non-null     object
#  64  Productivity by land (11 divided by 24)                      50 non-null     object
# dtypes: int64(1), object(64)
# memory usage: 25.5+ KB

# %% [markdown]
# All our data columns are coded as objects now (due to the text in the column names when they were row1).  We can fix this by applying pd.to_numeric across the dataframe.

# %%
df = df.apply(pd.to_numeric)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 65 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   Year                                                         49 non-null     int64
#  1   1 Output of cereals                                          49 non-null     float64
#  2   wheat                                                        49 non-null     float64
#  3   rye                                                          49 non-null     float64
#  4   barley                                                       49 non-null     float64
#  5   oats and summer cereal mixtures                              49 non-null     float64
#  6   other cereals                                                49 non-null     float64
#  7   2 Output of industrial crops                                 49 non-null     float64
#  8   oil seeds                                                    49 non-null     float64
#  9   oilseed rape                                                 49 non-null     float64
#  10  other oil seeds                                              49 non-null     float64
#  11  protein crops                                                49 non-null     float64
#  12  sugar beet                                                   49 non-null     float64
#  13  other industrial crops                                       49 non-null     float64
#  14  3 Output of forage plants                                    49 non-null     float64
#  15  4 Output of vegetables and horticultural products            49 non-null     float64
#  16  fresh vegetables                                             49 non-null     float64
#  17  plants and flowers                                           49 non-null     float64
#  18  5 Output of potatoes (c)                                     49 non-null     float64
#  19  6 Output of fruit                                            49 non-null     float64
#  20  7 Output of other crop products                              49 non-null     float64
#  21  Total crop output (sum 1 - 7)                                49 non-null     float64
#  22  8 Output of livestock (meat) (d)                             49 non-null     float64
#  23  cattle                                                       49 non-null     float64
#  24  pigs                                                         49 non-null     float64
#  25  sheep                                                        49 non-null     float64
#  26  poultry                                                      49 non-null     float64
#  27  other animals                                                49 non-null     float64
#  28  9 Output of livestock products                               49 non-null     float64
#  29  milk                                                         49 non-null     float64
#  30  eggs                                                         49 non-null     float64
#  31  raw wool                                                     49 non-null     float64
#  32  other animal products                                        49 non-null     float64
#  33  Total livestock output (8 + 9)                               49 non-null     float64
#  34  10 Inseparable non-agricultural activities                   49 non-null     float64
#  35  11 All outputs                                               49 non-null     float64
#  36  12 Seeds                                                     49 non-null     float64
#  37  13 Energy                                                    49 non-null     float64
#  38  electricity and fuels for heating                            49 non-null     float64
#  39  motor and machinery fuels                                    49 non-null     float64
#  40  14 Fertilisers                                               49 non-null     float64
#  41  15 Plant protection products                                 49 non-null     float64
#  42  16 Veterinary expenses                                       49 non-null     float64
#  43  17 Animal feed                                               49 non-null     float64
#  44  compounds                                                    49 non-null     float64
#  45  straights                                                    49 non-null     float64
#  46  18 Total maintenance                                         49 non-null     float64
#  47  materials                                                    49 non-null     float64
#  48  buildings                                                    49 non-null     float64
#  49  19 FISIM                                                     49 non-null     int64
#  50  20 Other goods and services                                  49 non-null     float64
#  51  21 Intermediate consumption (excl Agricultural services)     49 non-null     float64
#  52  22 Consumption of fixed capital (excluding livestock)        49 non-null     float64
#  53  equipment                                                    49 non-null     float64
#  54  buildings                                                    49 non-null     float64
#  55  23 All Labour                                                49 non-null     float64
#  56  Compensation of employees                                    49 non-null     float64
#  57  Entrepreneurial workers (farm and specialist contractor)     49 non-null     float64
#  58  24 Land                                                      49 non-null     float64
#  59  25 All Inputs and Entrepreneurial Labour                     49 non-null     float64
#  60  Total factor productivity (11 divided by 25)                 49 non-null     float64
#  61  Productivity by intermediate consumption (11 divided by 21)  49 non-null     float64
#  62  Productivity by capital consumption (11 divided by 22)       49 non-null     float64
#  63  Productivity by labour (11 divided by 23)                    49 non-null     float64
#  64  Productivity by land (11 divided by 24)                      49 non-null     float64
# dtypes: float64(63), int64(2)
# memory usage: 25.0 KB

# %% [markdown]
# Now we can plot changes in agricultural output since 1973!

# %% [markdown]
# Use sns.lineplot to look at changes in any agricultural output.
# Use list(df.columns) to see your options

# %%
list(df.columns)
# Out:
# ['Year',
#  '1 Output of cereals',
#  'wheat',
#  'rye ',
#  'barley',
#  'oats and summer cereal mixtures',
#  'other cereals',
#  '2 Output of industrial crops',
#  'oil seeds ',
#  'oilseed rape',
#  'other oil seeds',
#  'protein crops',
#  'sugar beet',
#  'other industrial crops',
#  '3 Output of forage plants',
#  '4 Output of vegetables and horticultural products',
#  'fresh vegetables',
#  'plants and flowers',
#  '5 Output of potatoes (c) ',
#  '6 Output of fruit',
#  '7 Output of other crop products ',
#  'Total crop output (sum 1 - 7)',
#  '8 Output of livestock (meat) (d)',
#  'cattle',
#  'pigs ',
#  'sheep',
#  'poultry ',
#  'other animals',
#  '9 Output of livestock products',
#  'milk',
#  'eggs',
#  'raw wool',
#  'other animal products',
#  'Total livestock output (8 + 9)',
#  '10 Inseparable non-agricultural activities',
#  '11 All outputs',
#  '12 Seeds',
#  '13 Energy',
#  'electricity and fuels for heating',
#  'motor and machinery fuels',
#  '14 Fertilisers',
#  '15 Plant protection products',
#  '16 Veterinary expenses',
#  '17 Animal feed',
#  'compounds',
#  'straights ',
#  '18 Total maintenance',
#  'materials',
#  'buildings',
#  '19 FISIM',
#  '20 Other goods and services',
#  '21 Intermediate consumption (excl Agricultural services)',
#  '22 Consumption of fixed capital (excluding livestock)',
#  'equipment',
#  'buildings',
#  '23 All Labour',
#  'Compensation of employees',
#  'Entrepreneurial workers (farm and specialist contractor)',
#  '24 Land',
#  '25 All Inputs and Entrepreneurial Labour',
#  'Total factor productivity (11 divided by 25)',
#  'Productivity by intermediate consumption (11 divided by 21)',
#  'Productivity by capital consumption (11 divided by 22)',
#  'Productivity by labour (11 divided by 23)',
#  'Productivity by land (11 divided by 24)']

# %%
sns.lineplot(x=df['Year'], y=df['plants and flowers'])
# Out:
# <AxesSubplot:xlabel='Year', ylabel='plants and flowers'>

# %%
sns.lineplot(x=df['Year'], y=df['4 Output of vegetables and horticultural products'])
# Out:
# <AxesSubplot:xlabel='Year', ylabel='4 Output of vegetables and horticultural products'>

# %%
sns.lineplot(x=df['Year'], y=df['sugar beet'])
# Out:
# <AxesSubplot:xlabel='Year', ylabel='sugar beet'>

# %% [markdown]
# Can you see the effect of the foot and mouth outbreak?  the green revolution in grain productivity, the switch to imported fruit and vegetables?

# %% [markdown]
# ### Saving dataframes

# %% [markdown]
# Save as csv

# %%
df.to_csv('UK_agriculture.csv', index=False)

# %% [markdown]
# Save as excel

# %%
df.to_excel('UK_agriculture.xlsx', index=False)

# %% [markdown]
# What happens if you leave off 'index=False'?

# %% [markdown]
# #### Pickling
# Sometime you are working solely within python and want to preserve the syntax exactly rather than writing to a flat csv or excel file

# %%
df.to_pickle('UK_crops.pkl')

# %% [markdown]
# Reading from pickle

# %%
df = pd.read_pickle('UK_crops.pkl')

# %% [markdown]
# Checking contents

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69 entries, 0 to 68
# Data columns (total 49 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Production(2015=100)  65 non-null     object
#  1   1973                  64 non-null     float64
#  2   1974                  64 non-null     float64
#  3   1975                  64 non-null     float64
#  4   1976                  64 non-null     float64
#  5   1977                  64 non-null     float64
#  6   1978                  64 non-null     float64
#  7   1979                  64 non-null     float64
#  8   1980                  64 non-null     float64
#  9   1981                  64 non-null     float64
#  10  1982                  64 non-null     float64
#  11  1983                  64 non-null     float64
#  12  1984                  64 non-null     float64
#  13  1985                  64 non-null     float64
#  14  1986                  64 non-null     float64
#  15  1987                  64 non-null     float64
#  16  1988                  64 non-null     float64
#  17  1989                  64 non-null     float64
#  18  1990                  64 non-null     float64
#  19  1991                  64 non-null     float64
#  20  1992                  64 non-null     float64
#  21  1993                  64 non-null     float64
#  22  1994                  64 non-null     float64
#  23  1995                  64 non-null     float64
#  24  1996                  64 non-null     float64
#  25  1997                  64 non-null     float64
#  26  1998                  64 non-null     float64
#  27  1999                  64 non-null     float64
#  28  2000                  64 non-null     float64
#  29  2001                  64 non-null     float64
#  30  2002                  64 non-null     float64
#  31  2003                  64 non-null     float64
#  32  2004                  64 non-null     float64
#  33  2005                  64 non-null     float64
#  34  2006                  64 non-null     float64
#  35  2007                  64 non-null     float64
#  36  2008                  64 non-null     float64
#  37  2009                  64 non-null     float64
#  38  2010                  64 non-null     float64
#  39  2011                  64 non-null     float64
#  40  2012                  64 non-null     float64
#  41  2013                  64 non-null     float64
#  42  2014                  64 non-null     float64
#  43  2015                  64 non-null     float64
#  44  2016                  64 non-null     float64
#  45  2017                  64 non-null     float64
#  46  2018                  64 non-null     float64
#  47  2019                  64 non-null     float64
#  48  2020                  64 non-null     float64
# dtypes: float64(48), object(1)
# memory usage: 26.5+ KB
# None
