# %% [markdown]
# ### Visualising multidimensional data

# %%
from pydoc import help  # can type in the python console `help(name of function)` to get the documentation
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import scale
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.cluster import KMeans

from scipy import stats
from IPython.display import display, HTML
import statsmodels.api as sm
from statsmodels.formula.api import ols

# figures inline in notebook
# %matplotlib inline

np.set_printoptions(suppress=True)

DISPLAY_MAX_ROWS = 20  # number of max rows to print for a DataFrame
pd.set_option('display.max_rows', DISPLAY_MAX_ROWS)

# %% [markdown]
# You should by now be quite happy about working with and plotting one or two factors against annother.  However, in biology is it common to be dealing with datasets with many parameters.  For example, the expression level of thousands of genes across many tissues, or the frequency of hundreds of species in hundreds of sites, or tens of measurements across hundreds of beaks.  Multivariant Analysis is a way of managing and visualising such large datasets.  We will cover correlations across large datasets, heatplots to visualisae them, heirarthical clustering and PCA

# %% [markdown]
# Start with a couple of toy examples to explore distance and clustering methods.

# %%
data = {'test_score': [25,34,22,27,33,33,31,22,35,34,67,54,57,43,50,57,59,52,65,47,49,48,35,33,44,45,38,43,51,46],
        'head_diameter': [79,51,53,78,59,74,73,57,69,75,51,32,40,47,53,36,35,58,59,50,25,20,14,12,20,5,29,27,8,7]
       }
  
df = pd.DataFrame(data, columns=['test_score', 'head_diameter'])
print(df)
# Out:
#     test_score  head_diameter
# 0           25             79
# 1           34             51
# 2           22             53
# 3           27             78
# 4           33             59
# ..         ...            ...
# 25          45              5
# 26          38             29
# 27          43             27
# 28          51              8
# 29          46              7
#
# [30 rows x 2 columns]

# %%
sns.scatterplot(data=df, x="test_score", y="head_diameter")
# Out:
# <AxesSubplot:xlabel='test_score', ylabel='head_diameter'>

# %% [markdown]
# #### basic hierarchical

# %%
sns.clustermap(df)

# %% [markdown]
# Yes, it is that easy.  You can explore the effect of different distance measures and clustering methods

# %%
clustering method (method) - average, complete, single, weighted
Distance measure (metric) jaccard, cityblock, minkowski, braycurtis

# %%
sns.clustermap(df, method='weighted', metric='braycurtis')

# %% [markdown]
# #### basic k-means

# %% [markdown]
# Find the centroids of clusters in the data.  sklearn fits the data into as many clusters as you specify.  It can then compute the centroid of each cluster.

# %%
kmeans = KMeans(n_clusters=2).fit(df)
centroids = kmeans.cluster_centers_
print(centroids)
# Out:
# [[38.75       61.625     ]
#  [47.07142857 22.14285714]]

# %%
type(kmeans)
# Out:
# sklearn.cluster._kmeans.KMeans

# %%
type(centroids)
# Out:
# numpy.ndarray

# %%
centroids
# Out:
# array([[38.75      , 61.625     ],
#        [47.07142857, 22.14285714]])

# %% [markdown]
# Add the centroids to the data plot.
# The datapoints are coloured by the labels in the kmeans output.
# The centroids are plotted on the same plot.

# %%
plt.scatter(df['test_score'], df['head_diameter'], c= kmeans.labels_.astype(float))
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', s=50)
plt.show()
# Out:
# [[38.75       61.625     ]
#  [47.07142857 22.14285714]]

# %% [markdown]
# Try looking for differnt numbers of clusters

# %%
kmeans = KMeans(n_clusters=3).fit(df)
centroids = kmeans.cluster_centers_
print(centroids)

plt.scatter(df['test_score'], df['head_diameter'], c= kmeans.labels_.astype(float), s=50, alpha=0.5)
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', s=50)
plt.show()
# Out:
# [[29.6 66.8  1.   2.   1.8]
#  [43.2 16.7  0.   1.   0. ]
#  [55.1 46.1  0.6  0.   2. ]]

# %%
kmeans = KMeans(n_clusters=4).fit(df)
centroids = kmeans.cluster_centers_
print(centroids)

plt.scatter(df['test_score'], df['head_diameter'], c= kmeans.labels_.astype(float), s=50, alpha=0.5)
plt.scatter(centroids[:, 0], centroids[:, 1], c='red', s=50)
plt.show()
# Out:
# [[55.1        46.1         0.6         0.          2.        ]
#  [43.2        16.7         0.          1.          0.        ]
#  [30.83333333 74.66666667  1.          2.          1.        ]
#  [27.75       55.          1.          2.          3.        ]]

# %% [markdown]
# Now we have found clusters we can test their significance

# %% [markdown]
# Add the cluster categorisation to the dataframe.
# Do a test for significance of head diameter and test scores in each case.

# %%
kmeans = KMeans(n_clusters=2).fit(df)
df['bi_group'] = kmeans.labels_.astype(str)

# %%
kmeans = KMeans(n_clusters=3).fit(df)
df['tri_group'] = kmeans.labels_.astype(str)

# %%
kmeans = KMeans(n_clusters=4).fit(df)
df['quad_group'] = kmeans.labels_.astype(str)

# %%
df.head(3)
# Out:
#    test_score  head_diameter bi_group tri_group quad_group
# 0          25             79        0         1          3
# 1          34             51        0         1          0
# 2          22             53        0         1          0

# %%
mod = ols('test_score ~ bi_group', data=df).fit()
sm.stats.anova_lm(mod)
# Out:
#             df       sum_sq     mean_sq         F    PR(>F)
# bi_group   1.0   517.038095  517.038095  3.795841  0.061467
# Residual  28.0  3813.928571  136.211735       NaN       NaN

# %%
mod = ols('test_score ~ tri_group', data=df).fit()
sm.stats.anova_lm(mod)
# Out:
#              df       sum_sq      mean_sq          F        PR(>F)
# tri_group   2.0  3256.066667  1628.033333  40.893944  6.754193e-09
# Residual   27.0  1074.900000    39.811111        NaN           NaN

# %%
mod = ols('test_score ~ quad_group', data=df).fit()
sm.stats.anova_lm(mod)
# Out:
#               df       sum_sq      mean_sq          F        PR(>F)
# quad_group   3.0  3278.883333  1092.961111  27.010207  3.777105e-08
# Residual    26.0  1052.083333    40.464744        NaN           NaN

# %% [markdown]
# The groupings with three and four clusters both look good, but three clusters is the best fit.

# %% [markdown]
# ### A more complex clustering

# %% [markdown]
# Here is a basic dataset of expression patterns for a set of biosynthetic genes from a range of plant tissues.

# %%
df = pd.read_csv('../Datasets/TPS.csv')
df.head(3)
# Out:
#                                Gene  Bcon1019-0.0_TPS-bc3  \
# 0  Female.flower.B.conchifolia.rep1             67.311275
# 1  Female.flower.B.conchifolia.rep2             24.881496
# 2  Female.flower.B.conchifolia.rep3              0.000000
#
#    Bcon1019-0.2_TPS-bc3  \
# 0                   0.0
# 1                   0.0
# 2                   0.0
#
#    Bcon1029-0.2_Geranylgeranyl pyrophosphate synthase family protein  \
# 0                                          15.645225
# 1                                           3.396060
# 2                                           4.865841
#
#    Bcon1055-2.10_TPS-bc3  Bcon1055-3.1_TPS-bc3  Bcon1055-3.14_TPS-bc3  \
# 0               0.660818                     0                    0.0
# 1               0.000000                     0                    0.0
# 2               0.101612                     0                    0.0
#
#    Bcon1055-3.3_TPS-bc3  Bcon1055-5.2_TPS-bc3  \
# 0                     0                   0.0
# 1                     0                   0.0
# 2                     0                   0.0
#
#    Bcon1065-0.18_1-deoxy-D-xylulose 5-phosphate reductoisomerase  ...  \
# 0                                                  0              ...
# 1                                                  0              ...
# 2                                                  0              ...
#
#    Bcon983-0.7_TPS-bc2  Bcon983-1.18_TPS-bc2  Bcon983-1.31_TPS-bc2  \
# 0                    0             22.447206                     0
# 1                    0             13.809320                     0
# 2                    0              3.518609                     0
#
#    Bcon983-1.38_TPS-bc2  Bcon983-1.6_TPS-bc2  Bcon983-1.7_TPS-bc2  \
# 0                     0             0.188740             1.391640
# 1                     0             0.000000             0.964168
# 2                     0             0.437499             0.910456
#
#    Bcon995-0.5_TPS-bc3  Bcon995-0.6_TPS-bc3  Bcon995-0.7_TPS-bc3  \
# 0             3.125789                  0.0             0.940281
# 1             1.100803                  0.0             0.000000
# 2             0.333213                  0.0             0.000000
#
#    Bcon1049-2.11_Geranyl diphosphate synthase
# 0                                           0
# 1                                           0
# 2                                           0
#
# [3 rows x 103 columns]

# %% [markdown]
# We will make the sample data rows more useful by splitting into groups

# %%
new = df["Gene"].str.split(".B.|.rep", n = 2, expand = True)
new.head(3)
# Out:
#                0            1  2
# 0  Female.flower  conchifolia  1
# 1  Female.flower  conchifolia  2
# 2  Female.flower  conchifolia  3

# %% [markdown]
# and giving the new columns useful names

# %%
# Dropping old Name columns
df.drop(columns =["Gene"], inplace = True)
df.insert(0,'Tissue', new[0] )
df.insert(0,'Species', new[1] )
df.insert(0,'Rep', new[2] )
df.head(3)
# Out:
#   Rep      Species         Tissue  Bcon1019-0.0_TPS-bc3  Bcon1019-0.2_TPS-bc3  \
# 0   1  conchifolia  Female.flower             67.311275                   0.0
# 1   2  conchifolia  Female.flower             24.881496                   0.0
# 2   3  conchifolia  Female.flower              0.000000                   0.0
#
#    Bcon1029-0.2_Geranylgeranyl pyrophosphate synthase family protein  \
# 0                                          15.645225
# 1                                           3.396060
# 2                                           4.865841
#
#    Bcon1055-2.10_TPS-bc3  Bcon1055-3.1_TPS-bc3  Bcon1055-3.14_TPS-bc3  \
# 0               0.660818                     0                    0.0
# 1               0.000000                     0                    0.0
# 2               0.101612                     0                    0.0
#
#    Bcon1055-3.3_TPS-bc3  ...  Bcon983-0.7_TPS-bc2  Bcon983-1.18_TPS-bc2  \
# 0                     0  ...                    0             22.447206
# 1                     0  ...                    0             13.809320
# 2                     0  ...                    0              3.518609
#
#    Bcon983-1.31_TPS-bc2  Bcon983-1.38_TPS-bc2  Bcon983-1.6_TPS-bc2  \
# 0                     0                     0             0.188740
# 1                     0                     0             0.000000
# 2                     0                     0             0.437499
#
#    Bcon983-1.7_TPS-bc2  Bcon995-0.5_TPS-bc3  Bcon995-0.6_TPS-bc3  \
# 0             1.391640             3.125789                  0.0
# 1             0.964168             1.100803                  0.0
# 2             0.910456             0.333213                  0.0
#
#    Bcon995-0.7_TPS-bc3  Bcon1049-2.11_Geranyl diphosphate synthase
# 0             0.940281                                           0
# 1             0.000000                                           0
# 2             0.000000                                           0
#
# [3 rows x 105 columns]

# %%
df.head()
# Out:
#    Bcon1019-0.0_TPS-bc3  Bcon1019-0.2_TPS-bc3  \
# 0             67.311275                   0.0
# 1             24.881496                   0.0
# 2              0.000000                   0.0
# 3              0.000000                   0.0
# 4              0.000000                   0.0
#
#    Bcon1029-0.2_Geranylgeranyl pyrophosphate synthase family protein  \
# 0                                          15.645225
# 1                                           3.396060
# 2                                           4.865841
# 3                                           9.810125
# 4                                           8.091472
#
#    Bcon1055-2.10_TPS-bc3  Bcon1055-3.1_TPS-bc3  Bcon1055-3.14_TPS-bc3  \
# 0               0.660818                     0                    0.0
# 1               0.000000                     0                    0.0
# 2               0.101612                     0                    0.0
# 3               0.140581                     0                    0.0
# 4               1.800174                     0                    0.0
#
#    Bcon1055-3.3_TPS-bc3  Bcon1055-5.2_TPS-bc3  \
# 0                     0                   0.0
# 1                     0                   0.0
# 2                     0                   0.0
# 3                     0                   0.0
# 4                     0                   0.0
#
#    Bcon1065-0.18_1-deoxy-D-xylulose 5-phosphate reductoisomerase  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#
#    Bcon109-3.8_3-hydroxy-3-methylglutaryl coenzyme A reductase  ...  \
# 0                                         140.151858            ...
# 1                                         168.266137            ...
# 2                                         178.561685            ...
# 3                                          35.867421            ...
# 4                                          40.712185            ...
#
#    Bcon983-1.38_TPS-bc2  Bcon983-1.6_TPS-bc2  Bcon983-1.7_TPS-bc2  \
# 0                     0             0.188740             1.391640
# 1                     0             0.000000             0.964168
# 2                     0             0.437499             0.910456
# 3                     0             0.296516             1.205079
# 4                     0             0.000000             0.800220
#
#    Bcon995-0.5_TPS-bc3  Bcon995-0.6_TPS-bc3  Bcon995-0.7_TPS-bc3  \
# 0             3.125789             0.000000             0.940281
# 1             1.100803             0.000000             0.000000
# 2             0.333213             0.000000             0.000000
# 3             0.819789             0.000000             0.884948
# 4             2.437815             0.700965             2.614249
#
#    Bcon1049-2.11_Geranyl diphosphate synthase         Tissue      species  Rep
# 0                                           0  Female.flower  conchifolia    1
# 1                                           0  Female.flower  conchifolia    2
# 2                                           0  Female.flower  conchifolia    3
# 3                                           0           Leaf  conchifolia    1
# 4                                           0           Leaf  conchifolia    2
#
# [5 rows x 105 columns]

# %%
df.describe()
# Out:
#        Bcon1019-0.0_TPS-bc3  Bcon1019-0.2_TPS-bc3  \
# count             36.000000             36.000000
# mean              49.655797              2.994775
# std              146.008415              4.959268
# min                0.000000              0.000000
# 25%                0.000000              0.000000
# 50%                0.000000              0.360312
# 75%                1.646738              4.602375
# max              775.748743             20.639070
#
#        Bcon1029-0.2_Geranylgeranyl pyrophosphate synthase family protein  \
# count                                          36.000000
# mean                                            8.844578
# std                                             3.508785
# min                                             2.785489
# 25%                                             5.470198
# 50%                                             8.899535
# 75%                                            11.469944
# max                                            15.645225
#
#        Bcon1055-2.10_TPS-bc3  Bcon1055-3.1_TPS-bc3  Bcon1055-3.14_TPS-bc3  \
# count              36.000000                  36.0              36.000000
# mean                0.537160                   0.0               1.194785
# std                 0.979806                   0.0               2.582390
# min                 0.000000                   0.0               0.000000
# 25%                 0.000000                   0.0               0.000000
# 50%                 0.079268                   0.0               0.000000
# 75%                 0.621480                   0.0               0.392406
# max                 3.767931                   0.0               8.317929
#
#        Bcon1055-3.3_TPS-bc3  Bcon1055-5.2_TPS-bc3  \
# count                  36.0             36.000000
# mean                    0.0              1.712132
# std                     0.0              2.601749
# min                     0.0              0.000000
# 25%                     0.0              0.000000
# 50%                     0.0              0.202499
# 75%                     0.0              2.430931
# max                     0.0              8.911507
#
#        Bcon1065-0.18_1-deoxy-D-xylulose 5-phosphate reductoisomerase  \
# count                                               36.0
# mean                                                 0.0
# std                                                  0.0
# min                                                  0.0
# 25%                                                  0.0
# 50%                                                  0.0
# 75%                                                  0.0
# max                                                  0.0
#
#        Bcon109-3.8_3-hydroxy-3-methylglutaryl coenzyme A reductase  ...  \
# count                                          36.000000            ...
# mean                                          168.296520            ...
# std                                           103.882396            ...
# min                                            16.280952            ...
# 25%                                           118.316571            ...
# 50%                                           147.455481            ...
# 75%                                           191.264679            ...
# max                                           552.243608            ...
#
#        Bcon983-0.7_TPS-bc2  Bcon983-1.18_TPS-bc2  Bcon983-1.31_TPS-bc2  \
# count                 36.0             36.000000                  36.0
# mean                   0.0              6.640752                   0.0
# std                    0.0             17.353320                   0.0
# min                    0.0              0.000000                   0.0
# 25%                    0.0              0.201176                   0.0
# 50%                    0.0              0.421347                   0.0
# 75%                    0.0              1.172816                   0.0
# max                    0.0             69.053289                   0.0
#
#        Bcon983-1.38_TPS-bc2  Bcon983-1.6_TPS-bc2  Bcon983-1.7_TPS-bc2  \
# count                  36.0            36.000000            36.000000
# mean                    0.0             1.282518             1.690958
# std                     0.0             3.359908             2.262099
# min                     0.0             0.000000             0.000000
# 25%                     0.0             0.000000             0.407832
# 50%                     0.0             0.275829             0.896740
# 75%                     0.0             0.758830             1.790371
# max                     0.0            19.109890             9.247095
#
#        Bcon995-0.5_TPS-bc3  Bcon995-0.6_TPS-bc3  Bcon995-0.7_TPS-bc3  \
# count            36.000000            36.000000            36.000000
# mean              7.241468             0.202839             6.348424
# std              18.535442             0.777848            19.487094
# min               0.000000             0.000000             0.000000
# 25%               0.452119             0.000000             0.000000
# 50%               0.830992             0.000000             0.497733
# 75%               3.299946             0.000000             2.348776
# max              94.998578             4.620112           106.685782
#
#        Bcon1049-2.11_Geranyl diphosphate synthase
# count                                        36.0
# mean                                          0.0
# std                                           0.0
# min                                           0.0
# 25%                                           0.0
# 50%                                           0.0
# 75%                                           0.0
# max                                           0.0
#
# [8 rows x 102 columns]

# %% [markdown]
# We could try to pairplot everything against everything, but with nearly 100 genes it would be a strain.

# %%
# Do not run!
# sns.pairplot(df, hue="Tissue")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 sns.pairplot(df, hue="Tissue")
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:2096, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2094 # Set up the PairGrid
#    2095 grid_kws.setdefault("diag_sharey", diag_kind == "hist")
# -> 2096 grid = PairGrid(data, vars=vars, x_vars=x_vars, y_vars=y_vars, hue=hue,
#    2097                 hue_order=hue_order, palette=palette, corner=corner,
#    2098                 height=height, aspect=aspect, dropna=dropna, **grid_kws)
#    2100 # Add the markers here as PairGrid has figured out how many levels of the
#    2101 # hue variable are needed and we don't want to duplicate that process
#    2102 if markers is not None:
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:1244, in PairGrid.__init__(self, data, hue, hue_order, palette, hue_kws, vars, x_vars, y_vars, corner, diag_sharey, height, aspect, layout_pad, despine, dropna, size)
#    1241 with mpl.rc_context({"figure.autolayout": False}):
#    1242     fig = plt.figure(figsize=figsize)
# -> 1244 axes = fig.subplots(len(y_vars), len(x_vars),
#    1245                     sharex="col", sharey="row",
#    1246                     squeeze=False)
#    1248 # Possibly remove upper axes to make a corner grid
#    1249 # Note: setting up the axes is usually the most time-intensive part
#    1250 # of using the PairGrid. We are foregoing the speed improvement that
#    1251 # we would get by just not setting up the hidden axes so that we can
#    1252 # avoid implementing fig.subplots ourselves. But worth thinking about.
#    1253 self._corner = corner
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/figure.py:897, in FigureBase.subplots(self, nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw)
#     895     gridspec_kw = {}
#     896 gs = self.add_gridspec(nrows, ncols, figure=self, **gridspec_kw)
# --> 897 axs = gs.subplots(sharex=sharex, sharey=sharey, squeeze=squeeze,
#     898                   subplot_kw=subplot_kw)
#     899 return axs
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/gridspec.py:307, in GridSpecBase.subplots(self, sharex, sharey, squeeze, subplot_kw)
#     305         subplot_kw["sharex"] = shared_with[sharex]
#     306         subplot_kw["sharey"] = shared_with[sharey]
# --> 307         axarr[row, col] = figure.add_subplot(
#     308             self[row, col], **subplot_kw)
#     310 # turn off redundant tick labeling
#     311 if sharex in ["col", "all"]:
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/figure.py:774, in FigureBase.add_subplot(self, *args, **kwargs)
#     772     ax = subplot_class_factory(projection_class)(self, *args, **pkw)
#     773     key = (projection_class, pkw)
# --> 774 return self._add_axes_internal(ax, key)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/figure.py:780, in FigureBase._add_axes_internal(self, ax, key)
#     778 self._axstack.add(ax)
#     779 self._localaxes.add(ax)
# --> 780 self.sca(ax)
#     781 ax._remove_method = self.delaxes
#     782 # this is to support plt.subplot's re-selection logic
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/figure.py:1535, in FigureBase.sca(self, a)
#    1533 def sca(self, a):
#    1534     """Set the current Axes to be *a* and return *a*."""
# -> 1535     self._axstack.bubble(a)
#    1536     self._axobservers.process("_axes_change_event", self)
#    1537     return a
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/figure.py:82, in _AxesStack.bubble(self, a)
#      78 def bubble(self, a):
#      79     """
#      80     Move the given axes, which must already exist in the stack, to the top.
#      81     """
# ---> 82     return super().bubble(self._entry_from_axes(a))
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:646, in Stack.bubble(self, o)
#     644         top_elements.append(elem)
#     645     else:
# --> 646         self.push(elem)
#     647 for _ in top_elements:
#     648     self.push(o)
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:604, in Stack.push(self, o)
#     598 def push(self, o):
#     599     """
#     600     Push *o* to the stack at current position.  Discard all later elements.
#     601
#     602     *o* is returned.
#     603     """
# --> 604     self._elements = self._elements[:self._pos + 1] + [o]
#     605     self._pos = len(self._elements) - 1
#     606     return self()
#
# KeyboardInterrupt:

# %% [markdown]
# We could plot expression of individual genes.  Which would be interesting

# %%
ax = df[["Bcon1019-0.0_TPS-bc3","Bcon1019-0.2_TPS-bc3","Bcon1055-2.10_TPS-bc3","Bcon1055-3.3_TPS-bc3","Bcon1055-3.14_TPS-bc3"]].plot()
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5));

# %% [markdown]
# To cluster we need to define which are the dependant and which the independant variables.
#
# The independent variable is the cause. Its value is independent of other variables in your study.
# The dependent variable is the effect. Its value depends on changes in the independent variable.
#
# The independant variables are the genes.  They are the categroeis we are collectin data for.
# In this case the dependant variable is the transcripts per million (TPM) for each sample. This is the data we are gathering. The samples are defined by tissue and replicate.

# %%
#Splitting dependant and independant variables
X = df.loc[:, "Bcon1019-0.0_TPS-bc3":]  # gathers ALL the gene columnsw, independent variables data
Y = df.loc[:, "Rep":"Tissue"]  # Gathers the 3 columsn of dependent variable data

# %%
Y.head(3)
# Out:
#   Rep      Species         Tissue
# 0   1  conchifolia  Female.flower
# 1   2  conchifolia  Female.flower
# 2   3  conchifolia  Female.flower

# %%
X.head(3)
# Out:
#    Bcon1019-0.0_TPS-bc3  Bcon1019-0.2_TPS-bc3  \
# 0             67.311275                   0.0
# 1             24.881496                   0.0
# 2              0.000000                   0.0
#
#    Bcon1029-0.2_Geranylgeranyl pyrophosphate synthase family protein  \
# 0                                          15.645225
# 1                                           3.396060
# 2                                           4.865841
#
#    Bcon1055-2.10_TPS-bc3  Bcon1055-3.1_TPS-bc3  Bcon1055-3.14_TPS-bc3  \
# 0               0.660818                     0                    0.0
# 1               0.000000                     0                    0.0
# 2               0.101612                     0                    0.0
#
#    Bcon1055-3.3_TPS-bc3  Bcon1055-5.2_TPS-bc3  \
# 0                     0                   0.0
# 1                     0                   0.0
# 2                     0                   0.0
#
#    Bcon1065-0.18_1-deoxy-D-xylulose 5-phosphate reductoisomerase  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
#
#    Bcon109-3.8_3-hydroxy-3-methylglutaryl coenzyme A reductase  ...  \
# 0                                         140.151858            ...
# 1                                         168.266137            ...
# 2                                         178.561685            ...
#
#    Bcon983-0.7_TPS-bc2  Bcon983-1.18_TPS-bc2  Bcon983-1.31_TPS-bc2  \
# 0                    0             22.447206                     0
# 1                    0             13.809320                     0
# 2                    0              3.518609                     0
#
#    Bcon983-1.38_TPS-bc2  Bcon983-1.6_TPS-bc2  Bcon983-1.7_TPS-bc2  \
# 0                     0             0.188740             1.391640
# 1                     0             0.000000             0.964168
# 2                     0             0.437499             0.910456
#
#    Bcon995-0.5_TPS-bc3  Bcon995-0.6_TPS-bc3  Bcon995-0.7_TPS-bc3  \
# 0             3.125789                  0.0             0.940281
# 1             1.100803                  0.0             0.000000
# 2             0.333213                  0.0             0.000000
#
#    Bcon1049-2.11_Geranyl diphosphate synthase
# 0                                           0
# 1                                           0
# 2                                           0
#
# [3 rows x 102 columns]

# %% [markdown]
# We can examine mean expression level of each gene across all samples

# %%
X.apply(np.mean)
# Out:
# Bcon1019-0.0_TPS-bc3                                                 49.655797
# Bcon1019-0.2_TPS-bc3                                                  2.994775
# Bcon1029-0.2_Geranylgeranyl pyrophosphate synthase family protein     8.844578
# Bcon1055-2.10_TPS-bc3                                                 0.537160
# Bcon1055-3.1_TPS-bc3                                                  0.000000
#                                                                        ...
# Bcon983-1.7_TPS-bc2                                                   1.690958
# Bcon995-0.5_TPS-bc3                                                   7.241468
# Bcon995-0.6_TPS-bc3                                                   0.202839
# Bcon995-0.7_TPS-bc3                                                   6.348424
# Bcon1049-2.11_Geranyl diphosphate synthase                            0.000000
# Length: 102, dtype: float64

# %% [markdown]
# We could look at covarience between groups using the methods from last week, and analyse whether there was more varation between species or tissues

# %% [markdown]
# However, we can also look at correlations across the whole matrix

# %%
corrmat = X.corr()
corrmat
# Out:
#                                                     Bcon1019-0.0_TPS-bc3  \
# Bcon1019-0.0_TPS-bc3                                            1.000000
# Bcon1019-0.2_TPS-bc3                                           -0.007390
# Bcon1029-0.2_Geranylgeranyl pyrophosphate synth...              0.238361
# Bcon1055-2.10_TPS-bc3                                           0.020721
# Bcon1055-3.1_TPS-bc3                                                 NaN
# ...                                                                  ...
# Bcon983-1.7_TPS-bc2                                            -0.120104
# Bcon995-0.5_TPS-bc3                                             0.007962
# Bcon995-0.6_TPS-bc3                                            -0.060767
# Bcon995-0.7_TPS-bc3                                             0.030317
# Bcon1049-2.11_Geranyl diphosphate synthase                           NaN
#
#                                                     Bcon1019-0.2_TPS-bc3  \
# Bcon1019-0.0_TPS-bc3                                           -0.007390
# Bcon1019-0.2_TPS-bc3                                            1.000000
# Bcon1029-0.2_Geranylgeranyl pyrophosphate synth...              0.304442
# Bcon1055-2.10_TPS-bc3                                           0.523585
# Bcon1055-3.1_TPS-bc3                                                 NaN
# ...                                                                  ...
# Bcon983-1.7_TPS-bc2                                            -0.003356
# Bcon995-0.5_TPS-bc3                                             0.304547
# Bcon995-0.6_TPS-bc3                                             0.079291
# Bcon995-0.7_TPS-bc3                                             0.365028
# Bcon1049-2.11_Geranyl diphosphate synthase                           NaN
#
#                                                     Bcon1029-0.2_Geranylgeranyl pyrophosphate synthase family protein  \
# Bcon1019-0.0_TPS-bc3                                                                         0.238361
# Bcon1019-0.2_TPS-bc3                                                                         0.304442
# Bcon1029-0.2_Geranylgeranyl pyrophosphate synth...                                           1.000000
# Bcon1055-2.10_TPS-bc3                                                                        0.167268
# Bcon1055-3.1_TPS-bc3                                                                              NaN
# ...                                                                                               ...
# Bcon983-1.7_TPS-bc2                                                                         -0.263418
# Bcon995-0.5_TPS-bc3                                                                          0.106731
# Bcon995-0.6_TPS-bc3                                                                         -0.143057
# Bcon995-0.7_TPS-bc3                                                                          0.109730
# Bcon1049-2.11_Geranyl diphosphate synthase                                                        NaN
#
#                                                     Bcon1055-2.10_TPS-bc3  \
# Bcon1019-0.0_TPS-bc3                                             0.020721
# Bcon1019-0.2_TPS-bc3                                             0.523585
# Bcon1029-0.2_Geranylgeranyl pyrophosphate synth...               0.167268
# Bcon1055-2.10_TPS-bc3                                            1.000000
# Bcon1055-3.1_TPS-bc3                                                  NaN
# ...                                                                   ...
# Bcon983-1.7_TPS-bc2                                              0.055433
# Bcon995-0.5_TPS-bc3                                              0.373357
# Bcon995-0.6_TPS-bc3                                              0.023627
# Bcon995-0.7_TPS-bc3                                              0.397050
# Bcon1049-2.11_Geranyl diphosphate synthase                            NaN
#
#                                                     Bcon1055-3.1_TPS-bc3  \
# Bcon1019-0.0_TPS-bc3                                                 NaN
# Bcon1019-0.2_TPS-bc3                                                 NaN
# Bcon1029-0.2_Geranylgeranyl pyrophosphate synth...                   NaN
# Bcon1055-2.10_TPS-bc3                                                NaN
# Bcon1055-3.1_TPS-bc3                                                 NaN
# ...                                                                  ...
# Bcon983-1.7_TPS-bc2                                                  NaN
# Bcon995-0.5_TPS-bc3                                                  NaN
# Bcon995-0.6_TPS-bc3                                                  NaN
# Bcon995-0.7_TPS-bc3                                                  NaN
# Bcon1049-2.11_Geranyl diphosphate synthase                           NaN
#
#                                                     Bcon1055-3.14_TPS-bc3  \
# Bcon1019-0.0_TPS-bc3                                             0.012373
# Bcon1019-0.2_TPS-bc3                                             0.716988
# Bcon1029-0.2_Geranylgeranyl pyrophosphate synth...               0.165037
# Bcon1055-2.10_TPS-bc3                                            0.571354
# Bcon1055-3.1_TPS-bc3                                                  NaN
# ...                                                                   ...
# Bcon983-1.7_TPS-bc2                                              0.215660
# Bcon995-0.5_TPS-bc3                                              0.510331
# Bcon995-0.6_TPS-bc3                                              0.085601
# Bcon995-0.7_TPS-bc3                                              0.574630
# Bcon1049-2.11_Geranyl diphosphate synthase                            NaN
#
#                                                     Bcon1055-3.3_TPS-bc3  \
# Bcon1019-0.0_TPS-bc3                                                 NaN
# Bcon1019-0.2_TPS-bc3                                                 NaN
# Bcon1029-0.2_Geranylgeranyl pyrophosphate synth...                   NaN
# Bcon1055-2.10_TPS-bc3                                                NaN
# Bcon1055-3.1_TPS-bc3                                                 NaN
# ...                                                                  ...
# Bcon983-1.7_TPS-bc2                                                  NaN
# Bcon995-0.5_TPS-bc3                                                  NaN
# Bcon995-0.6_TPS-bc3                                                  NaN
# Bcon995-0.7_TPS-bc3                                                  NaN
# Bcon1049-2.11_Geranyl diphosphate synthase                           NaN
#
#                                                     Bcon1055-5.2_TPS-bc3  \
# Bcon1019-0.0_TPS-bc3                                           -0.082005
# Bcon1019-0.2_TPS-bc3                                            0.870053
# Bcon1029-0.2_Geranylgeranyl pyrophosphate synth...              0.248240
# Bcon1055-2.10_TPS-bc3                                           0.394880
# Bcon1055-3.1_TPS-bc3                                                 NaN
# ...                                                                  ...
# Bcon983-1.7_TPS-bc2                                            -0.029156
# Bcon995-0.5_TPS-bc3                                             0.225552
# Bcon995-0.6_TPS-bc3                                             0.019361
# Bcon995-0.7_TPS-bc3                                             0.272506
# Bcon1049-2.11_Geranyl diphosphate synthase                           NaN
#
#                                                     Bcon1065-0.18_1-deoxy-D-xylulose 5-phosphate reductoisomerase  \
# Bcon1019-0.0_TPS-bc3                                                                              NaN
# Bcon1019-0.2_TPS-bc3                                                                              NaN
# Bcon1029-0.2_Geranylgeranyl pyrophosphate synth...                                                NaN
# Bcon1055-2.10_TPS-bc3                                                                             NaN
# Bcon1055-3.1_TPS-bc3                                                                              NaN
# ...                                                                                               ...
# Bcon983-1.7_TPS-bc2                                                                               NaN
# Bcon995-0.5_TPS-bc3                                                                               NaN
# Bcon995-0.6_TPS-bc3                                                                               NaN
# Bcon995-0.7_TPS-bc3                                                                               NaN
# Bcon1049-2.11_Geranyl diphosphate synthase                                                        NaN
#
#                                                     Bcon109-3.8_3-hydroxy-3-methylglutaryl coenzyme A reductase  \
# Bcon1019-0.0_TPS-bc3                                                                        -0.118767
# Bcon1019-0.2_TPS-bc3                                                                         0.101446
# Bcon1029-0.2_Geranylgeranyl pyrophosphate synth...                                          -0.128220
# Bcon1055-2.10_TPS-bc3                                                                       -0.129243
# Bcon1055-3.1_TPS-bc3                                                                              NaN
# ...                                                                                               ...
# Bcon983-1.7_TPS-bc2                                                                         -0.025388
# Bcon995-0.5_TPS-bc3                                                                         -0.015845
# Bcon995-0.6_TPS-bc3                                                                          0.020345
# Bcon995-0.7_TPS-bc3                                                                          0.018977
# Bcon1049-2.11_Geranyl diphosphate synthase                                                        NaN
#
#                                                     ...  Bcon983-0.7_TPS-bc2  \
# Bcon1019-0.0_TPS-bc3                                ...                  NaN
# Bcon1019-0.2_TPS-bc3                                ...                  NaN
# Bcon1029-0.2_Geranylgeranyl pyrophosphate synth...  ...                  NaN
# Bcon1055-2.10_TPS-bc3                               ...                  NaN
# Bcon1055-3.1_TPS-bc3                                ...                  NaN
# ...                                                 ...                  ...
# Bcon983-1.7_TPS-bc2                                 ...                  NaN
# Bcon995-0.5_TPS-bc3                                 ...                  NaN
# Bcon995-0.6_TPS-bc3                                 ...                  NaN
# Bcon995-0.7_TPS-bc3                                 ...                  NaN
# Bcon1049-2.11_Geranyl diphosphate synthase          ...                  NaN
#
#                                                     Bcon983-1.18_TPS-bc2  \
# Bcon1019-0.0_TPS-bc3                                            0.843876
# Bcon1019-0.2_TPS-bc3                                           -0.188076
# Bcon1029-0.2_Geranylgeranyl pyrophosphate synth...              0.190146
# Bcon1055-2.10_TPS-bc3                                          -0.138544
# Bcon1055-3.1_TPS-bc3                                                 NaN
# ...                                                                  ...
# Bcon983-1.7_TPS-bc2                                            -0.198689
# Bcon995-0.5_TPS-bc3                                            -0.120811
# Bcon995-0.6_TPS-bc3                                            -0.067403
# Bcon995-0.7_TPS-bc3                                            -0.104558
# Bcon1049-2.11_Geranyl diphosphate synthase                           NaN
#
#                                                     Bcon983-1.31_TPS-bc2  \
# Bcon1019-0.0_TPS-bc3                                                 NaN
# Bcon1019-0.2_TPS-bc3                                                 NaN
# Bcon1029-0.2_Geranylgeranyl pyrophosphate synth...                   NaN
# Bcon1055-2.10_TPS-bc3                                                NaN
# Bcon1055-3.1_TPS-bc3                                                 NaN
# ...                                                                  ...
# Bcon983-1.7_TPS-bc2                                                  NaN
# Bcon995-0.5_TPS-bc3                                                  NaN
# Bcon995-0.6_TPS-bc3                                                  NaN
# Bcon995-0.7_TPS-bc3                                                  NaN
# Bcon1049-2.11_Geranyl diphosphate synthase                           NaN
#
#                                                     Bcon983-1.38_TPS-bc2  \
# Bcon1019-0.0_TPS-bc3                                                 NaN
# Bcon1019-0.2_TPS-bc3                                                 NaN
# Bcon1029-0.2_Geranylgeranyl pyrophosphate synth...                   NaN
# Bcon1055-2.10_TPS-bc3                                                NaN
# Bcon1055-3.1_TPS-bc3                                                 NaN
# ...                                                                  ...
# Bcon983-1.7_TPS-bc2                                                  NaN
# Bcon995-0.5_TPS-bc3                                                  NaN
# Bcon995-0.6_TPS-bc3                                                  NaN
# Bcon995-0.7_TPS-bc3                                                  NaN
# Bcon1049-2.11_Geranyl diphosphate synthase                           NaN
#
#                                                     Bcon983-1.6_TPS-bc2  \
# Bcon1019-0.0_TPS-bc3                                          -0.105836
# Bcon1019-0.2_TPS-bc3                                           0.184807
# Bcon1029-0.2_Geranylgeranyl pyrophosphate synth...             0.247651
# Bcon1055-2.10_TPS-bc3                                         -0.092169
# Bcon1055-3.1_TPS-bc3                                                NaN
# ...                                                                 ...
# Bcon983-1.7_TPS-bc2                                           -0.009520
# Bcon995-0.5_TPS-bc3                                           -0.023087
# Bcon995-0.6_TPS-bc3                                           -0.063214
# Bcon995-0.7_TPS-bc3                                           -0.009703
# Bcon1049-2.11_Geranyl diphosphate synthase                          NaN
#
#                                                     Bcon983-1.7_TPS-bc2  \
# Bcon1019-0.0_TPS-bc3                                          -0.120104
# Bcon1019-0.2_TPS-bc3                                          -0.003356
# Bcon1029-0.2_Geranylgeranyl pyrophosphate synth...            -0.263418
# Bcon1055-2.10_TPS-bc3                                          0.055433
# Bcon1055-3.1_TPS-bc3                                                NaN
# ...                                                                 ...
# Bcon983-1.7_TPS-bc2                                            1.000000
# Bcon995-0.5_TPS-bc3                                            0.465609
# Bcon995-0.6_TPS-bc3                                           -0.119836
# Bcon995-0.7_TPS-bc3                                            0.504609
# Bcon1049-2.11_Geranyl diphosphate synthase                          NaN
#
#                                                     Bcon995-0.5_TPS-bc3  \
# Bcon1019-0.0_TPS-bc3                                           0.007962
# Bcon1019-0.2_TPS-bc3                                           0.304547
# Bcon1029-0.2_Geranylgeranyl pyrophosphate synth...             0.106731
# Bcon1055-2.10_TPS-bc3                                          0.373357
# Bcon1055-3.1_TPS-bc3                                                NaN
# ...                                                                 ...
# Bcon983-1.7_TPS-bc2                                            0.465609
# Bcon995-0.5_TPS-bc3                                            1.000000
# Bcon995-0.6_TPS-bc3                                            0.025698
# Bcon995-0.7_TPS-bc3                                            0.958235
# Bcon1049-2.11_Geranyl diphosphate synthase                          NaN
#
#                                                     Bcon995-0.6_TPS-bc3  \
# Bcon1019-0.0_TPS-bc3                                          -0.060767
# Bcon1019-0.2_TPS-bc3                                           0.079291
# Bcon1029-0.2_Geranylgeranyl pyrophosphate synth...            -0.143057
# Bcon1055-2.10_TPS-bc3                                          0.023627
# Bcon1055-3.1_TPS-bc3                                                NaN
# ...                                                                 ...
# Bcon983-1.7_TPS-bc2                                           -0.119836
# Bcon995-0.5_TPS-bc3                                            0.025698
# Bcon995-0.6_TPS-bc3                                            1.000000
# Bcon995-0.7_TPS-bc3                                            0.040376
# Bcon1049-2.11_Geranyl diphosphate synthase                          NaN
#
#                                                     Bcon995-0.7_TPS-bc3  \
# Bcon1019-0.0_TPS-bc3                                           0.030317
# Bcon1019-0.2_TPS-bc3                                           0.365028
# Bcon1029-0.2_Geranylgeranyl pyrophosphate synth...             0.109730
# Bcon1055-2.10_TPS-bc3                                          0.397050
# Bcon1055-3.1_TPS-bc3                                                NaN
# ...                                                                 ...
# Bcon983-1.7_TPS-bc2                                            0.504609
# Bcon995-0.5_TPS-bc3                                            0.958235
# Bcon995-0.6_TPS-bc3                                            0.040376
# Bcon995-0.7_TPS-bc3                                            1.000000
# Bcon1049-2.11_Geranyl diphosphate synthase                          NaN
#
#                                                     Bcon1049-2.11_Geranyl diphosphate synthase
# Bcon1019-0.0_TPS-bc3                                                                       NaN
# Bcon1019-0.2_TPS-bc3                                                                       NaN
# Bcon1029-0.2_Geranylgeranyl pyrophosphate synth...                                         NaN
# Bcon1055-2.10_TPS-bc3                                                                      NaN
# Bcon1055-3.1_TPS-bc3                                                                       NaN
# ...                                                                                        ...
# Bcon983-1.7_TPS-bc2                                                                        NaN
# Bcon995-0.5_TPS-bc3                                                                        NaN
# Bcon995-0.6_TPS-bc3                                                                        NaN
# Bcon995-0.7_TPS-bc3                                                                        NaN
# Bcon1049-2.11_Geranyl diphosphate synthase                                                 NaN
#
# [102 rows x 102 columns]

# %% [markdown]
# and this can be nicely displayed in a heatmap

# %%
sns.heatmap(corrmat, vmax=1., square=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# All these gaps are caused by genes which are not expressed.  If we remove the 'all zero' rows we get a clearer plot

# %%
X = X.loc[:, (X != 0).any(axis=0)]
corrmat = X.corr()
sns.heatmap(corrmat, vmax=1., square=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# But so messy!

# %% [markdown]
# How can we order the heatmap plotting?
# For this we need to cluster the genes by the most similar.

# %%
sns.clustermap(X)

# %% [markdown]
# Ah!  the plot is dominated by a few very highly expressed genes. One way round this is to change the ends of the color scale to the 2nd and 98th percentile values of the data, rather then the maximum and minimum.

# %%
sns.clustermap(X, robust=True)

# %% [markdown]
# To see more pattern we need to standardise the dataframe.  We will use 'standard_scale =1' which , for each oclumn, subtracts the miniomum and divides by the maximum

# %%
sns.clustermap(X, standard_scale = 1)

# %% [markdown]
# We can label the rows by tissue type, using a dictionary to look up the right colour for each label.  We get the set of unique values in each column, and give each of them a colour.  We then map these colour labels onto the series of 'Tissue' or 'Species'.

# %%
Y.head(3)
# Out:
#   Rep      Species         Tissue
# 0   1  conchifolia  Female.flower
# 1   2  conchifolia  Female.flower
# 2   3  conchifolia  Female.flower

# %%
Tissue = Y["Tissue"]
labels = Tissue.unique()
lut = dict(zip(set(labels), ['red','limegreen','deeppink','yellowgreen', 'saddlebrown', 'palegreen']))
row_colors = Tissue.map(lut)

# %%
Species = Y["Species"]
labels2 = Species.unique()
lut = dict(zip(set(labels2), ['orangered', 'lightgreen']))
row_colors2 = Species.map(lut)

# %%
Tissue.unique()
# Out:
# array(['Female.flower', 'Leaf', 'Male.flower', 'Petiole', 'Root',
#        'Veg.bud'], dtype=object)

# %%
Species.unique()
# Out:
# array(['conchifolia', 'plebeja'], dtype=object)

# %%
row_colors2
# Out:
# 0      orangered
# 1      orangered
# 2      orangered
# 3      orangered
# 4      orangered
#          ...
# 31    lightgreen
# 32    lightgreen
# 33    lightgreen
# 34    lightgreen
# 35    lightgreen
# Name: Species, Length: 36, dtype: object

# %%
g=sns.clustermap(X, standard_scale = 1, row_colors=[row_colors, row_colors2])
plt.show()

# %% [markdown]
# The two species look very different.  Try plotting separate heatmaps for each species.

# %% [markdown]
# It's noteable that the hierchical clustering has NOT separated exactly by species or by tissue.
# Does a kmeans approach do this?  To use kmeans we first need to do some dimension reduction, via PCA which we will cover in the next class.
